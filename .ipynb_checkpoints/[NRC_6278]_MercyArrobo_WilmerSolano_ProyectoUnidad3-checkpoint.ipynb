# %% [markdown]
# ## PROYECTO
# Nombre: Mercy Arrobo - Solano Wilmer

# %%
#Importación de librerías necesarias
import cv2
import numpy as np
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' 
import shutil
import glob
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn
from keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.utils import img_to_array, array_to_img, img_to_array, load_img
from  PIL  import Image
from rembg import remove
from sklearn.preprocessing import MinMaxScaler
import h5py
from time import sleep
#para la segunda parte
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras import layers, models
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.model_selection import train_test_split
#AlexNet
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Dropout
from tensorflow.keras.layers import BatchNormalization

# %% [markdown]
# # Procesamiento de imagenes

# %%
"""Declarar y presentar la dirección donde se encuentran las imagenes"""
ruta_imagen = "./PROYECTOIA-U3"
nombre_clases = os.listdir(ruta_imagen )
nombre_clases.sort()
"""Presentando etiquetas"""
print(nombre_clases)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedeno', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MelanyLópez', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'Raymond Davila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
"""Ciclo for para reocrren el nombre de las etiquetas"""
for nombre_clase in nombre_clases:
    cur_path = ruta_imagen + "/" + nombre_clase
    elements = os.listdir(cur_path)
    """Copiando las imágenes en una nueva carpeta"""
    for element in elements:
        print("Copiando imagen - {} in PROYECTOIA-U3_Aumento/{}".format(element, nombre_clase))
        src = os.path.join(ruta_imagen  + "/" + nombre_clase, element) # origen
        dst = os.path.join("./PROYECTOIA-U3_Aumento/" + nombre_clase, element) 
        shutil.copy(src, dst)
# Out:
# Copiando imagen - L00376418_1.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00376418_2.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00376418_3.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00376418_4.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00376418_5.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00376418_6.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00376418_7.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00376418_8.jpg in PROYECTOIA-U3_Aumento/Ariel Chabla
# Copiando imagen - L00385770_1.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00385770_2.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00385770_3.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00385770_4.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00385770_5.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00385770_6.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00385770_7.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00385770_8.jpg in PROYECTOIA-U3_Aumento/ArroboMercy
# Copiando imagen - L00392978_1.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_10.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_11.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_12.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_13.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_14.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_2.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_3.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_4.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_5.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_6.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_7.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_8.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00392978_9.jpg in PROYECTOIA-U3_Aumento/BarraganSteven
# Copiando imagen - L00376416_1.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_2.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_3.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_4.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_5.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_6.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_7.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_8.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L00376416_9.jpg in PROYECTOIA-U3_Aumento/CevallosJoan
# Copiando imagen - L000376481_1.jpg in PROYECTOIA-U3_Aumento/EnriquezSelena
# Copiando imagen - L000376481_2.jpg in PROYECTOIA-U3_Aumento/EnriquezSelena
# Copiando imagen - L000376481_3.jpg in PROYECTOIA-U3_Aumento/EnriquezSelena
# Copiando imagen - L000376481_4.jpg in PROYECTOIA-U3_Aumento/EnriquezSelena
# Copiando imagen - L000376481_5.jpg in PROYECTOIA-U3_Aumento/EnriquezSelena
# Copiando imagen - L00392991_1.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_10.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_2.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_3.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_4.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_5.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_6.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_7.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_8.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00392991_9.jpg in PROYECTOIA-U3_Aumento/GenesisHeredia
# Copiando imagen - L00393010_1.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_10.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_2.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_3.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_4.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_5.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_6.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_7.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_8.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L00393010_9.jpg in PROYECTOIA-U3_Aumento/GoyesAnthony
# Copiando imagen - L003392989_4.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L003392989_5.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L003392989_6.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L003392989_7.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L003392989_8.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L00392989_1.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L00392989_10.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L00392989_2.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L00392989_3.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L00392989_9.jpg in PROYECTOIA-U3_Aumento/HectorCedeno
# Copiando imagen - L00392993_10.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_11.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_12.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_13.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_4.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_5.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_6.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_7.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_8.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_9.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_Centro.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_LD.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00392993_LI.jpg in PROYECTOIA-U3_Aumento/Jhon Zambrano
# Copiando imagen - L00080128_1 Frente.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00080128_2 Derecho.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00080128_3 Izquierda.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00080128_4.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00080128_5.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00080128_6.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00080128_7.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00080128_8.jpg in PROYECTOIA-U3_Aumento/Jordan Espinosa
# Copiando imagen - L00379412_1.jpg in PROYECTOIA-U3_Aumento/Jorge Borrero
# Copiando imagen - L00379412_2.jpg in PROYECTOIA-U3_Aumento/Jorge Borrero
# Copiando imagen - L00379412_3.jpg in PROYECTOIA-U3_Aumento/Jorge Borrero
# Copiando imagen - L00380361_1.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_10.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_2.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_3.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_4.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_5.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_6.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_7.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_8.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00380361_9.jpg in PROYECTOIA-U3_Aumento/JoseRuiz
# Copiando imagen - L00393009_1.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_10.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_2.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_3.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_4.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_5.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_6.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_7.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_8.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00393009_9.jpg in PROYECTOIA-U3_Aumento/LucioCarlos
# Copiando imagen - L00392999_1.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_10.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_11.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_2.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_3.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_4.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_5.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_6.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_7.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_8.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00392999_9.jpg in PROYECTOIA-U3_Aumento/MelanyLópez
# Copiando imagen - L00073392_1.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_2.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_3.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_4.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_5.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_6.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_7.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_8.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00073392_9.jpg in PROYECTOIA-U3_Aumento/MosqueraLucy
# Copiando imagen - L00380424_1.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00380424_2.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00380424_3.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00380424_4.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00380424_5.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00380424_6.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00380424_7.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00380424_8.jpg in PROYECTOIA-U3_Aumento/Nataly Acosta
# Copiando imagen - L00393001_1.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_10.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_11.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_12.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_13.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_2.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_3.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_4.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_5.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_6.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_7.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_8.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00393001_9.jpg in PROYECTOIA-U3_Aumento/OlallaLuis
# Copiando imagen - L00392984_1.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_10.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_2.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_3.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_4.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_5.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_6.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_7.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_8.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00392984_9.jpg in PROYECTOIA-U3_Aumento/ParragaMariaJose
# Copiando imagen - L00080134_1.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_10.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_2.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_3.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_4.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_5.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_6.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_7.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_8.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080134_9.jpg in PROYECTOIA-U3_Aumento/PauteKevin
# Copiando imagen - L00080957_1.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_2.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_3.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_4.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_5.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_6.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_7.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_8.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00080957_9.jpg in PROYECTOIA-U3_Aumento/Raymond Davila
# Copiando imagen - L00376689_1.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_10.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_11.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_2.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_3.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_4.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_5.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_6.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_7.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_8.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00376689_9.jpg in PROYECTOIA-U3_Aumento/RivasSelena
# Copiando imagen - L00380416_1.png in PROYECTOIA-U3_Aumento/SalazarJohana
# Copiando imagen - L00380416_2.png in PROYECTOIA-U3_Aumento/SalazarJohana
# Copiando imagen - L00380416_3.png in PROYECTOIA-U3_Aumento/SalazarJohana
# Copiando imagen - L00380416_4.png in PROYECTOIA-U3_Aumento/SalazarJohana
# Copiando imagen - L00380416_5.png in PROYECTOIA-U3_Aumento/SalazarJohana
# Copiando imagen - L00392980_1.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00392980_2.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00392980_3.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00392980_4.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00392980_5.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00392980_6.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00392980_7.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00392980_8.jpg in PROYECTOIA-U3_Aumento/Solano Wilmer
# Copiando imagen - L00080131_1.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_2.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_3.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_4.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_5.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_6.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_7.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_8.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00080131_9.jpg in PROYECTOIA-U3_Aumento/SolorzanoBryan
# Copiando imagen - L00393007_1.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_10.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_2.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_3.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_4.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_5.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_6.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_7.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_8.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja
# Copiando imagen - L00393007_9.jpeg in PROYECTOIA-U3_Aumento/VinicioBorja

# %% [markdown]
# ## Aumento de datos

# %%
"""Generando imagenes nuevas"""
datagen = ImageDataGenerator(
        rotation_range=40,
        width_shift_range=0.2,
        height_shift_range=0.2,
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.4,
        horizontal_flip=True,
        fill_mode='nearest')

# %% [markdown]
# ## Arrobo Mercy

# %%
"""Creando imágenes para la carpeta de Mercy"""
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\ArroboMercy")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'ArroboMercy', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# ## Leonardo Borja

# %%
"""Creando imágenes para la carpeta de Borja"""
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\VinicioBorja")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".",  
            save_prefix= 'VinicioBorja', 
            save_format='jpg'):
        i += 1
        if i == 9:     
            break

# %% [markdown]
# ## Paute Kevin

# %%
"""Creando imágenes para la carpeta de Paute"""
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\PauteKevin")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".",   
            save_prefix= 'PauteKevin', 
            save_format='jpg'):
        i += 1
        if i == 9:     
            break

# %% [markdown]
# ## RivasSelena

# %%
"""Creando imágenes para la carpeta de Rivas"""
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\RivasSelena")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".",   
            save_prefix= 'RivasSelena', 
            save_format='jpg'):
        i += 1
        if i == 9:     
            break

# %% [markdown]
# ## Solano Wilmer

# %%
"""Creando imágenes para la carpeta de Solano"""
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\Solano Wilmer")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".",   
            save_prefix= 'Solano Wilmer', 
            save_format='jpg'):
        i += 1
        if i == 9:     
            break

# %% [markdown]
# # Ariel Chaula

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\Ariel Chabla")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Ariel Chabla', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # Barragan Steven

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\BarraganSteven")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'BarraganSteven', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # CevallosJoan

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\CevallosJoan")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'CevallosJoan', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # EnriquezSelena

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\EnriquezSelena")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'EnriquezSelena', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # GenesisHeredia

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\GenesisHeredia")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'GenesisHeredia', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # GoyesAnthony

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\GoyesAnthony")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'GoyesAnthony', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # HectorCedeño

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\HectorCedeno")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'HectorCedeno', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # Jhon Zambrano

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\Jhon Zambrano")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Jhon Zambrano', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # Jordan Espinosa

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\Jordan Espinosa")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Jordan Espinosa', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # Jorge Borrero

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\Jorge Borrero")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Jorge Borrero', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # JoseRuiz

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\JoseRuiz")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'JoseRuiz', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # LucioCarlos

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\LucioCarlos")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'LucioCarlos', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # MelanyLópez

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\MelanyLópez")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'MelanyLópez', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # MosqueraLucy

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\MosqueraLucy")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'MosqueraLucy', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # Nataly Acosta

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\Nataly Acosta")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Nataly Acosta', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # OlallaLuis

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\OlallaLuis")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'OlallaLuis', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # ParragaMariaJose

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\ParragaMariaJose")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'ParragaMariaJose', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # Raymond Davila

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\Raymond Davila")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'Raymond Davila', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # SalazarJohana

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\SalazarJohana")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'SalazarJohana', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# # SolórzanoBryan

# %%
"""Creando imágenes para la carpeta: """
os.chdir(r"C:\Users\wilme\PROYECTOIA-U3_Aumento\SolorzanoBryan")
for path in os.listdir():
    img = load_img(f"{path}")
    x = img_to_array(img)    
    x = x.reshape((1,) + x.shape)
    i = 0
    for batch in datagen.flow(x, batch_size=1,
            save_to_dir=".", 
            save_prefix= 'SolorzanoBryan', 
            save_format='jpg'):
        i += 1
        if i == 9:    
            break

# %% [markdown]
# ## Filtro NLM para eliminación de ruido de imágenes

# %%
"""Obteniendo etiquetas de la nueva carpeta que se ha creado"""
os.chdir(r"C:\Users\wilme")
ruta_imagen = "./PROYECTOIA-U3_Aumento"
nombre_clases = os.listdir(ruta_imagen)
nombre_clases.sort()
print(nombre_clases)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedeno', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LeonardoBorja', 'LucioCarlos', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'Raymond Davila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
"""Recorriendo la ruta y el nombre de cada carpeta"""
for nombre_clase in nombre_clases:
    cur_path = ruta_imagen + "/" + nombre_clase
    cur_label = nombre_clase
    i = 1
    """Ciclo for para que se elimine el ruido de cada imágen"""
    for file in glob.glob(cur_path + "/*"):
        print("Imagen de procesamiento - {} in {}".format(i, cur_label))
        # leer la ruta de las imágenes
        image = cv2.imread(file)
        # Imágenes de denoising
        dst = cv2.fastNlMeansDenoisingColored(image,None,10,10,7,21)
        b,g,r = cv2.split(dst)
        rgb_dst = cv2.merge([r,g,b])
        # guardando imágenes
        save_path = './PROYECTOIA-U3_eliminarRuido/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.jpg'),
                    cv2.cvtColor(rgb_dst,cv2.COLOR_RGB2BGR))
        
        # mostrar actualización de bucle
        i += 1
# Out:
# Imagen de procesamiento - 1 in Ariel Chabla
# Imagen de procesamiento - 2 in Ariel Chabla
# Imagen de procesamiento - 3 in Ariel Chabla
# Imagen de procesamiento - 4 in Ariel Chabla
# Imagen de procesamiento - 5 in Ariel Chabla
# Imagen de procesamiento - 6 in Ariel Chabla
# Imagen de procesamiento - 7 in Ariel Chabla
# Imagen de procesamiento - 8 in Ariel Chabla
# Imagen de procesamiento - 9 in Ariel Chabla
# Imagen de procesamiento - 10 in Ariel Chabla
# Imagen de procesamiento - 11 in Ariel Chabla
# Imagen de procesamiento - 12 in Ariel Chabla
# Imagen de procesamiento - 13 in Ariel Chabla
# Imagen de procesamiento - 14 in Ariel Chabla
# Imagen de procesamiento - 15 in Ariel Chabla
# Imagen de procesamiento - 16 in Ariel Chabla
# Imagen de procesamiento - 17 in Ariel Chabla
# Imagen de procesamiento - 18 in Ariel Chabla
# Imagen de procesamiento - 19 in Ariel Chabla
# Imagen de procesamiento - 20 in Ariel Chabla
# Imagen de procesamiento - 21 in Ariel Chabla
# Imagen de procesamiento - 22 in Ariel Chabla
# Imagen de procesamiento - 23 in Ariel Chabla
# Imagen de procesamiento - 24 in Ariel Chabla
# Imagen de procesamiento - 25 in Ariel Chabla
# Imagen de procesamiento - 26 in Ariel Chabla
# Imagen de procesamiento - 27 in Ariel Chabla
# Imagen de procesamiento - 28 in Ariel Chabla
# Imagen de procesamiento - 29 in Ariel Chabla
# Imagen de procesamiento - 30 in Ariel Chabla
# Imagen de procesamiento - 31 in Ariel Chabla
# Imagen de procesamiento - 32 in Ariel Chabla
# Imagen de procesamiento - 33 in Ariel Chabla
# Imagen de procesamiento - 34 in Ariel Chabla
# Imagen de procesamiento - 35 in Ariel Chabla
# Imagen de procesamiento - 36 in Ariel Chabla
# Imagen de procesamiento - 37 in Ariel Chabla
# Imagen de procesamiento - 38 in Ariel Chabla
# Imagen de procesamiento - 39 in Ariel Chabla
# Imagen de procesamiento - 40 in Ariel Chabla
# Imagen de procesamiento - 41 in Ariel Chabla
# Imagen de procesamiento - 42 in Ariel Chabla
# Imagen de procesamiento - 43 in Ariel Chabla
# Imagen de procesamiento - 44 in Ariel Chabla
# Imagen de procesamiento - 45 in Ariel Chabla
# Imagen de procesamiento - 46 in Ariel Chabla
# Imagen de procesamiento - 47 in Ariel Chabla
# Imagen de procesamiento - 48 in Ariel Chabla
# Imagen de procesamiento - 49 in Ariel Chabla
# Imagen de procesamiento - 50 in Ariel Chabla
# Imagen de procesamiento - 51 in Ariel Chabla
# Imagen de procesamiento - 52 in Ariel Chabla
# Imagen de procesamiento - 53 in Ariel Chabla
# Imagen de procesamiento - 54 in Ariel Chabla
# Imagen de procesamiento - 55 in Ariel Chabla
# Imagen de procesamiento - 56 in Ariel Chabla
# Imagen de procesamiento - 57 in Ariel Chabla
# Imagen de procesamiento - 58 in Ariel Chabla
# Imagen de procesamiento - 59 in Ariel Chabla
# Imagen de procesamiento - 60 in Ariel Chabla
# Imagen de procesamiento - 61 in Ariel Chabla
# Imagen de procesamiento - 62 in Ariel Chabla
# Imagen de procesamiento - 63 in Ariel Chabla
# Imagen de procesamiento - 64 in Ariel Chabla
# Imagen de procesamiento - 65 in Ariel Chabla
# Imagen de procesamiento - 66 in Ariel Chabla
# Imagen de procesamiento - 67 in Ariel Chabla
# Imagen de procesamiento - 68 in Ariel Chabla
# Imagen de procesamiento - 69 in Ariel Chabla
# Imagen de procesamiento - 70 in Ariel Chabla
# Imagen de procesamiento - 71 in Ariel Chabla
# Imagen de procesamiento - 72 in Ariel Chabla
# Imagen de procesamiento - 73 in Ariel Chabla
# Imagen de procesamiento - 74 in Ariel Chabla
# Imagen de procesamiento - 75 in Ariel Chabla
# Imagen de procesamiento - 76 in Ariel Chabla
# Imagen de procesamiento - 77 in Ariel Chabla
# Imagen de procesamiento - 78 in Ariel Chabla
# Imagen de procesamiento - 79 in Ariel Chabla
# Imagen de procesamiento - 80 in Ariel Chabla
# Imagen de procesamiento - 1 in ArroboMercy
# Imagen de procesamiento - 2 in ArroboMercy
# Imagen de procesamiento - 3 in ArroboMercy
# Imagen de procesamiento - 4 in ArroboMercy
# Imagen de procesamiento - 5 in ArroboMercy
# Imagen de procesamiento - 6 in ArroboMercy
# Imagen de procesamiento - 7 in ArroboMercy
# Imagen de procesamiento - 8 in ArroboMercy
# Imagen de procesamiento - 9 in ArroboMercy
# Imagen de procesamiento - 10 in ArroboMercy
# Imagen de procesamiento - 11 in ArroboMercy
# Imagen de procesamiento - 12 in ArroboMercy
# Imagen de procesamiento - 13 in ArroboMercy
# Imagen de procesamiento - 14 in ArroboMercy
# Imagen de procesamiento - 15 in ArroboMercy
# Imagen de procesamiento - 16 in ArroboMercy
# Imagen de procesamiento - 17 in ArroboMercy
# Imagen de procesamiento - 18 in ArroboMercy
# Imagen de procesamiento - 19 in ArroboMercy
# Imagen de procesamiento - 20 in ArroboMercy
# Imagen de procesamiento - 21 in ArroboMercy
# Imagen de procesamiento - 22 in ArroboMercy
# Imagen de procesamiento - 23 in ArroboMercy
# Imagen de procesamiento - 24 in ArroboMercy
# Imagen de procesamiento - 25 in ArroboMercy
# Imagen de procesamiento - 26 in ArroboMercy
# Imagen de procesamiento - 27 in ArroboMercy
# Imagen de procesamiento - 28 in ArroboMercy
# Imagen de procesamiento - 29 in ArroboMercy
# Imagen de procesamiento - 30 in ArroboMercy
# Imagen de procesamiento - 31 in ArroboMercy
# Imagen de procesamiento - 32 in ArroboMercy
# Imagen de procesamiento - 33 in ArroboMercy
# Imagen de procesamiento - 34 in ArroboMercy
# Imagen de procesamiento - 35 in ArroboMercy
# Imagen de procesamiento - 36 in ArroboMercy
# Imagen de procesamiento - 37 in ArroboMercy
# Imagen de procesamiento - 38 in ArroboMercy
# Imagen de procesamiento - 39 in ArroboMercy
# Imagen de procesamiento - 40 in ArroboMercy
# Imagen de procesamiento - 41 in ArroboMercy
# Imagen de procesamiento - 42 in ArroboMercy
# Imagen de procesamiento - 43 in ArroboMercy
# Imagen de procesamiento - 44 in ArroboMercy
# Imagen de procesamiento - 45 in ArroboMercy
# Imagen de procesamiento - 46 in ArroboMercy
# Imagen de procesamiento - 47 in ArroboMercy
# Imagen de procesamiento - 48 in ArroboMercy
# Imagen de procesamiento - 49 in ArroboMercy
# Imagen de procesamiento - 50 in ArroboMercy
# Imagen de procesamiento - 51 in ArroboMercy
# Imagen de procesamiento - 52 in ArroboMercy
# Imagen de procesamiento - 53 in ArroboMercy
# Imagen de procesamiento - 54 in ArroboMercy
# Imagen de procesamiento - 55 in ArroboMercy
# Imagen de procesamiento - 56 in ArroboMercy
# Imagen de procesamiento - 57 in ArroboMercy
# Imagen de procesamiento - 58 in ArroboMercy
# Imagen de procesamiento - 59 in ArroboMercy
# Imagen de procesamiento - 60 in ArroboMercy
# Imagen de procesamiento - 61 in ArroboMercy
# Imagen de procesamiento - 62 in ArroboMercy
# Imagen de procesamiento - 63 in ArroboMercy
# Imagen de procesamiento - 64 in ArroboMercy
# Imagen de procesamiento - 65 in ArroboMercy
# Imagen de procesamiento - 66 in ArroboMercy
# Imagen de procesamiento - 67 in ArroboMercy
# Imagen de procesamiento - 68 in ArroboMercy
# Imagen de procesamiento - 69 in ArroboMercy
# Imagen de procesamiento - 70 in ArroboMercy
# Imagen de procesamiento - 71 in ArroboMercy
# Imagen de procesamiento - 72 in ArroboMercy
# Imagen de procesamiento - 73 in ArroboMercy
# Imagen de procesamiento - 74 in ArroboMercy
# Imagen de procesamiento - 75 in ArroboMercy
# Imagen de procesamiento - 76 in ArroboMercy
# Imagen de procesamiento - 77 in ArroboMercy
# Imagen de procesamiento - 78 in ArroboMercy
# Imagen de procesamiento - 79 in ArroboMercy
# Imagen de procesamiento - 1 in BarraganSteven
# Imagen de procesamiento - 2 in BarraganSteven
# Imagen de procesamiento - 3 in BarraganSteven
# Imagen de procesamiento - 4 in BarraganSteven
# Imagen de procesamiento - 5 in BarraganSteven
# Imagen de procesamiento - 6 in BarraganSteven
# Imagen de procesamiento - 7 in BarraganSteven
# Imagen de procesamiento - 8 in BarraganSteven
# Imagen de procesamiento - 9 in BarraganSteven
# Imagen de procesamiento - 10 in BarraganSteven
# Imagen de procesamiento - 11 in BarraganSteven
# Imagen de procesamiento - 12 in BarraganSteven
# Imagen de procesamiento - 13 in BarraganSteven
# Imagen de procesamiento - 14 in BarraganSteven
# Imagen de procesamiento - 15 in BarraganSteven
# Imagen de procesamiento - 16 in BarraganSteven
# Imagen de procesamiento - 17 in BarraganSteven
# Imagen de procesamiento - 18 in BarraganSteven
# Imagen de procesamiento - 19 in BarraganSteven
# Imagen de procesamiento - 20 in BarraganSteven
# Imagen de procesamiento - 21 in BarraganSteven
# Imagen de procesamiento - 22 in BarraganSteven
# Imagen de procesamiento - 23 in BarraganSteven
# Imagen de procesamiento - 24 in BarraganSteven
# Imagen de procesamiento - 25 in BarraganSteven
# Imagen de procesamiento - 26 in BarraganSteven
# Imagen de procesamiento - 27 in BarraganSteven
# Imagen de procesamiento - 28 in BarraganSteven
# Imagen de procesamiento - 29 in BarraganSteven
# Imagen de procesamiento - 30 in BarraganSteven
# Imagen de procesamiento - 31 in BarraganSteven
# Imagen de procesamiento - 32 in BarraganSteven
# Imagen de procesamiento - 33 in BarraganSteven
# Imagen de procesamiento - 34 in BarraganSteven
# Imagen de procesamiento - 35 in BarraganSteven
# Imagen de procesamiento - 36 in BarraganSteven
# Imagen de procesamiento - 37 in BarraganSteven
# Imagen de procesamiento - 38 in BarraganSteven
# Imagen de procesamiento - 39 in BarraganSteven
# Imagen de procesamiento - 40 in BarraganSteven
# Imagen de procesamiento - 41 in BarraganSteven
# Imagen de procesamiento - 42 in BarraganSteven
# Imagen de procesamiento - 43 in BarraganSteven
# Imagen de procesamiento - 44 in BarraganSteven
# Imagen de procesamiento - 45 in BarraganSteven
# Imagen de procesamiento - 46 in BarraganSteven
# Imagen de procesamiento - 47 in BarraganSteven
# Imagen de procesamiento - 48 in BarraganSteven
# Imagen de procesamiento - 49 in BarraganSteven
# Imagen de procesamiento - 50 in BarraganSteven
# Imagen de procesamiento - 51 in BarraganSteven
# Imagen de procesamiento - 52 in BarraganSteven
# Imagen de procesamiento - 53 in BarraganSteven
# Imagen de procesamiento - 54 in BarraganSteven
# Imagen de procesamiento - 55 in BarraganSteven
# Imagen de procesamiento - 56 in BarraganSteven
# Imagen de procesamiento - 57 in BarraganSteven
# Imagen de procesamiento - 58 in BarraganSteven
# Imagen de procesamiento - 59 in BarraganSteven
# Imagen de procesamiento - 60 in BarraganSteven
# Imagen de procesamiento - 61 in BarraganSteven
# Imagen de procesamiento - 62 in BarraganSteven
# Imagen de procesamiento - 63 in BarraganSteven
# Imagen de procesamiento - 64 in BarraganSteven
# Imagen de procesamiento - 65 in BarraganSteven
# Imagen de procesamiento - 66 in BarraganSteven
# Imagen de procesamiento - 67 in BarraganSteven
# Imagen de procesamiento - 68 in BarraganSteven
# Imagen de procesamiento - 69 in BarraganSteven
# Imagen de procesamiento - 70 in BarraganSteven
# Imagen de procesamiento - 71 in BarraganSteven
# Imagen de procesamiento - 72 in BarraganSteven
# Imagen de procesamiento - 73 in BarraganSteven
# Imagen de procesamiento - 74 in BarraganSteven
# Imagen de procesamiento - 75 in BarraganSteven
# Imagen de procesamiento - 76 in BarraganSteven
# Imagen de procesamiento - 77 in BarraganSteven
# Imagen de procesamiento - 78 in BarraganSteven
# Imagen de procesamiento - 79 in BarraganSteven
# Imagen de procesamiento - 80 in BarraganSteven
# Imagen de procesamiento - 81 in BarraganSteven
# Imagen de procesamiento - 82 in BarraganSteven
# Imagen de procesamiento - 83 in BarraganSteven
# Imagen de procesamiento - 84 in BarraganSteven
# Imagen de procesamiento - 85 in BarraganSteven
# Imagen de procesamiento - 86 in BarraganSteven
# Imagen de procesamiento - 87 in BarraganSteven
# Imagen de procesamiento - 88 in BarraganSteven
# Imagen de procesamiento - 89 in BarraganSteven
# Imagen de procesamiento - 90 in BarraganSteven
# Imagen de procesamiento - 91 in BarraganSteven
# Imagen de procesamiento - 92 in BarraganSteven
# Imagen de procesamiento - 93 in BarraganSteven
# Imagen de procesamiento - 94 in BarraganSteven
# Imagen de procesamiento - 95 in BarraganSteven
# Imagen de procesamiento - 96 in BarraganSteven
# Imagen de procesamiento - 97 in BarraganSteven
# Imagen de procesamiento - 98 in BarraganSteven
# Imagen de procesamiento - 99 in BarraganSteven
# Imagen de procesamiento - 100 in BarraganSteven
# Imagen de procesamiento - 101 in BarraganSteven
# Imagen de procesamiento - 102 in BarraganSteven
# Imagen de procesamiento - 103 in BarraganSteven
# Imagen de procesamiento - 104 in BarraganSteven
# Imagen de procesamiento - 105 in BarraganSteven
# Imagen de procesamiento - 106 in BarraganSteven
# Imagen de procesamiento - 107 in BarraganSteven
# Imagen de procesamiento - 108 in BarraganSteven
# Imagen de procesamiento - 109 in BarraganSteven
# Imagen de procesamiento - 110 in BarraganSteven
# Imagen de procesamiento - 111 in BarraganSteven
# Imagen de procesamiento - 112 in BarraganSteven
# Imagen de procesamiento - 113 in BarraganSteven
# Imagen de procesamiento - 114 in BarraganSteven
# Imagen de procesamiento - 115 in BarraganSteven
# Imagen de procesamiento - 116 in BarraganSteven
# Imagen de procesamiento - 117 in BarraganSteven
# Imagen de procesamiento - 118 in BarraganSteven
# Imagen de procesamiento - 119 in BarraganSteven
# Imagen de procesamiento - 120 in BarraganSteven
# Imagen de procesamiento - 121 in BarraganSteven
# Imagen de procesamiento - 122 in BarraganSteven
# Imagen de procesamiento - 123 in BarraganSteven
# Imagen de procesamiento - 124 in BarraganSteven
# Imagen de procesamiento - 125 in BarraganSteven
# Imagen de procesamiento - 126 in BarraganSteven
# Imagen de procesamiento - 127 in BarraganSteven
# Imagen de procesamiento - 128 in BarraganSteven
# Imagen de procesamiento - 129 in BarraganSteven
# Imagen de procesamiento - 130 in BarraganSteven
# Imagen de procesamiento - 131 in BarraganSteven
# Imagen de procesamiento - 132 in BarraganSteven
# Imagen de procesamiento - 133 in BarraganSteven
# Imagen de procesamiento - 134 in BarraganSteven
# Imagen de procesamiento - 135 in BarraganSteven
# Imagen de procesamiento - 136 in BarraganSteven
# Imagen de procesamiento - 137 in BarraganSteven
# Imagen de procesamiento - 138 in BarraganSteven
# Imagen de procesamiento - 139 in BarraganSteven
# Imagen de procesamiento - 140 in BarraganSteven
# Imagen de procesamiento - 1 in CevallosJoan
# Imagen de procesamiento - 2 in CevallosJoan
# Imagen de procesamiento - 3 in CevallosJoan
# Imagen de procesamiento - 4 in CevallosJoan
# Imagen de procesamiento - 5 in CevallosJoan
# Imagen de procesamiento - 6 in CevallosJoan
# Imagen de procesamiento - 7 in CevallosJoan
# Imagen de procesamiento - 8 in CevallosJoan
# Imagen de procesamiento - 9 in CevallosJoan
# Imagen de procesamiento - 10 in CevallosJoan
# Imagen de procesamiento - 11 in CevallosJoan
# Imagen de procesamiento - 12 in CevallosJoan
# Imagen de procesamiento - 13 in CevallosJoan
# Imagen de procesamiento - 14 in CevallosJoan
# Imagen de procesamiento - 15 in CevallosJoan
# Imagen de procesamiento - 16 in CevallosJoan
# Imagen de procesamiento - 17 in CevallosJoan
# Imagen de procesamiento - 18 in CevallosJoan
# Imagen de procesamiento - 19 in CevallosJoan
# Imagen de procesamiento - 20 in CevallosJoan
# Imagen de procesamiento - 21 in CevallosJoan
# Imagen de procesamiento - 22 in CevallosJoan
# Imagen de procesamiento - 23 in CevallosJoan
# Imagen de procesamiento - 24 in CevallosJoan
# Imagen de procesamiento - 25 in CevallosJoan
# Imagen de procesamiento - 26 in CevallosJoan
# Imagen de procesamiento - 27 in CevallosJoan
# Imagen de procesamiento - 28 in CevallosJoan
# Imagen de procesamiento - 29 in CevallosJoan
# Imagen de procesamiento - 30 in CevallosJoan
# Imagen de procesamiento - 31 in CevallosJoan
# Imagen de procesamiento - 32 in CevallosJoan
# Imagen de procesamiento - 33 in CevallosJoan
# Imagen de procesamiento - 34 in CevallosJoan
# Imagen de procesamiento - 35 in CevallosJoan
# Imagen de procesamiento - 36 in CevallosJoan
# Imagen de procesamiento - 37 in CevallosJoan
# Imagen de procesamiento - 38 in CevallosJoan
# Imagen de procesamiento - 39 in CevallosJoan
# Imagen de procesamiento - 40 in CevallosJoan
# Imagen de procesamiento - 41 in CevallosJoan
# Imagen de procesamiento - 42 in CevallosJoan
# Imagen de procesamiento - 43 in CevallosJoan
# Imagen de procesamiento - 44 in CevallosJoan
# Imagen de procesamiento - 45 in CevallosJoan
# Imagen de procesamiento - 46 in CevallosJoan
# Imagen de procesamiento - 47 in CevallosJoan
# Imagen de procesamiento - 48 in CevallosJoan
# Imagen de procesamiento - 49 in CevallosJoan
# Imagen de procesamiento - 50 in CevallosJoan
# Imagen de procesamiento - 51 in CevallosJoan
# Imagen de procesamiento - 52 in CevallosJoan
# Imagen de procesamiento - 53 in CevallosJoan
# Imagen de procesamiento - 54 in CevallosJoan
# Imagen de procesamiento - 55 in CevallosJoan
# Imagen de procesamiento - 56 in CevallosJoan
# Imagen de procesamiento - 57 in CevallosJoan
# Imagen de procesamiento - 58 in CevallosJoan
# Imagen de procesamiento - 59 in CevallosJoan
# Imagen de procesamiento - 60 in CevallosJoan
# Imagen de procesamiento - 61 in CevallosJoan
# Imagen de procesamiento - 62 in CevallosJoan
# Imagen de procesamiento - 63 in CevallosJoan
# Imagen de procesamiento - 64 in CevallosJoan
# Imagen de procesamiento - 65 in CevallosJoan
# Imagen de procesamiento - 66 in CevallosJoan
# Imagen de procesamiento - 67 in CevallosJoan
# Imagen de procesamiento - 68 in CevallosJoan
# Imagen de procesamiento - 69 in CevallosJoan
# Imagen de procesamiento - 70 in CevallosJoan
# Imagen de procesamiento - 71 in CevallosJoan
# Imagen de procesamiento - 72 in CevallosJoan
# Imagen de procesamiento - 73 in CevallosJoan
# Imagen de procesamiento - 74 in CevallosJoan
# Imagen de procesamiento - 75 in CevallosJoan
# Imagen de procesamiento - 76 in CevallosJoan
# Imagen de procesamiento - 77 in CevallosJoan
# Imagen de procesamiento - 78 in CevallosJoan
# Imagen de procesamiento - 79 in CevallosJoan
# Imagen de procesamiento - 80 in CevallosJoan
# Imagen de procesamiento - 81 in CevallosJoan
# Imagen de procesamiento - 82 in CevallosJoan
# Imagen de procesamiento - 83 in CevallosJoan
# Imagen de procesamiento - 84 in CevallosJoan
# Imagen de procesamiento - 85 in CevallosJoan
# Imagen de procesamiento - 86 in CevallosJoan
# Imagen de procesamiento - 87 in CevallosJoan
# Imagen de procesamiento - 88 in CevallosJoan
# Imagen de procesamiento - 89 in CevallosJoan
# Imagen de procesamiento - 90 in CevallosJoan
# Imagen de procesamiento - 1 in EnriquezSelena
# Imagen de procesamiento - 2 in EnriquezSelena
# Imagen de procesamiento - 3 in EnriquezSelena
# Imagen de procesamiento - 4 in EnriquezSelena
# Imagen de procesamiento - 5 in EnriquezSelena
# Imagen de procesamiento - 6 in EnriquezSelena
# Imagen de procesamiento - 7 in EnriquezSelena
# Imagen de procesamiento - 8 in EnriquezSelena
# Imagen de procesamiento - 9 in EnriquezSelena
# Imagen de procesamiento - 10 in EnriquezSelena
# Imagen de procesamiento - 11 in EnriquezSelena
# Imagen de procesamiento - 12 in EnriquezSelena
# Imagen de procesamiento - 13 in EnriquezSelena
# Imagen de procesamiento - 14 in EnriquezSelena
# Imagen de procesamiento - 15 in EnriquezSelena
# Imagen de procesamiento - 16 in EnriquezSelena
# Imagen de procesamiento - 17 in EnriquezSelena
# Imagen de procesamiento - 18 in EnriquezSelena
# Imagen de procesamiento - 19 in EnriquezSelena
# Imagen de procesamiento - 20 in EnriquezSelena
# Imagen de procesamiento - 21 in EnriquezSelena
# Imagen de procesamiento - 22 in EnriquezSelena
# Imagen de procesamiento - 23 in EnriquezSelena
# Imagen de procesamiento - 24 in EnriquezSelena
# Imagen de procesamiento - 25 in EnriquezSelena
# Imagen de procesamiento - 26 in EnriquezSelena
# Imagen de procesamiento - 27 in EnriquezSelena
# Imagen de procesamiento - 28 in EnriquezSelena
# Imagen de procesamiento - 29 in EnriquezSelena
# Imagen de procesamiento - 30 in EnriquezSelena
# Imagen de procesamiento - 31 in EnriquezSelena
# Imagen de procesamiento - 32 in EnriquezSelena
# Imagen de procesamiento - 33 in EnriquezSelena
# Imagen de procesamiento - 34 in EnriquezSelena
# Imagen de procesamiento - 35 in EnriquezSelena
# Imagen de procesamiento - 36 in EnriquezSelena
# Imagen de procesamiento - 37 in EnriquezSelena
# Imagen de procesamiento - 38 in EnriquezSelena
# Imagen de procesamiento - 39 in EnriquezSelena
# Imagen de procesamiento - 40 in EnriquezSelena
# Imagen de procesamiento - 41 in EnriquezSelena
# Imagen de procesamiento - 42 in EnriquezSelena
# Imagen de procesamiento - 43 in EnriquezSelena
# Imagen de procesamiento - 44 in EnriquezSelena
# Imagen de procesamiento - 45 in EnriquezSelena
# Imagen de procesamiento - 46 in EnriquezSelena
# Imagen de procesamiento - 47 in EnriquezSelena
# Imagen de procesamiento - 48 in EnriquezSelena
# Imagen de procesamiento - 49 in EnriquezSelena
# Imagen de procesamiento - 50 in EnriquezSelena
# Imagen de procesamiento - 1 in GenesisHeredia
# Imagen de procesamiento - 2 in GenesisHeredia
# Imagen de procesamiento - 3 in GenesisHeredia
# Imagen de procesamiento - 4 in GenesisHeredia
# Imagen de procesamiento - 5 in GenesisHeredia
# Imagen de procesamiento - 6 in GenesisHeredia
# Imagen de procesamiento - 7 in GenesisHeredia
# Imagen de procesamiento - 8 in GenesisHeredia
# Imagen de procesamiento - 9 in GenesisHeredia
# Imagen de procesamiento - 10 in GenesisHeredia
# Imagen de procesamiento - 11 in GenesisHeredia
# Imagen de procesamiento - 12 in GenesisHeredia
# Imagen de procesamiento - 13 in GenesisHeredia
# Imagen de procesamiento - 14 in GenesisHeredia
# Imagen de procesamiento - 15 in GenesisHeredia
# Imagen de procesamiento - 16 in GenesisHeredia
# Imagen de procesamiento - 17 in GenesisHeredia
# Imagen de procesamiento - 18 in GenesisHeredia
# Imagen de procesamiento - 19 in GenesisHeredia
# Imagen de procesamiento - 20 in GenesisHeredia
# Imagen de procesamiento - 21 in GenesisHeredia
# Imagen de procesamiento - 22 in GenesisHeredia
# Imagen de procesamiento - 23 in GenesisHeredia
# Imagen de procesamiento - 24 in GenesisHeredia
# Imagen de procesamiento - 25 in GenesisHeredia
# Imagen de procesamiento - 26 in GenesisHeredia
# Imagen de procesamiento - 27 in GenesisHeredia
# Imagen de procesamiento - 28 in GenesisHeredia
# Imagen de procesamiento - 29 in GenesisHeredia
# Imagen de procesamiento - 30 in GenesisHeredia
# Imagen de procesamiento - 31 in GenesisHeredia
# Imagen de procesamiento - 32 in GenesisHeredia
# Imagen de procesamiento - 33 in GenesisHeredia
# Imagen de procesamiento - 34 in GenesisHeredia
# Imagen de procesamiento - 35 in GenesisHeredia
# Imagen de procesamiento - 36 in GenesisHeredia
# Imagen de procesamiento - 37 in GenesisHeredia
# Imagen de procesamiento - 38 in GenesisHeredia
# Imagen de procesamiento - 39 in GenesisHeredia
# Imagen de procesamiento - 40 in GenesisHeredia
# Imagen de procesamiento - 41 in GenesisHeredia
# Imagen de procesamiento - 42 in GenesisHeredia
# Imagen de procesamiento - 43 in GenesisHeredia
# Imagen de procesamiento - 44 in GenesisHeredia
# Imagen de procesamiento - 45 in GenesisHeredia
# Imagen de procesamiento - 46 in GenesisHeredia
# Imagen de procesamiento - 47 in GenesisHeredia
# Imagen de procesamiento - 48 in GenesisHeredia
# Imagen de procesamiento - 49 in GenesisHeredia
# Imagen de procesamiento - 50 in GenesisHeredia
# Imagen de procesamiento - 51 in GenesisHeredia
# Imagen de procesamiento - 52 in GenesisHeredia
# Imagen de procesamiento - 53 in GenesisHeredia
# Imagen de procesamiento - 54 in GenesisHeredia
# Imagen de procesamiento - 55 in GenesisHeredia
# Imagen de procesamiento - 56 in GenesisHeredia
# Imagen de procesamiento - 57 in GenesisHeredia
# Imagen de procesamiento - 58 in GenesisHeredia
# Imagen de procesamiento - 59 in GenesisHeredia
# Imagen de procesamiento - 60 in GenesisHeredia
# Imagen de procesamiento - 61 in GenesisHeredia
# Imagen de procesamiento - 62 in GenesisHeredia
# Imagen de procesamiento - 63 in GenesisHeredia
# Imagen de procesamiento - 64 in GenesisHeredia
# Imagen de procesamiento - 65 in GenesisHeredia
# Imagen de procesamiento - 66 in GenesisHeredia
# Imagen de procesamiento - 67 in GenesisHeredia
# Imagen de procesamiento - 68 in GenesisHeredia
# Imagen de procesamiento - 69 in GenesisHeredia
# Imagen de procesamiento - 70 in GenesisHeredia
# Imagen de procesamiento - 71 in GenesisHeredia
# Imagen de procesamiento - 72 in GenesisHeredia
# Imagen de procesamiento - 73 in GenesisHeredia
# Imagen de procesamiento - 74 in GenesisHeredia
# Imagen de procesamiento - 75 in GenesisHeredia
# Imagen de procesamiento - 76 in GenesisHeredia
# Imagen de procesamiento - 77 in GenesisHeredia
# Imagen de procesamiento - 78 in GenesisHeredia
# Imagen de procesamiento - 79 in GenesisHeredia
# Imagen de procesamiento - 80 in GenesisHeredia
# Imagen de procesamiento - 81 in GenesisHeredia
# Imagen de procesamiento - 82 in GenesisHeredia
# Imagen de procesamiento - 83 in GenesisHeredia
# Imagen de procesamiento - 84 in GenesisHeredia
# Imagen de procesamiento - 85 in GenesisHeredia
# Imagen de procesamiento - 86 in GenesisHeredia
# Imagen de procesamiento - 87 in GenesisHeredia
# Imagen de procesamiento - 88 in GenesisHeredia
# Imagen de procesamiento - 89 in GenesisHeredia
# Imagen de procesamiento - 90 in GenesisHeredia
# Imagen de procesamiento - 91 in GenesisHeredia
# Imagen de procesamiento - 92 in GenesisHeredia
# Imagen de procesamiento - 93 in GenesisHeredia
# Imagen de procesamiento - 94 in GenesisHeredia
# Imagen de procesamiento - 95 in GenesisHeredia
# Imagen de procesamiento - 96 in GenesisHeredia
# Imagen de procesamiento - 97 in GenesisHeredia
# Imagen de procesamiento - 98 in GenesisHeredia
# Imagen de procesamiento - 99 in GenesisHeredia
# Imagen de procesamiento - 100 in GenesisHeredia
# Imagen de procesamiento - 1 in GoyesAnthony
# Imagen de procesamiento - 2 in GoyesAnthony
# Imagen de procesamiento - 3 in GoyesAnthony
# Imagen de procesamiento - 4 in GoyesAnthony
# Imagen de procesamiento - 5 in GoyesAnthony
# Imagen de procesamiento - 6 in GoyesAnthony
# Imagen de procesamiento - 7 in GoyesAnthony
# Imagen de procesamiento - 8 in GoyesAnthony
# Imagen de procesamiento - 9 in GoyesAnthony
# Imagen de procesamiento - 10 in GoyesAnthony
# Imagen de procesamiento - 11 in GoyesAnthony
# Imagen de procesamiento - 12 in GoyesAnthony
# Imagen de procesamiento - 13 in GoyesAnthony
# Imagen de procesamiento - 14 in GoyesAnthony
# Imagen de procesamiento - 15 in GoyesAnthony
# Imagen de procesamiento - 16 in GoyesAnthony
# Imagen de procesamiento - 17 in GoyesAnthony
# Imagen de procesamiento - 18 in GoyesAnthony
# Imagen de procesamiento - 19 in GoyesAnthony
# Imagen de procesamiento - 20 in GoyesAnthony
# Imagen de procesamiento - 21 in GoyesAnthony
# Imagen de procesamiento - 22 in GoyesAnthony
# Imagen de procesamiento - 23 in GoyesAnthony
# Imagen de procesamiento - 24 in GoyesAnthony
# Imagen de procesamiento - 25 in GoyesAnthony
# Imagen de procesamiento - 26 in GoyesAnthony
# Imagen de procesamiento - 27 in GoyesAnthony
# Imagen de procesamiento - 28 in GoyesAnthony
# Imagen de procesamiento - 29 in GoyesAnthony
# Imagen de procesamiento - 30 in GoyesAnthony
# Imagen de procesamiento - 31 in GoyesAnthony
# Imagen de procesamiento - 32 in GoyesAnthony
# Imagen de procesamiento - 33 in GoyesAnthony
# Imagen de procesamiento - 34 in GoyesAnthony
# Imagen de procesamiento - 35 in GoyesAnthony
# Imagen de procesamiento - 36 in GoyesAnthony
# Imagen de procesamiento - 37 in GoyesAnthony
# Imagen de procesamiento - 38 in GoyesAnthony
# Imagen de procesamiento - 39 in GoyesAnthony
# Imagen de procesamiento - 40 in GoyesAnthony
# Imagen de procesamiento - 41 in GoyesAnthony
# Imagen de procesamiento - 42 in GoyesAnthony
# Imagen de procesamiento - 43 in GoyesAnthony
# Imagen de procesamiento - 44 in GoyesAnthony
# Imagen de procesamiento - 45 in GoyesAnthony
# Imagen de procesamiento - 46 in GoyesAnthony
# Imagen de procesamiento - 47 in GoyesAnthony
# Imagen de procesamiento - 48 in GoyesAnthony
# Imagen de procesamiento - 49 in GoyesAnthony
# Imagen de procesamiento - 50 in GoyesAnthony
# Imagen de procesamiento - 51 in GoyesAnthony
# Imagen de procesamiento - 52 in GoyesAnthony
# Imagen de procesamiento - 53 in GoyesAnthony
# Imagen de procesamiento - 54 in GoyesAnthony
# Imagen de procesamiento - 55 in GoyesAnthony
# Imagen de procesamiento - 56 in GoyesAnthony
# Imagen de procesamiento - 57 in GoyesAnthony
# Imagen de procesamiento - 58 in GoyesAnthony
# Imagen de procesamiento - 59 in GoyesAnthony
# Imagen de procesamiento - 60 in GoyesAnthony
# Imagen de procesamiento - 61 in GoyesAnthony
# Imagen de procesamiento - 62 in GoyesAnthony
# Imagen de procesamiento - 63 in GoyesAnthony
# Imagen de procesamiento - 64 in GoyesAnthony
# Imagen de procesamiento - 65 in GoyesAnthony
# Imagen de procesamiento - 66 in GoyesAnthony
# Imagen de procesamiento - 67 in GoyesAnthony
# Imagen de procesamiento - 68 in GoyesAnthony
# Imagen de procesamiento - 69 in GoyesAnthony
# Imagen de procesamiento - 70 in GoyesAnthony
# Imagen de procesamiento - 71 in GoyesAnthony
# Imagen de procesamiento - 72 in GoyesAnthony
# Imagen de procesamiento - 73 in GoyesAnthony
# Imagen de procesamiento - 74 in GoyesAnthony
# Imagen de procesamiento - 75 in GoyesAnthony
# Imagen de procesamiento - 76 in GoyesAnthony
# Imagen de procesamiento - 77 in GoyesAnthony
# Imagen de procesamiento - 78 in GoyesAnthony
# Imagen de procesamiento - 79 in GoyesAnthony
# Imagen de procesamiento - 80 in GoyesAnthony
# Imagen de procesamiento - 81 in GoyesAnthony
# Imagen de procesamiento - 82 in GoyesAnthony
# Imagen de procesamiento - 83 in GoyesAnthony
# Imagen de procesamiento - 84 in GoyesAnthony
# Imagen de procesamiento - 85 in GoyesAnthony
# Imagen de procesamiento - 86 in GoyesAnthony
# Imagen de procesamiento - 87 in GoyesAnthony
# Imagen de procesamiento - 88 in GoyesAnthony
# Imagen de procesamiento - 89 in GoyesAnthony
# Imagen de procesamiento - 90 in GoyesAnthony
# Imagen de procesamiento - 91 in GoyesAnthony
# Imagen de procesamiento - 92 in GoyesAnthony
# Imagen de procesamiento - 93 in GoyesAnthony
# Imagen de procesamiento - 94 in GoyesAnthony
# Imagen de procesamiento - 95 in GoyesAnthony
# Imagen de procesamiento - 96 in GoyesAnthony
# Imagen de procesamiento - 97 in GoyesAnthony
# Imagen de procesamiento - 98 in GoyesAnthony
# Imagen de procesamiento - 99 in GoyesAnthony
# Imagen de procesamiento - 1 in HectorCedeno
# Imagen de procesamiento - 2 in HectorCedeno
# Imagen de procesamiento - 3 in HectorCedeno
# Imagen de procesamiento - 4 in HectorCedeno
# Imagen de procesamiento - 5 in HectorCedeno
# Imagen de procesamiento - 6 in HectorCedeno
# Imagen de procesamiento - 7 in HectorCedeno
# Imagen de procesamiento - 8 in HectorCedeno
# Imagen de procesamiento - 9 in HectorCedeno
# Imagen de procesamiento - 10 in HectorCedeno
# Imagen de procesamiento - 11 in HectorCedeno
# Imagen de procesamiento - 12 in HectorCedeno
# Imagen de procesamiento - 13 in HectorCedeno
# Imagen de procesamiento - 14 in HectorCedeno
# Imagen de procesamiento - 15 in HectorCedeno
# Imagen de procesamiento - 16 in HectorCedeno
# Imagen de procesamiento - 17 in HectorCedeno
# Imagen de procesamiento - 18 in HectorCedeno
# Imagen de procesamiento - 19 in HectorCedeno
# Imagen de procesamiento - 20 in HectorCedeno
# Imagen de procesamiento - 21 in HectorCedeno
# Imagen de procesamiento - 22 in HectorCedeno
# Imagen de procesamiento - 23 in HectorCedeno
# Imagen de procesamiento - 24 in HectorCedeno
# Imagen de procesamiento - 25 in HectorCedeno
# Imagen de procesamiento - 26 in HectorCedeno
# Imagen de procesamiento - 27 in HectorCedeno
# Imagen de procesamiento - 28 in HectorCedeno
# Imagen de procesamiento - 29 in HectorCedeno
# Imagen de procesamiento - 30 in HectorCedeno
# Imagen de procesamiento - 31 in HectorCedeno
# Imagen de procesamiento - 32 in HectorCedeno
# Imagen de procesamiento - 33 in HectorCedeno
# Imagen de procesamiento - 34 in HectorCedeno
# Imagen de procesamiento - 35 in HectorCedeno
# Imagen de procesamiento - 36 in HectorCedeno
# Imagen de procesamiento - 37 in HectorCedeno
# Imagen de procesamiento - 38 in HectorCedeno
# Imagen de procesamiento - 39 in HectorCedeno
# Imagen de procesamiento - 40 in HectorCedeno
# Imagen de procesamiento - 41 in HectorCedeno
# Imagen de procesamiento - 42 in HectorCedeno
# Imagen de procesamiento - 43 in HectorCedeno
# Imagen de procesamiento - 44 in HectorCedeno
# Imagen de procesamiento - 45 in HectorCedeno
# Imagen de procesamiento - 46 in HectorCedeno
# Imagen de procesamiento - 47 in HectorCedeno
# Imagen de procesamiento - 48 in HectorCedeno
# Imagen de procesamiento - 49 in HectorCedeno
# Imagen de procesamiento - 50 in HectorCedeno
# Imagen de procesamiento - 51 in HectorCedeno
# Imagen de procesamiento - 52 in HectorCedeno
# Imagen de procesamiento - 53 in HectorCedeno
# Imagen de procesamiento - 54 in HectorCedeno
# Imagen de procesamiento - 55 in HectorCedeno
# Imagen de procesamiento - 56 in HectorCedeno
# Imagen de procesamiento - 57 in HectorCedeno
# Imagen de procesamiento - 58 in HectorCedeno
# Imagen de procesamiento - 59 in HectorCedeno
# Imagen de procesamiento - 60 in HectorCedeno
# Imagen de procesamiento - 61 in HectorCedeno
# Imagen de procesamiento - 62 in HectorCedeno
# Imagen de procesamiento - 63 in HectorCedeno
# Imagen de procesamiento - 64 in HectorCedeno
# Imagen de procesamiento - 65 in HectorCedeno
# Imagen de procesamiento - 66 in HectorCedeno
# Imagen de procesamiento - 67 in HectorCedeno
# Imagen de procesamiento - 68 in HectorCedeno
# Imagen de procesamiento - 69 in HectorCedeno
# Imagen de procesamiento - 70 in HectorCedeno
# Imagen de procesamiento - 71 in HectorCedeno
# Imagen de procesamiento - 72 in HectorCedeno
# Imagen de procesamiento - 73 in HectorCedeno
# Imagen de procesamiento - 74 in HectorCedeno
# Imagen de procesamiento - 75 in HectorCedeno
# Imagen de procesamiento - 76 in HectorCedeno
# Imagen de procesamiento - 77 in HectorCedeno
# Imagen de procesamiento - 78 in HectorCedeno
# Imagen de procesamiento - 79 in HectorCedeno
# Imagen de procesamiento - 80 in HectorCedeno
# Imagen de procesamiento - 81 in HectorCedeno
# Imagen de procesamiento - 82 in HectorCedeno
# Imagen de procesamiento - 83 in HectorCedeno
# Imagen de procesamiento - 84 in HectorCedeno
# Imagen de procesamiento - 85 in HectorCedeno
# Imagen de procesamiento - 86 in HectorCedeno
# Imagen de procesamiento - 87 in HectorCedeno
# Imagen de procesamiento - 88 in HectorCedeno
# Imagen de procesamiento - 89 in HectorCedeno
# Imagen de procesamiento - 90 in HectorCedeno
# Imagen de procesamiento - 91 in HectorCedeno
# Imagen de procesamiento - 92 in HectorCedeno
# Imagen de procesamiento - 93 in HectorCedeno
# Imagen de procesamiento - 94 in HectorCedeno
# Imagen de procesamiento - 95 in HectorCedeno
# Imagen de procesamiento - 96 in HectorCedeno
# Imagen de procesamiento - 97 in HectorCedeno
# Imagen de procesamiento - 98 in HectorCedeno
# Imagen de procesamiento - 99 in HectorCedeno
# Imagen de procesamiento - 100 in HectorCedeno
# Imagen de procesamiento - 1 in Jhon Zambrano
# Imagen de procesamiento - 2 in Jhon Zambrano
# Imagen de procesamiento - 3 in Jhon Zambrano
# Imagen de procesamiento - 4 in Jhon Zambrano
# Imagen de procesamiento - 5 in Jhon Zambrano
# Imagen de procesamiento - 6 in Jhon Zambrano
# Imagen de procesamiento - 7 in Jhon Zambrano
# Imagen de procesamiento - 8 in Jhon Zambrano
# Imagen de procesamiento - 9 in Jhon Zambrano
# Imagen de procesamiento - 10 in Jhon Zambrano
# Imagen de procesamiento - 11 in Jhon Zambrano
# Imagen de procesamiento - 12 in Jhon Zambrano
# Imagen de procesamiento - 13 in Jhon Zambrano
# Imagen de procesamiento - 14 in Jhon Zambrano
# Imagen de procesamiento - 15 in Jhon Zambrano
# Imagen de procesamiento - 16 in Jhon Zambrano
# Imagen de procesamiento - 17 in Jhon Zambrano
# Imagen de procesamiento - 18 in Jhon Zambrano
# Imagen de procesamiento - 19 in Jhon Zambrano
# Imagen de procesamiento - 20 in Jhon Zambrano
# Imagen de procesamiento - 21 in Jhon Zambrano
# Imagen de procesamiento - 22 in Jhon Zambrano
# Imagen de procesamiento - 23 in Jhon Zambrano
# Imagen de procesamiento - 24 in Jhon Zambrano
# Imagen de procesamiento - 25 in Jhon Zambrano
# Imagen de procesamiento - 26 in Jhon Zambrano
# Imagen de procesamiento - 27 in Jhon Zambrano
# Imagen de procesamiento - 28 in Jhon Zambrano
# Imagen de procesamiento - 29 in Jhon Zambrano
# Imagen de procesamiento - 30 in Jhon Zambrano
# Imagen de procesamiento - 31 in Jhon Zambrano
# Imagen de procesamiento - 32 in Jhon Zambrano
# Imagen de procesamiento - 33 in Jhon Zambrano
# Imagen de procesamiento - 34 in Jhon Zambrano
# Imagen de procesamiento - 35 in Jhon Zambrano
# Imagen de procesamiento - 36 in Jhon Zambrano
# Imagen de procesamiento - 37 in Jhon Zambrano
# Imagen de procesamiento - 38 in Jhon Zambrano
# Imagen de procesamiento - 39 in Jhon Zambrano
# Imagen de procesamiento - 40 in Jhon Zambrano
# Imagen de procesamiento - 41 in Jhon Zambrano
# Imagen de procesamiento - 42 in Jhon Zambrano
# Imagen de procesamiento - 43 in Jhon Zambrano
# Imagen de procesamiento - 44 in Jhon Zambrano
# Imagen de procesamiento - 45 in Jhon Zambrano
# Imagen de procesamiento - 46 in Jhon Zambrano
# Imagen de procesamiento - 47 in Jhon Zambrano
# Imagen de procesamiento - 48 in Jhon Zambrano
# Imagen de procesamiento - 49 in Jhon Zambrano
# Imagen de procesamiento - 50 in Jhon Zambrano
# Imagen de procesamiento - 51 in Jhon Zambrano
# Imagen de procesamiento - 52 in Jhon Zambrano
# Imagen de procesamiento - 53 in Jhon Zambrano
# Imagen de procesamiento - 54 in Jhon Zambrano
# Imagen de procesamiento - 55 in Jhon Zambrano
# Imagen de procesamiento - 56 in Jhon Zambrano
# Imagen de procesamiento - 57 in Jhon Zambrano
# Imagen de procesamiento - 58 in Jhon Zambrano
# Imagen de procesamiento - 59 in Jhon Zambrano
# Imagen de procesamiento - 60 in Jhon Zambrano
# Imagen de procesamiento - 61 in Jhon Zambrano
# Imagen de procesamiento - 62 in Jhon Zambrano
# Imagen de procesamiento - 63 in Jhon Zambrano
# Imagen de procesamiento - 64 in Jhon Zambrano
# Imagen de procesamiento - 65 in Jhon Zambrano
# Imagen de procesamiento - 66 in Jhon Zambrano
# Imagen de procesamiento - 67 in Jhon Zambrano
# Imagen de procesamiento - 68 in Jhon Zambrano
# Imagen de procesamiento - 69 in Jhon Zambrano
# Imagen de procesamiento - 70 in Jhon Zambrano
# Imagen de procesamiento - 71 in Jhon Zambrano
# Imagen de procesamiento - 72 in Jhon Zambrano
# Imagen de procesamiento - 73 in Jhon Zambrano
# Imagen de procesamiento - 74 in Jhon Zambrano
# Imagen de procesamiento - 75 in Jhon Zambrano
# Imagen de procesamiento - 76 in Jhon Zambrano
# Imagen de procesamiento - 77 in Jhon Zambrano
# Imagen de procesamiento - 78 in Jhon Zambrano
# Imagen de procesamiento - 79 in Jhon Zambrano
# Imagen de procesamiento - 80 in Jhon Zambrano
# Imagen de procesamiento - 81 in Jhon Zambrano
# Imagen de procesamiento - 82 in Jhon Zambrano
# Imagen de procesamiento - 83 in Jhon Zambrano
# Imagen de procesamiento - 84 in Jhon Zambrano
# Imagen de procesamiento - 85 in Jhon Zambrano
# Imagen de procesamiento - 86 in Jhon Zambrano
# Imagen de procesamiento - 87 in Jhon Zambrano
# Imagen de procesamiento - 88 in Jhon Zambrano
# Imagen de procesamiento - 89 in Jhon Zambrano
# Imagen de procesamiento - 90 in Jhon Zambrano
# Imagen de procesamiento - 91 in Jhon Zambrano
# Imagen de procesamiento - 92 in Jhon Zambrano
# Imagen de procesamiento - 93 in Jhon Zambrano
# Imagen de procesamiento - 94 in Jhon Zambrano
# Imagen de procesamiento - 95 in Jhon Zambrano
# Imagen de procesamiento - 96 in Jhon Zambrano
# Imagen de procesamiento - 97 in Jhon Zambrano
# Imagen de procesamiento - 98 in Jhon Zambrano
# Imagen de procesamiento - 99 in Jhon Zambrano
# Imagen de procesamiento - 100 in Jhon Zambrano
# Imagen de procesamiento - 101 in Jhon Zambrano
# Imagen de procesamiento - 102 in Jhon Zambrano
# Imagen de procesamiento - 103 in Jhon Zambrano
# Imagen de procesamiento - 104 in Jhon Zambrano
# Imagen de procesamiento - 105 in Jhon Zambrano
# Imagen de procesamiento - 106 in Jhon Zambrano
# Imagen de procesamiento - 107 in Jhon Zambrano
# Imagen de procesamiento - 108 in Jhon Zambrano
# Imagen de procesamiento - 109 in Jhon Zambrano
# Imagen de procesamiento - 110 in Jhon Zambrano
# Imagen de procesamiento - 111 in Jhon Zambrano
# Imagen de procesamiento - 112 in Jhon Zambrano
# Imagen de procesamiento - 113 in Jhon Zambrano
# Imagen de procesamiento - 114 in Jhon Zambrano
# Imagen de procesamiento - 115 in Jhon Zambrano
# Imagen de procesamiento - 116 in Jhon Zambrano
# Imagen de procesamiento - 117 in Jhon Zambrano
# Imagen de procesamiento - 118 in Jhon Zambrano
# Imagen de procesamiento - 119 in Jhon Zambrano
# Imagen de procesamiento - 120 in Jhon Zambrano
# Imagen de procesamiento - 121 in Jhon Zambrano
# Imagen de procesamiento - 122 in Jhon Zambrano
# Imagen de procesamiento - 123 in Jhon Zambrano
# Imagen de procesamiento - 124 in Jhon Zambrano
# Imagen de procesamiento - 125 in Jhon Zambrano
# Imagen de procesamiento - 126 in Jhon Zambrano
# Imagen de procesamiento - 127 in Jhon Zambrano
# Imagen de procesamiento - 128 in Jhon Zambrano
# Imagen de procesamiento - 129 in Jhon Zambrano
# Imagen de procesamiento - 130 in Jhon Zambrano
# Imagen de procesamiento - 1 in Jordan Espinosa
# Imagen de procesamiento - 2 in Jordan Espinosa
# Imagen de procesamiento - 3 in Jordan Espinosa
# Imagen de procesamiento - 4 in Jordan Espinosa
# Imagen de procesamiento - 5 in Jordan Espinosa
# Imagen de procesamiento - 6 in Jordan Espinosa
# Imagen de procesamiento - 7 in Jordan Espinosa
# Imagen de procesamiento - 8 in Jordan Espinosa
# Imagen de procesamiento - 9 in Jordan Espinosa
# Imagen de procesamiento - 10 in Jordan Espinosa
# Imagen de procesamiento - 11 in Jordan Espinosa
# Imagen de procesamiento - 12 in Jordan Espinosa
# Imagen de procesamiento - 13 in Jordan Espinosa
# Imagen de procesamiento - 14 in Jordan Espinosa
# Imagen de procesamiento - 15 in Jordan Espinosa
# Imagen de procesamiento - 16 in Jordan Espinosa
# Imagen de procesamiento - 17 in Jordan Espinosa
# Imagen de procesamiento - 18 in Jordan Espinosa
# Imagen de procesamiento - 19 in Jordan Espinosa
# Imagen de procesamiento - 20 in Jordan Espinosa
# Imagen de procesamiento - 21 in Jordan Espinosa
# Imagen de procesamiento - 22 in Jordan Espinosa
# Imagen de procesamiento - 23 in Jordan Espinosa
# Imagen de procesamiento - 24 in Jordan Espinosa
# Imagen de procesamiento - 25 in Jordan Espinosa
# Imagen de procesamiento - 26 in Jordan Espinosa
# Imagen de procesamiento - 27 in Jordan Espinosa
# Imagen de procesamiento - 28 in Jordan Espinosa
# Imagen de procesamiento - 29 in Jordan Espinosa
# Imagen de procesamiento - 30 in Jordan Espinosa
# Imagen de procesamiento - 31 in Jordan Espinosa
# Imagen de procesamiento - 32 in Jordan Espinosa
# Imagen de procesamiento - 33 in Jordan Espinosa
# Imagen de procesamiento - 34 in Jordan Espinosa
# Imagen de procesamiento - 35 in Jordan Espinosa
# Imagen de procesamiento - 36 in Jordan Espinosa
# Imagen de procesamiento - 37 in Jordan Espinosa
# Imagen de procesamiento - 38 in Jordan Espinosa
# Imagen de procesamiento - 39 in Jordan Espinosa
# Imagen de procesamiento - 40 in Jordan Espinosa
# Imagen de procesamiento - 41 in Jordan Espinosa
# Imagen de procesamiento - 42 in Jordan Espinosa
# Imagen de procesamiento - 43 in Jordan Espinosa
# Imagen de procesamiento - 44 in Jordan Espinosa
# Imagen de procesamiento - 45 in Jordan Espinosa
# Imagen de procesamiento - 46 in Jordan Espinosa
# Imagen de procesamiento - 47 in Jordan Espinosa
# Imagen de procesamiento - 48 in Jordan Espinosa
# Imagen de procesamiento - 49 in Jordan Espinosa
# Imagen de procesamiento - 50 in Jordan Espinosa
# Imagen de procesamiento - 51 in Jordan Espinosa
# Imagen de procesamiento - 52 in Jordan Espinosa
# Imagen de procesamiento - 53 in Jordan Espinosa
# Imagen de procesamiento - 54 in Jordan Espinosa
# Imagen de procesamiento - 55 in Jordan Espinosa
# Imagen de procesamiento - 56 in Jordan Espinosa
# Imagen de procesamiento - 57 in Jordan Espinosa
# Imagen de procesamiento - 58 in Jordan Espinosa
# Imagen de procesamiento - 59 in Jordan Espinosa
# Imagen de procesamiento - 60 in Jordan Espinosa
# Imagen de procesamiento - 61 in Jordan Espinosa
# Imagen de procesamiento - 62 in Jordan Espinosa
# Imagen de procesamiento - 63 in Jordan Espinosa
# Imagen de procesamiento - 64 in Jordan Espinosa
# Imagen de procesamiento - 65 in Jordan Espinosa
# Imagen de procesamiento - 66 in Jordan Espinosa
# Imagen de procesamiento - 67 in Jordan Espinosa
# Imagen de procesamiento - 68 in Jordan Espinosa
# Imagen de procesamiento - 69 in Jordan Espinosa
# Imagen de procesamiento - 70 in Jordan Espinosa
# Imagen de procesamiento - 71 in Jordan Espinosa
# Imagen de procesamiento - 72 in Jordan Espinosa
# Imagen de procesamiento - 73 in Jordan Espinosa
# Imagen de procesamiento - 74 in Jordan Espinosa
# Imagen de procesamiento - 75 in Jordan Espinosa
# Imagen de procesamiento - 76 in Jordan Espinosa
# Imagen de procesamiento - 77 in Jordan Espinosa
# Imagen de procesamiento - 78 in Jordan Espinosa
# Imagen de procesamiento - 79 in Jordan Espinosa
# Imagen de procesamiento - 80 in Jordan Espinosa
# Imagen de procesamiento - 1 in Jorge Borrero
# Imagen de procesamiento - 2 in Jorge Borrero
# Imagen de procesamiento - 3 in Jorge Borrero
# Imagen de procesamiento - 4 in Jorge Borrero
# Imagen de procesamiento - 5 in Jorge Borrero
# Imagen de procesamiento - 6 in Jorge Borrero
# Imagen de procesamiento - 7 in Jorge Borrero
# Imagen de procesamiento - 8 in Jorge Borrero
# Imagen de procesamiento - 9 in Jorge Borrero
# Imagen de procesamiento - 10 in Jorge Borrero
# Imagen de procesamiento - 11 in Jorge Borrero
# Imagen de procesamiento - 12 in Jorge Borrero
# Imagen de procesamiento - 13 in Jorge Borrero
# Imagen de procesamiento - 14 in Jorge Borrero
# Imagen de procesamiento - 15 in Jorge Borrero
# Imagen de procesamiento - 16 in Jorge Borrero
# Imagen de procesamiento - 17 in Jorge Borrero
# Imagen de procesamiento - 18 in Jorge Borrero
# Imagen de procesamiento - 19 in Jorge Borrero
# Imagen de procesamiento - 20 in Jorge Borrero
# Imagen de procesamiento - 21 in Jorge Borrero
# Imagen de procesamiento - 22 in Jorge Borrero
# Imagen de procesamiento - 23 in Jorge Borrero
# Imagen de procesamiento - 24 in Jorge Borrero
# Imagen de procesamiento - 25 in Jorge Borrero
# Imagen de procesamiento - 26 in Jorge Borrero
# Imagen de procesamiento - 27 in Jorge Borrero
# Imagen de procesamiento - 28 in Jorge Borrero
# Imagen de procesamiento - 29 in Jorge Borrero
# Imagen de procesamiento - 30 in Jorge Borrero
# Imagen de procesamiento - 1 in JoseRuiz
# Imagen de procesamiento - 2 in JoseRuiz
# Imagen de procesamiento - 3 in JoseRuiz
# Imagen de procesamiento - 4 in JoseRuiz
# Imagen de procesamiento - 5 in JoseRuiz
# Imagen de procesamiento - 6 in JoseRuiz
# Imagen de procesamiento - 7 in JoseRuiz
# Imagen de procesamiento - 8 in JoseRuiz
# Imagen de procesamiento - 9 in JoseRuiz
# Imagen de procesamiento - 10 in JoseRuiz
# Imagen de procesamiento - 11 in JoseRuiz
# Imagen de procesamiento - 12 in JoseRuiz
# Imagen de procesamiento - 13 in JoseRuiz
# Imagen de procesamiento - 14 in JoseRuiz
# Imagen de procesamiento - 15 in JoseRuiz
# Imagen de procesamiento - 16 in JoseRuiz
# Imagen de procesamiento - 17 in JoseRuiz
# Imagen de procesamiento - 18 in JoseRuiz
# Imagen de procesamiento - 19 in JoseRuiz
# Imagen de procesamiento - 20 in JoseRuiz
# Imagen de procesamiento - 21 in JoseRuiz
# Imagen de procesamiento - 22 in JoseRuiz
# Imagen de procesamiento - 23 in JoseRuiz
# Imagen de procesamiento - 24 in JoseRuiz
# Imagen de procesamiento - 25 in JoseRuiz
# Imagen de procesamiento - 26 in JoseRuiz
# Imagen de procesamiento - 27 in JoseRuiz
# Imagen de procesamiento - 28 in JoseRuiz
# Imagen de procesamiento - 29 in JoseRuiz
# Imagen de procesamiento - 30 in JoseRuiz
# Imagen de procesamiento - 31 in JoseRuiz
# Imagen de procesamiento - 32 in JoseRuiz
# Imagen de procesamiento - 33 in JoseRuiz
# Imagen de procesamiento - 34 in JoseRuiz
# Imagen de procesamiento - 35 in JoseRuiz
# Imagen de procesamiento - 36 in JoseRuiz
# Imagen de procesamiento - 37 in JoseRuiz
# Imagen de procesamiento - 38 in JoseRuiz
# Imagen de procesamiento - 39 in JoseRuiz
# Imagen de procesamiento - 40 in JoseRuiz
# Imagen de procesamiento - 41 in JoseRuiz
# Imagen de procesamiento - 42 in JoseRuiz
# Imagen de procesamiento - 43 in JoseRuiz
# Imagen de procesamiento - 44 in JoseRuiz
# Imagen de procesamiento - 45 in JoseRuiz
# Imagen de procesamiento - 46 in JoseRuiz
# Imagen de procesamiento - 47 in JoseRuiz
# Imagen de procesamiento - 48 in JoseRuiz
# Imagen de procesamiento - 49 in JoseRuiz
# Imagen de procesamiento - 50 in JoseRuiz
# Imagen de procesamiento - 51 in JoseRuiz
# Imagen de procesamiento - 52 in JoseRuiz
# Imagen de procesamiento - 53 in JoseRuiz
# Imagen de procesamiento - 54 in JoseRuiz
# Imagen de procesamiento - 55 in JoseRuiz
# Imagen de procesamiento - 56 in JoseRuiz
# Imagen de procesamiento - 57 in JoseRuiz
# Imagen de procesamiento - 58 in JoseRuiz
# Imagen de procesamiento - 59 in JoseRuiz
# Imagen de procesamiento - 60 in JoseRuiz
# Imagen de procesamiento - 61 in JoseRuiz
# Imagen de procesamiento - 62 in JoseRuiz
# Imagen de procesamiento - 63 in JoseRuiz
# Imagen de procesamiento - 64 in JoseRuiz
# Imagen de procesamiento - 65 in JoseRuiz
# Imagen de procesamiento - 66 in JoseRuiz
# Imagen de procesamiento - 67 in JoseRuiz
# Imagen de procesamiento - 68 in JoseRuiz
# Imagen de procesamiento - 69 in JoseRuiz
# Imagen de procesamiento - 70 in JoseRuiz
# Imagen de procesamiento - 71 in JoseRuiz
# Imagen de procesamiento - 72 in JoseRuiz
# Imagen de procesamiento - 73 in JoseRuiz
# Imagen de procesamiento - 74 in JoseRuiz
# Imagen de procesamiento - 75 in JoseRuiz
# Imagen de procesamiento - 76 in JoseRuiz
# ...
# Imagen de procesamiento - 78 in RivasSelena
# Imagen de procesamiento - 79 in RivasSelena
# Imagen de procesamiento - 80 in RivasSelena
# Imagen de procesamiento - 81 in RivasSelena
# Imagen de procesamiento - 82 in RivasSelena
# Imagen de procesamiento - 83 in RivasSelena
# Imagen de procesamiento - 84 in RivasSelena
# Imagen de procesamiento - 85 in RivasSelena
# Imagen de procesamiento - 86 in RivasSelena
# Imagen de procesamiento - 87 in RivasSelena
# Imagen de procesamiento - 88 in RivasSelena
# Imagen de procesamiento - 89 in RivasSelena
# Imagen de procesamiento - 90 in RivasSelena
# Imagen de procesamiento - 91 in RivasSelena
# Imagen de procesamiento - 92 in RivasSelena
# Imagen de procesamiento - 93 in RivasSelena
# Imagen de procesamiento - 94 in RivasSelena
# Imagen de procesamiento - 95 in RivasSelena
# Imagen de procesamiento - 96 in RivasSelena
# Imagen de procesamiento - 97 in RivasSelena
# Imagen de procesamiento - 98 in RivasSelena
# Imagen de procesamiento - 99 in RivasSelena
# Imagen de procesamiento - 100 in RivasSelena
# Imagen de procesamiento - 101 in RivasSelena
# Imagen de procesamiento - 102 in RivasSelena
# Imagen de procesamiento - 103 in RivasSelena
# Imagen de procesamiento - 104 in RivasSelena
# Imagen de procesamiento - 105 in RivasSelena
# Imagen de procesamiento - 106 in RivasSelena
# Imagen de procesamiento - 107 in RivasSelena
# Imagen de procesamiento - 108 in RivasSelena
# Imagen de procesamiento - 109 in RivasSelena
# Imagen de procesamiento - 1 in SalazarJohana
# Imagen de procesamiento - 2 in SalazarJohana
# Imagen de procesamiento - 3 in SalazarJohana
# Imagen de procesamiento - 4 in SalazarJohana
# Imagen de procesamiento - 5 in SalazarJohana
# Imagen de procesamiento - 6 in SalazarJohana
# Imagen de procesamiento - 7 in SalazarJohana
# Imagen de procesamiento - 8 in SalazarJohana
# Imagen de procesamiento - 9 in SalazarJohana
# Imagen de procesamiento - 10 in SalazarJohana
# Imagen de procesamiento - 11 in SalazarJohana
# Imagen de procesamiento - 12 in SalazarJohana
# Imagen de procesamiento - 13 in SalazarJohana
# Imagen de procesamiento - 14 in SalazarJohana
# Imagen de procesamiento - 15 in SalazarJohana
# Imagen de procesamiento - 16 in SalazarJohana
# Imagen de procesamiento - 17 in SalazarJohana
# Imagen de procesamiento - 18 in SalazarJohana
# Imagen de procesamiento - 19 in SalazarJohana
# Imagen de procesamiento - 20 in SalazarJohana
# Imagen de procesamiento - 21 in SalazarJohana
# Imagen de procesamiento - 22 in SalazarJohana
# Imagen de procesamiento - 23 in SalazarJohana
# Imagen de procesamiento - 24 in SalazarJohana
# Imagen de procesamiento - 25 in SalazarJohana
# Imagen de procesamiento - 26 in SalazarJohana
# Imagen de procesamiento - 27 in SalazarJohana
# Imagen de procesamiento - 28 in SalazarJohana
# Imagen de procesamiento - 29 in SalazarJohana
# Imagen de procesamiento - 30 in SalazarJohana
# Imagen de procesamiento - 31 in SalazarJohana
# Imagen de procesamiento - 32 in SalazarJohana
# Imagen de procesamiento - 33 in SalazarJohana
# Imagen de procesamiento - 34 in SalazarJohana
# Imagen de procesamiento - 35 in SalazarJohana
# Imagen de procesamiento - 36 in SalazarJohana
# Imagen de procesamiento - 37 in SalazarJohana
# Imagen de procesamiento - 38 in SalazarJohana
# Imagen de procesamiento - 39 in SalazarJohana
# Imagen de procesamiento - 40 in SalazarJohana
# Imagen de procesamiento - 41 in SalazarJohana
# Imagen de procesamiento - 42 in SalazarJohana
# Imagen de procesamiento - 43 in SalazarJohana
# Imagen de procesamiento - 44 in SalazarJohana
# Imagen de procesamiento - 45 in SalazarJohana
# Imagen de procesamiento - 46 in SalazarJohana
# Imagen de procesamiento - 47 in SalazarJohana
# Imagen de procesamiento - 48 in SalazarJohana
# Imagen de procesamiento - 49 in SalazarJohana
# Imagen de procesamiento - 50 in SalazarJohana
# Imagen de procesamiento - 1 in Solano Wilmer
# Imagen de procesamiento - 2 in Solano Wilmer
# Imagen de procesamiento - 3 in Solano Wilmer
# Imagen de procesamiento - 4 in Solano Wilmer
# Imagen de procesamiento - 5 in Solano Wilmer
# Imagen de procesamiento - 6 in Solano Wilmer
# Imagen de procesamiento - 7 in Solano Wilmer
# Imagen de procesamiento - 8 in Solano Wilmer
# Imagen de procesamiento - 9 in Solano Wilmer
# Imagen de procesamiento - 10 in Solano Wilmer
# Imagen de procesamiento - 11 in Solano Wilmer
# Imagen de procesamiento - 12 in Solano Wilmer
# Imagen de procesamiento - 13 in Solano Wilmer
# Imagen de procesamiento - 14 in Solano Wilmer
# Imagen de procesamiento - 15 in Solano Wilmer
# Imagen de procesamiento - 16 in Solano Wilmer
# Imagen de procesamiento - 17 in Solano Wilmer
# Imagen de procesamiento - 18 in Solano Wilmer
# Imagen de procesamiento - 19 in Solano Wilmer
# Imagen de procesamiento - 20 in Solano Wilmer
# Imagen de procesamiento - 21 in Solano Wilmer
# Imagen de procesamiento - 22 in Solano Wilmer
# Imagen de procesamiento - 23 in Solano Wilmer
# Imagen de procesamiento - 24 in Solano Wilmer
# Imagen de procesamiento - 25 in Solano Wilmer
# Imagen de procesamiento - 26 in Solano Wilmer
# Imagen de procesamiento - 27 in Solano Wilmer
# Imagen de procesamiento - 28 in Solano Wilmer
# Imagen de procesamiento - 29 in Solano Wilmer
# Imagen de procesamiento - 30 in Solano Wilmer
# Imagen de procesamiento - 31 in Solano Wilmer
# Imagen de procesamiento - 32 in Solano Wilmer
# Imagen de procesamiento - 33 in Solano Wilmer
# Imagen de procesamiento - 34 in Solano Wilmer
# Imagen de procesamiento - 35 in Solano Wilmer
# Imagen de procesamiento - 36 in Solano Wilmer
# Imagen de procesamiento - 37 in Solano Wilmer
# Imagen de procesamiento - 38 in Solano Wilmer
# Imagen de procesamiento - 39 in Solano Wilmer
# Imagen de procesamiento - 40 in Solano Wilmer
# Imagen de procesamiento - 41 in Solano Wilmer
# Imagen de procesamiento - 42 in Solano Wilmer
# Imagen de procesamiento - 43 in Solano Wilmer
# Imagen de procesamiento - 44 in Solano Wilmer
# Imagen de procesamiento - 45 in Solano Wilmer
# Imagen de procesamiento - 46 in Solano Wilmer
# Imagen de procesamiento - 47 in Solano Wilmer
# Imagen de procesamiento - 48 in Solano Wilmer
# Imagen de procesamiento - 49 in Solano Wilmer
# Imagen de procesamiento - 50 in Solano Wilmer
# Imagen de procesamiento - 51 in Solano Wilmer
# Imagen de procesamiento - 52 in Solano Wilmer
# Imagen de procesamiento - 53 in Solano Wilmer
# Imagen de procesamiento - 54 in Solano Wilmer
# Imagen de procesamiento - 55 in Solano Wilmer
# Imagen de procesamiento - 56 in Solano Wilmer
# Imagen de procesamiento - 57 in Solano Wilmer
# Imagen de procesamiento - 58 in Solano Wilmer
# Imagen de procesamiento - 59 in Solano Wilmer
# Imagen de procesamiento - 60 in Solano Wilmer
# Imagen de procesamiento - 61 in Solano Wilmer
# Imagen de procesamiento - 62 in Solano Wilmer
# Imagen de procesamiento - 63 in Solano Wilmer
# Imagen de procesamiento - 64 in Solano Wilmer
# Imagen de procesamiento - 65 in Solano Wilmer
# Imagen de procesamiento - 66 in Solano Wilmer
# Imagen de procesamiento - 67 in Solano Wilmer
# Imagen de procesamiento - 68 in Solano Wilmer
# Imagen de procesamiento - 69 in Solano Wilmer
# Imagen de procesamiento - 70 in Solano Wilmer
# Imagen de procesamiento - 71 in Solano Wilmer
# Imagen de procesamiento - 72 in Solano Wilmer
# Imagen de procesamiento - 73 in Solano Wilmer
# Imagen de procesamiento - 74 in Solano Wilmer
# Imagen de procesamiento - 75 in Solano Wilmer
# Imagen de procesamiento - 76 in Solano Wilmer
# Imagen de procesamiento - 77 in Solano Wilmer
# Imagen de procesamiento - 78 in Solano Wilmer
# Imagen de procesamiento - 79 in Solano Wilmer
# Imagen de procesamiento - 80 in Solano Wilmer
# Imagen de procesamiento - 1 in SolorzanoBryan
# Imagen de procesamiento - 2 in SolorzanoBryan
# Imagen de procesamiento - 3 in SolorzanoBryan
# Imagen de procesamiento - 4 in SolorzanoBryan
# Imagen de procesamiento - 5 in SolorzanoBryan
# Imagen de procesamiento - 6 in SolorzanoBryan
# Imagen de procesamiento - 7 in SolorzanoBryan
# Imagen de procesamiento - 8 in SolorzanoBryan
# Imagen de procesamiento - 9 in SolorzanoBryan
# Imagen de procesamiento - 10 in SolorzanoBryan
# Imagen de procesamiento - 11 in SolorzanoBryan
# Imagen de procesamiento - 12 in SolorzanoBryan
# Imagen de procesamiento - 13 in SolorzanoBryan
# Imagen de procesamiento - 14 in SolorzanoBryan
# Imagen de procesamiento - 15 in SolorzanoBryan
# Imagen de procesamiento - 16 in SolorzanoBryan
# Imagen de procesamiento - 17 in SolorzanoBryan
# Imagen de procesamiento - 18 in SolorzanoBryan
# Imagen de procesamiento - 19 in SolorzanoBryan
# Imagen de procesamiento - 20 in SolorzanoBryan
# Imagen de procesamiento - 21 in SolorzanoBryan
# Imagen de procesamiento - 22 in SolorzanoBryan
# Imagen de procesamiento - 23 in SolorzanoBryan
# Imagen de procesamiento - 24 in SolorzanoBryan
# Imagen de procesamiento - 25 in SolorzanoBryan
# Imagen de procesamiento - 26 in SolorzanoBryan
# Imagen de procesamiento - 27 in SolorzanoBryan
# Imagen de procesamiento - 28 in SolorzanoBryan
# Imagen de procesamiento - 29 in SolorzanoBryan
# Imagen de procesamiento - 30 in SolorzanoBryan
# Imagen de procesamiento - 31 in SolorzanoBryan
# Imagen de procesamiento - 32 in SolorzanoBryan
# Imagen de procesamiento - 33 in SolorzanoBryan
# Imagen de procesamiento - 34 in SolorzanoBryan
# Imagen de procesamiento - 35 in SolorzanoBryan
# Imagen de procesamiento - 36 in SolorzanoBryan
# Imagen de procesamiento - 37 in SolorzanoBryan
# Imagen de procesamiento - 38 in SolorzanoBryan
# Imagen de procesamiento - 39 in SolorzanoBryan
# Imagen de procesamiento - 40 in SolorzanoBryan
# Imagen de procesamiento - 41 in SolorzanoBryan
# Imagen de procesamiento - 42 in SolorzanoBryan
# Imagen de procesamiento - 43 in SolorzanoBryan
# Imagen de procesamiento - 44 in SolorzanoBryan
# Imagen de procesamiento - 45 in SolorzanoBryan
# Imagen de procesamiento - 46 in SolorzanoBryan
# Imagen de procesamiento - 47 in SolorzanoBryan
# Imagen de procesamiento - 48 in SolorzanoBryan
# Imagen de procesamiento - 49 in SolorzanoBryan
# Imagen de procesamiento - 50 in SolorzanoBryan
# Imagen de procesamiento - 51 in SolorzanoBryan
# Imagen de procesamiento - 52 in SolorzanoBryan
# Imagen de procesamiento - 53 in SolorzanoBryan
# Imagen de procesamiento - 54 in SolorzanoBryan
# Imagen de procesamiento - 55 in SolorzanoBryan
# Imagen de procesamiento - 56 in SolorzanoBryan
# Imagen de procesamiento - 57 in SolorzanoBryan
# Imagen de procesamiento - 58 in SolorzanoBryan
# Imagen de procesamiento - 59 in SolorzanoBryan
# Imagen de procesamiento - 60 in SolorzanoBryan
# Imagen de procesamiento - 61 in SolorzanoBryan
# Imagen de procesamiento - 62 in SolorzanoBryan
# Imagen de procesamiento - 63 in SolorzanoBryan
# Imagen de procesamiento - 64 in SolorzanoBryan
# Imagen de procesamiento - 65 in SolorzanoBryan
# Imagen de procesamiento - 66 in SolorzanoBryan
# Imagen de procesamiento - 67 in SolorzanoBryan
# Imagen de procesamiento - 68 in SolorzanoBryan
# Imagen de procesamiento - 69 in SolorzanoBryan
# Imagen de procesamiento - 70 in SolorzanoBryan
# Imagen de procesamiento - 71 in SolorzanoBryan
# Imagen de procesamiento - 72 in SolorzanoBryan
# Imagen de procesamiento - 73 in SolorzanoBryan
# Imagen de procesamiento - 74 in SolorzanoBryan
# Imagen de procesamiento - 75 in SolorzanoBryan
# Imagen de procesamiento - 76 in SolorzanoBryan
# Imagen de procesamiento - 77 in SolorzanoBryan
# Imagen de procesamiento - 78 in SolorzanoBryan
# Imagen de procesamiento - 79 in SolorzanoBryan
# Imagen de procesamiento - 80 in SolorzanoBryan
# Imagen de procesamiento - 81 in SolorzanoBryan
# Imagen de procesamiento - 82 in SolorzanoBryan
# Imagen de procesamiento - 83 in SolorzanoBryan
# Imagen de procesamiento - 84 in SolorzanoBryan
# Imagen de procesamiento - 85 in SolorzanoBryan
# Imagen de procesamiento - 86 in SolorzanoBryan
# Imagen de procesamiento - 87 in SolorzanoBryan
# Imagen de procesamiento - 88 in SolorzanoBryan
# Imagen de procesamiento - 89 in SolorzanoBryan
# Imagen de procesamiento - 1 in VinicioBorja
# Imagen de procesamiento - 2 in VinicioBorja
# Imagen de procesamiento - 3 in VinicioBorja
# Imagen de procesamiento - 4 in VinicioBorja
# Imagen de procesamiento - 5 in VinicioBorja
# Imagen de procesamiento - 6 in VinicioBorja
# Imagen de procesamiento - 7 in VinicioBorja
# Imagen de procesamiento - 8 in VinicioBorja
# Imagen de procesamiento - 9 in VinicioBorja
# Imagen de procesamiento - 10 in VinicioBorja
# Imagen de procesamiento - 11 in VinicioBorja
# Imagen de procesamiento - 12 in VinicioBorja
# Imagen de procesamiento - 13 in VinicioBorja
# Imagen de procesamiento - 14 in VinicioBorja
# Imagen de procesamiento - 15 in VinicioBorja
# Imagen de procesamiento - 16 in VinicioBorja
# Imagen de procesamiento - 17 in VinicioBorja
# Imagen de procesamiento - 18 in VinicioBorja
# Imagen de procesamiento - 19 in VinicioBorja
# Imagen de procesamiento - 20 in VinicioBorja
# Imagen de procesamiento - 21 in VinicioBorja
# Imagen de procesamiento - 22 in VinicioBorja
# Imagen de procesamiento - 23 in VinicioBorja
# Imagen de procesamiento - 24 in VinicioBorja
# Imagen de procesamiento - 25 in VinicioBorja
# Imagen de procesamiento - 26 in VinicioBorja
# Imagen de procesamiento - 27 in VinicioBorja
# Imagen de procesamiento - 28 in VinicioBorja
# Imagen de procesamiento - 29 in VinicioBorja
# Imagen de procesamiento - 30 in VinicioBorja
# Imagen de procesamiento - 31 in VinicioBorja
# Imagen de procesamiento - 32 in VinicioBorja
# Imagen de procesamiento - 33 in VinicioBorja
# Imagen de procesamiento - 34 in VinicioBorja
# Imagen de procesamiento - 35 in VinicioBorja
# Imagen de procesamiento - 36 in VinicioBorja
# Imagen de procesamiento - 37 in VinicioBorja
# Imagen de procesamiento - 38 in VinicioBorja
# Imagen de procesamiento - 39 in VinicioBorja
# Imagen de procesamiento - 40 in VinicioBorja
# Imagen de procesamiento - 41 in VinicioBorja
# Imagen de procesamiento - 42 in VinicioBorja
# Imagen de procesamiento - 43 in VinicioBorja
# Imagen de procesamiento - 44 in VinicioBorja
# Imagen de procesamiento - 45 in VinicioBorja
# Imagen de procesamiento - 46 in VinicioBorja
# Imagen de procesamiento - 47 in VinicioBorja
# Imagen de procesamiento - 48 in VinicioBorja
# Imagen de procesamiento - 49 in VinicioBorja
# Imagen de procesamiento - 50 in VinicioBorja
# Imagen de procesamiento - 51 in VinicioBorja
# Imagen de procesamiento - 52 in VinicioBorja
# Imagen de procesamiento - 53 in VinicioBorja
# Imagen de procesamiento - 54 in VinicioBorja
# Imagen de procesamiento - 55 in VinicioBorja
# Imagen de procesamiento - 56 in VinicioBorja
# Imagen de procesamiento - 57 in VinicioBorja
# Imagen de procesamiento - 58 in VinicioBorja
# Imagen de procesamiento - 59 in VinicioBorja
# Imagen de procesamiento - 60 in VinicioBorja
# Imagen de procesamiento - 61 in VinicioBorja
# Imagen de procesamiento - 62 in VinicioBorja
# Imagen de procesamiento - 63 in VinicioBorja
# Imagen de procesamiento - 64 in VinicioBorja
# Imagen de procesamiento - 65 in VinicioBorja
# Imagen de procesamiento - 66 in VinicioBorja
# Imagen de procesamiento - 67 in VinicioBorja
# Imagen de procesamiento - 68 in VinicioBorja
# Imagen de procesamiento - 69 in VinicioBorja
# Imagen de procesamiento - 70 in VinicioBorja
# Imagen de procesamiento - 71 in VinicioBorja
# Imagen de procesamiento - 72 in VinicioBorja
# Imagen de procesamiento - 73 in VinicioBorja
# Imagen de procesamiento - 74 in VinicioBorja
# Imagen de procesamiento - 75 in VinicioBorja
# Imagen de procesamiento - 76 in VinicioBorja
# Imagen de procesamiento - 77 in VinicioBorja
# Imagen de procesamiento - 78 in VinicioBorja
# Imagen de procesamiento - 79 in VinicioBorja
# Imagen de procesamiento - 80 in VinicioBorja
# Imagen de procesamiento - 81 in VinicioBorja
# Imagen de procesamiento - 82 in VinicioBorja
# Imagen de procesamiento - 83 in VinicioBorja
# Imagen de procesamiento - 84 in VinicioBorja
# Imagen de procesamiento - 85 in VinicioBorja
# Imagen de procesamiento - 86 in VinicioBorja
# Imagen de procesamiento - 87 in VinicioBorja
# Imagen de procesamiento - 88 in VinicioBorja
# Imagen de procesamiento - 89 in VinicioBorja
# Imagen de procesamiento - 90 in VinicioBorja
# Imagen de procesamiento - 91 in VinicioBorja
# Imagen de procesamiento - 92 in VinicioBorja
# Imagen de procesamiento - 93 in VinicioBorja
# Imagen de procesamiento - 94 in VinicioBorja
# Imagen de procesamiento - 95 in VinicioBorja
# Imagen de procesamiento - 96 in VinicioBorja
# Imagen de procesamiento - 97 in VinicioBorja
# Imagen de procesamiento - 98 in VinicioBorja
# Imagen de procesamiento - 99 in VinicioBorja

# %% [markdown]
# ## Eliminación de fondo

# %%
"""Obteniendo etiquetas de la nueva carpeta que se ha creado"""
ruta_imagen = "./PROYECTOIA-U3_eliminarRuido"
nombre_clases = os.listdir(ruta_imagen)
nombre_clases.sort()
print(nombre_clases)
# Out:
# ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedeno', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'Raymond Davila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']

# %%
"""Recorriendo la ruta y el nombre de cada carpeta"""
for nombre_clase in nombre_clases:
    cur_path = ruta_imagen + "/" + nombre_clase
    cur_label = nombre_clase
    i = 1
    """Ciclo for para que se elimine el ruido de cada imágen"""
    for file in glob.glob(cur_path + "/*"):
        print("Imágen de procesamiento - {} in {}".format(i, cur_label))
        # leer la ruta de las imágenes
        image = cv2.imread(file)
        # removiendo bg 
        output = remove(image)
        # guardando imágenes
        save_path = './PROYECTOIA-U3_eliminarBG/'+ cur_label
        cv2.imwrite(os.path.join(save_path , cur_label + '_' + str(i) + '.png'), output)
        

        # mostrar actualización de bucle
        i += 1
# Out:
# Imágen de procesamiento - 1 in Ariel Chabla
# Imágen de procesamiento - 2 in Ariel Chabla
# Imágen de procesamiento - 3 in Ariel Chabla
# Imágen de procesamiento - 4 in Ariel Chabla
# Imágen de procesamiento - 5 in Ariel Chabla
# Imágen de procesamiento - 6 in Ariel Chabla
# Imágen de procesamiento - 7 in Ariel Chabla
# Imágen de procesamiento - 8 in Ariel Chabla
# Imágen de procesamiento - 9 in Ariel Chabla
# Imágen de procesamiento - 10 in Ariel Chabla
# Imágen de procesamiento - 11 in Ariel Chabla
# Imágen de procesamiento - 12 in Ariel Chabla
# Imágen de procesamiento - 13 in Ariel Chabla
# Imágen de procesamiento - 14 in Ariel Chabla
# Imágen de procesamiento - 15 in Ariel Chabla
# Imágen de procesamiento - 16 in Ariel Chabla
# Imágen de procesamiento - 17 in Ariel Chabla
# Imágen de procesamiento - 18 in Ariel Chabla
# Imágen de procesamiento - 19 in Ariel Chabla
# Imágen de procesamiento - 20 in Ariel Chabla
# Imágen de procesamiento - 21 in Ariel Chabla
# Imágen de procesamiento - 22 in Ariel Chabla
# Imágen de procesamiento - 23 in Ariel Chabla
# Imágen de procesamiento - 24 in Ariel Chabla
# Imágen de procesamiento - 25 in Ariel Chabla
# Imágen de procesamiento - 26 in Ariel Chabla
# Imágen de procesamiento - 27 in Ariel Chabla
# Imágen de procesamiento - 28 in Ariel Chabla
# Imágen de procesamiento - 29 in Ariel Chabla
# Imágen de procesamiento - 30 in Ariel Chabla
# Imágen de procesamiento - 31 in Ariel Chabla
# Imágen de procesamiento - 32 in Ariel Chabla
# Imágen de procesamiento - 33 in Ariel Chabla
# Imágen de procesamiento - 34 in Ariel Chabla
# Imágen de procesamiento - 35 in Ariel Chabla
# Imágen de procesamiento - 36 in Ariel Chabla
# Imágen de procesamiento - 37 in Ariel Chabla
# Imágen de procesamiento - 38 in Ariel Chabla
# Imágen de procesamiento - 39 in Ariel Chabla
# Imágen de procesamiento - 40 in Ariel Chabla
# Imágen de procesamiento - 41 in Ariel Chabla
# Imágen de procesamiento - 42 in Ariel Chabla
# Imágen de procesamiento - 43 in Ariel Chabla
# Imágen de procesamiento - 44 in Ariel Chabla
# Imágen de procesamiento - 45 in Ariel Chabla
# Imágen de procesamiento - 46 in Ariel Chabla
# Imágen de procesamiento - 47 in Ariel Chabla
# Imágen de procesamiento - 48 in Ariel Chabla
# Imágen de procesamiento - 49 in Ariel Chabla
# Imágen de procesamiento - 50 in Ariel Chabla
# Imágen de procesamiento - 51 in Ariel Chabla
# Imágen de procesamiento - 52 in Ariel Chabla
# Imágen de procesamiento - 53 in Ariel Chabla
# Imágen de procesamiento - 54 in Ariel Chabla
# Imágen de procesamiento - 55 in Ariel Chabla
# Imágen de procesamiento - 56 in Ariel Chabla
# Imágen de procesamiento - 57 in Ariel Chabla
# Imágen de procesamiento - 58 in Ariel Chabla
# Imágen de procesamiento - 59 in Ariel Chabla
# Imágen de procesamiento - 60 in Ariel Chabla
# Imágen de procesamiento - 61 in Ariel Chabla
# Imágen de procesamiento - 62 in Ariel Chabla
# Imágen de procesamiento - 63 in Ariel Chabla
# Imágen de procesamiento - 64 in Ariel Chabla
# Imágen de procesamiento - 65 in Ariel Chabla
# Imágen de procesamiento - 66 in Ariel Chabla
# Imágen de procesamiento - 67 in Ariel Chabla
# Imágen de procesamiento - 68 in Ariel Chabla
# Imágen de procesamiento - 69 in Ariel Chabla
# Imágen de procesamiento - 70 in Ariel Chabla
# Imágen de procesamiento - 71 in Ariel Chabla
# Imágen de procesamiento - 72 in Ariel Chabla
# Imágen de procesamiento - 73 in Ariel Chabla
# Imágen de procesamiento - 74 in Ariel Chabla
# Imágen de procesamiento - 75 in Ariel Chabla
# Imágen de procesamiento - 76 in Ariel Chabla
# Imágen de procesamiento - 77 in Ariel Chabla
# Imágen de procesamiento - 78 in Ariel Chabla
# Imágen de procesamiento - 79 in Ariel Chabla
# Imágen de procesamiento - 80 in Ariel Chabla
# Imágen de procesamiento - 1 in ArroboMercy
# Imágen de procesamiento - 2 in ArroboMercy
# Imágen de procesamiento - 3 in ArroboMercy
# Imágen de procesamiento - 4 in ArroboMercy
# Imágen de procesamiento - 5 in ArroboMercy
# Imágen de procesamiento - 6 in ArroboMercy
# Imágen de procesamiento - 7 in ArroboMercy
# Imágen de procesamiento - 8 in ArroboMercy
# Imágen de procesamiento - 9 in ArroboMercy
# Imágen de procesamiento - 10 in ArroboMercy
# Imágen de procesamiento - 11 in ArroboMercy
# Imágen de procesamiento - 12 in ArroboMercy
# Imágen de procesamiento - 13 in ArroboMercy
# Imágen de procesamiento - 14 in ArroboMercy
# Imágen de procesamiento - 15 in ArroboMercy
# Imágen de procesamiento - 16 in ArroboMercy
# Imágen de procesamiento - 17 in ArroboMercy
# Imágen de procesamiento - 18 in ArroboMercy
# Imágen de procesamiento - 19 in ArroboMercy
# Imágen de procesamiento - 20 in ArroboMercy
# Imágen de procesamiento - 21 in ArroboMercy
# Imágen de procesamiento - 22 in ArroboMercy
# Imágen de procesamiento - 23 in ArroboMercy
# Imágen de procesamiento - 24 in ArroboMercy
# Imágen de procesamiento - 25 in ArroboMercy
# Imágen de procesamiento - 26 in ArroboMercy
# Imágen de procesamiento - 27 in ArroboMercy
# Imágen de procesamiento - 28 in ArroboMercy
# Imágen de procesamiento - 29 in ArroboMercy
# Imágen de procesamiento - 30 in ArroboMercy
# Imágen de procesamiento - 31 in ArroboMercy
# Imágen de procesamiento - 32 in ArroboMercy
# Imágen de procesamiento - 33 in ArroboMercy
# Imágen de procesamiento - 34 in ArroboMercy
# Imágen de procesamiento - 35 in ArroboMercy
# Imágen de procesamiento - 36 in ArroboMercy
# Imágen de procesamiento - 37 in ArroboMercy
# Imágen de procesamiento - 38 in ArroboMercy
# Imágen de procesamiento - 39 in ArroboMercy
# Imágen de procesamiento - 40 in ArroboMercy
# Imágen de procesamiento - 41 in ArroboMercy
# Imágen de procesamiento - 42 in ArroboMercy
# Imágen de procesamiento - 43 in ArroboMercy
# Imágen de procesamiento - 44 in ArroboMercy
# Imágen de procesamiento - 45 in ArroboMercy
# Imágen de procesamiento - 46 in ArroboMercy
# Imágen de procesamiento - 47 in ArroboMercy
# Imágen de procesamiento - 48 in ArroboMercy
# Imágen de procesamiento - 49 in ArroboMercy
# Imágen de procesamiento - 50 in ArroboMercy
# Imágen de procesamiento - 51 in ArroboMercy
# Imágen de procesamiento - 52 in ArroboMercy
# Imágen de procesamiento - 53 in ArroboMercy
# Imágen de procesamiento - 54 in ArroboMercy
# Imágen de procesamiento - 55 in ArroboMercy
# Imágen de procesamiento - 56 in ArroboMercy
# Imágen de procesamiento - 57 in ArroboMercy
# Imágen de procesamiento - 58 in ArroboMercy
# Imágen de procesamiento - 59 in ArroboMercy
# Imágen de procesamiento - 60 in ArroboMercy
# Imágen de procesamiento - 61 in ArroboMercy
# Imágen de procesamiento - 62 in ArroboMercy
# Imágen de procesamiento - 63 in ArroboMercy
# Imágen de procesamiento - 64 in ArroboMercy
# Imágen de procesamiento - 65 in ArroboMercy
# Imágen de procesamiento - 66 in ArroboMercy
# Imágen de procesamiento - 67 in ArroboMercy
# Imágen de procesamiento - 68 in ArroboMercy
# Imágen de procesamiento - 69 in ArroboMercy
# Imágen de procesamiento - 70 in ArroboMercy
# Imágen de procesamiento - 71 in ArroboMercy
# Imágen de procesamiento - 72 in ArroboMercy
# Imágen de procesamiento - 73 in ArroboMercy
# Imágen de procesamiento - 74 in ArroboMercy
# Imágen de procesamiento - 75 in ArroboMercy
# Imágen de procesamiento - 76 in ArroboMercy
# Imágen de procesamiento - 77 in ArroboMercy
# Imágen de procesamiento - 78 in ArroboMercy
# Imágen de procesamiento - 79 in ArroboMercy
# Imágen de procesamiento - 1 in BarraganSteven
# Imágen de procesamiento - 2 in BarraganSteven
# Imágen de procesamiento - 3 in BarraganSteven
# Imágen de procesamiento - 4 in BarraganSteven
# Imágen de procesamiento - 5 in BarraganSteven
# Imágen de procesamiento - 6 in BarraganSteven
# Imágen de procesamiento - 7 in BarraganSteven
# Imágen de procesamiento - 8 in BarraganSteven
# Imágen de procesamiento - 9 in BarraganSteven
# Imágen de procesamiento - 10 in BarraganSteven
# Imágen de procesamiento - 11 in BarraganSteven
# Imágen de procesamiento - 12 in BarraganSteven
# Imágen de procesamiento - 13 in BarraganSteven
# Imágen de procesamiento - 14 in BarraganSteven
# Imágen de procesamiento - 15 in BarraganSteven
# Imágen de procesamiento - 16 in BarraganSteven
# Imágen de procesamiento - 17 in BarraganSteven
# Imágen de procesamiento - 18 in BarraganSteven
# Imágen de procesamiento - 19 in BarraganSteven
# Imágen de procesamiento - 20 in BarraganSteven
# Imágen de procesamiento - 21 in BarraganSteven
# Imágen de procesamiento - 22 in BarraganSteven
# Imágen de procesamiento - 23 in BarraganSteven
# Imágen de procesamiento - 24 in BarraganSteven
# Imágen de procesamiento - 25 in BarraganSteven
# Imágen de procesamiento - 26 in BarraganSteven
# Imágen de procesamiento - 27 in BarraganSteven
# Imágen de procesamiento - 28 in BarraganSteven
# Imágen de procesamiento - 29 in BarraganSteven
# Imágen de procesamiento - 30 in BarraganSteven
# Imágen de procesamiento - 31 in BarraganSteven
# Imágen de procesamiento - 32 in BarraganSteven
# Imágen de procesamiento - 33 in BarraganSteven
# Imágen de procesamiento - 34 in BarraganSteven
# Imágen de procesamiento - 35 in BarraganSteven
# Imágen de procesamiento - 36 in BarraganSteven
# Imágen de procesamiento - 37 in BarraganSteven
# Imágen de procesamiento - 38 in BarraganSteven
# Imágen de procesamiento - 39 in BarraganSteven
# Imágen de procesamiento - 40 in BarraganSteven
# Imágen de procesamiento - 41 in BarraganSteven
# Imágen de procesamiento - 42 in BarraganSteven
# Imágen de procesamiento - 43 in BarraganSteven
# Imágen de procesamiento - 44 in BarraganSteven
# Imágen de procesamiento - 45 in BarraganSteven
# Imágen de procesamiento - 46 in BarraganSteven
# Imágen de procesamiento - 47 in BarraganSteven
# Imágen de procesamiento - 48 in BarraganSteven
# Imágen de procesamiento - 49 in BarraganSteven
# Imágen de procesamiento - 50 in BarraganSteven
# Imágen de procesamiento - 51 in BarraganSteven
# Imágen de procesamiento - 52 in BarraganSteven
# Imágen de procesamiento - 53 in BarraganSteven
# Imágen de procesamiento - 54 in BarraganSteven
# Imágen de procesamiento - 55 in BarraganSteven
# Imágen de procesamiento - 56 in BarraganSteven
# Imágen de procesamiento - 57 in BarraganSteven
# Imágen de procesamiento - 58 in BarraganSteven
# Imágen de procesamiento - 59 in BarraganSteven
# Imágen de procesamiento - 60 in BarraganSteven
# Imágen de procesamiento - 61 in BarraganSteven
# Imágen de procesamiento - 62 in BarraganSteven
# Imágen de procesamiento - 63 in BarraganSteven
# Imágen de procesamiento - 64 in BarraganSteven
# Imágen de procesamiento - 65 in BarraganSteven
# Imágen de procesamiento - 66 in BarraganSteven
# Imágen de procesamiento - 67 in BarraganSteven
# Imágen de procesamiento - 68 in BarraganSteven
# Imágen de procesamiento - 69 in BarraganSteven
# Imágen de procesamiento - 70 in BarraganSteven
# Imágen de procesamiento - 71 in BarraganSteven
# Imágen de procesamiento - 72 in BarraganSteven
# Imágen de procesamiento - 73 in BarraganSteven
# Imágen de procesamiento - 74 in BarraganSteven
# Imágen de procesamiento - 75 in BarraganSteven
# Imágen de procesamiento - 76 in BarraganSteven
# Imágen de procesamiento - 77 in BarraganSteven
# Imágen de procesamiento - 78 in BarraganSteven
# Imágen de procesamiento - 79 in BarraganSteven
# Imágen de procesamiento - 80 in BarraganSteven
# Imágen de procesamiento - 81 in BarraganSteven
# Imágen de procesamiento - 82 in BarraganSteven
# Imágen de procesamiento - 83 in BarraganSteven
# Imágen de procesamiento - 84 in BarraganSteven
# Imágen de procesamiento - 85 in BarraganSteven
# Imágen de procesamiento - 86 in BarraganSteven
# Imágen de procesamiento - 87 in BarraganSteven
# Imágen de procesamiento - 88 in BarraganSteven
# Imágen de procesamiento - 89 in BarraganSteven
# Imágen de procesamiento - 90 in BarraganSteven
# Imágen de procesamiento - 91 in BarraganSteven
# Imágen de procesamiento - 92 in BarraganSteven
# Imágen de procesamiento - 93 in BarraganSteven
# Imágen de procesamiento - 94 in BarraganSteven
# Imágen de procesamiento - 95 in BarraganSteven
# Imágen de procesamiento - 96 in BarraganSteven
# Imágen de procesamiento - 97 in BarraganSteven
# Imágen de procesamiento - 98 in BarraganSteven
# Imágen de procesamiento - 99 in BarraganSteven
# Imágen de procesamiento - 100 in BarraganSteven
# Imágen de procesamiento - 101 in BarraganSteven
# Imágen de procesamiento - 102 in BarraganSteven
# Imágen de procesamiento - 103 in BarraganSteven
# Imágen de procesamiento - 104 in BarraganSteven
# Imágen de procesamiento - 105 in BarraganSteven
# Imágen de procesamiento - 106 in BarraganSteven
# Imágen de procesamiento - 107 in BarraganSteven
# Imágen de procesamiento - 108 in BarraganSteven
# Imágen de procesamiento - 109 in BarraganSteven
# Imágen de procesamiento - 110 in BarraganSteven
# Imágen de procesamiento - 111 in BarraganSteven
# Imágen de procesamiento - 112 in BarraganSteven
# Imágen de procesamiento - 113 in BarraganSteven
# Imágen de procesamiento - 114 in BarraganSteven
# Imágen de procesamiento - 115 in BarraganSteven
# Imágen de procesamiento - 116 in BarraganSteven
# Imágen de procesamiento - 117 in BarraganSteven
# Imágen de procesamiento - 118 in BarraganSteven
# Imágen de procesamiento - 119 in BarraganSteven
# Imágen de procesamiento - 120 in BarraganSteven
# Imágen de procesamiento - 121 in BarraganSteven
# Imágen de procesamiento - 122 in BarraganSteven
# Imágen de procesamiento - 123 in BarraganSteven
# Imágen de procesamiento - 124 in BarraganSteven
# Imágen de procesamiento - 125 in BarraganSteven
# Imágen de procesamiento - 126 in BarraganSteven
# Imágen de procesamiento - 127 in BarraganSteven
# Imágen de procesamiento - 128 in BarraganSteven
# Imágen de procesamiento - 129 in BarraganSteven
# Imágen de procesamiento - 130 in BarraganSteven
# Imágen de procesamiento - 131 in BarraganSteven
# Imágen de procesamiento - 132 in BarraganSteven
# Imágen de procesamiento - 133 in BarraganSteven
# Imágen de procesamiento - 134 in BarraganSteven
# Imágen de procesamiento - 135 in BarraganSteven
# Imágen de procesamiento - 136 in BarraganSteven
# Imágen de procesamiento - 137 in BarraganSteven
# Imágen de procesamiento - 138 in BarraganSteven
# Imágen de procesamiento - 139 in BarraganSteven
# Imágen de procesamiento - 140 in BarraganSteven
# Imágen de procesamiento - 1 in CevallosJoan
# Imágen de procesamiento - 2 in CevallosJoan
# Imágen de procesamiento - 3 in CevallosJoan
# Imágen de procesamiento - 4 in CevallosJoan
# Imágen de procesamiento - 5 in CevallosJoan
# Imágen de procesamiento - 6 in CevallosJoan
# Imágen de procesamiento - 7 in CevallosJoan
# Imágen de procesamiento - 8 in CevallosJoan
# Imágen de procesamiento - 9 in CevallosJoan
# Imágen de procesamiento - 10 in CevallosJoan
# Imágen de procesamiento - 11 in CevallosJoan
# Imágen de procesamiento - 12 in CevallosJoan
# Imágen de procesamiento - 13 in CevallosJoan
# Imágen de procesamiento - 14 in CevallosJoan
# Imágen de procesamiento - 15 in CevallosJoan
# Imágen de procesamiento - 16 in CevallosJoan
# Imágen de procesamiento - 17 in CevallosJoan
# Imágen de procesamiento - 18 in CevallosJoan
# Imágen de procesamiento - 19 in CevallosJoan
# Imágen de procesamiento - 20 in CevallosJoan
# Imágen de procesamiento - 21 in CevallosJoan
# Imágen de procesamiento - 22 in CevallosJoan
# Imágen de procesamiento - 23 in CevallosJoan
# Imágen de procesamiento - 24 in CevallosJoan
# Imágen de procesamiento - 25 in CevallosJoan
# Imágen de procesamiento - 26 in CevallosJoan
# Imágen de procesamiento - 27 in CevallosJoan
# Imágen de procesamiento - 28 in CevallosJoan
# Imágen de procesamiento - 29 in CevallosJoan
# Imágen de procesamiento - 30 in CevallosJoan
# Imágen de procesamiento - 31 in CevallosJoan
# Imágen de procesamiento - 32 in CevallosJoan
# Imágen de procesamiento - 33 in CevallosJoan
# Imágen de procesamiento - 34 in CevallosJoan
# Imágen de procesamiento - 35 in CevallosJoan
# Imágen de procesamiento - 36 in CevallosJoan
# Imágen de procesamiento - 37 in CevallosJoan
# Imágen de procesamiento - 38 in CevallosJoan
# Imágen de procesamiento - 39 in CevallosJoan
# Imágen de procesamiento - 40 in CevallosJoan
# Imágen de procesamiento - 41 in CevallosJoan
# Imágen de procesamiento - 42 in CevallosJoan
# Imágen de procesamiento - 43 in CevallosJoan
# Imágen de procesamiento - 44 in CevallosJoan
# Imágen de procesamiento - 45 in CevallosJoan
# Imágen de procesamiento - 46 in CevallosJoan
# Imágen de procesamiento - 47 in CevallosJoan
# Imágen de procesamiento - 48 in CevallosJoan
# Imágen de procesamiento - 49 in CevallosJoan
# Imágen de procesamiento - 50 in CevallosJoan
# Imágen de procesamiento - 51 in CevallosJoan
# Imágen de procesamiento - 52 in CevallosJoan
# Imágen de procesamiento - 53 in CevallosJoan
# Imágen de procesamiento - 54 in CevallosJoan
# Imágen de procesamiento - 55 in CevallosJoan
# Imágen de procesamiento - 56 in CevallosJoan
# Imágen de procesamiento - 57 in CevallosJoan
# Imágen de procesamiento - 58 in CevallosJoan
# Imágen de procesamiento - 59 in CevallosJoan
# Imágen de procesamiento - 60 in CevallosJoan
# Imágen de procesamiento - 61 in CevallosJoan
# Imágen de procesamiento - 62 in CevallosJoan
# Imágen de procesamiento - 63 in CevallosJoan
# Imágen de procesamiento - 64 in CevallosJoan
# Imágen de procesamiento - 65 in CevallosJoan
# Imágen de procesamiento - 66 in CevallosJoan
# Imágen de procesamiento - 67 in CevallosJoan
# Imágen de procesamiento - 68 in CevallosJoan
# Imágen de procesamiento - 69 in CevallosJoan
# Imágen de procesamiento - 70 in CevallosJoan
# Imágen de procesamiento - 71 in CevallosJoan
# Imágen de procesamiento - 72 in CevallosJoan
# Imágen de procesamiento - 73 in CevallosJoan
# Imágen de procesamiento - 74 in CevallosJoan
# Imágen de procesamiento - 75 in CevallosJoan
# Imágen de procesamiento - 76 in CevallosJoan
# Imágen de procesamiento - 77 in CevallosJoan
# Imágen de procesamiento - 78 in CevallosJoan
# Imágen de procesamiento - 79 in CevallosJoan
# Imágen de procesamiento - 80 in CevallosJoan
# Imágen de procesamiento - 81 in CevallosJoan
# Imágen de procesamiento - 82 in CevallosJoan
# Imágen de procesamiento - 83 in CevallosJoan
# Imágen de procesamiento - 84 in CevallosJoan
# Imágen de procesamiento - 85 in CevallosJoan
# Imágen de procesamiento - 86 in CevallosJoan
# Imágen de procesamiento - 87 in CevallosJoan
# Imágen de procesamiento - 88 in CevallosJoan
# Imágen de procesamiento - 89 in CevallosJoan
# Imágen de procesamiento - 90 in CevallosJoan
# Imágen de procesamiento - 1 in EnriquezSelena
# Imágen de procesamiento - 2 in EnriquezSelena
# Imágen de procesamiento - 3 in EnriquezSelena
# Imágen de procesamiento - 4 in EnriquezSelena
# Imágen de procesamiento - 5 in EnriquezSelena
# Imágen de procesamiento - 6 in EnriquezSelena
# Imágen de procesamiento - 7 in EnriquezSelena
# Imágen de procesamiento - 8 in EnriquezSelena
# Imágen de procesamiento - 9 in EnriquezSelena
# Imágen de procesamiento - 10 in EnriquezSelena
# Imágen de procesamiento - 11 in EnriquezSelena
# Imágen de procesamiento - 12 in EnriquezSelena
# Imágen de procesamiento - 13 in EnriquezSelena
# Imágen de procesamiento - 14 in EnriquezSelena
# Imágen de procesamiento - 15 in EnriquezSelena
# Imágen de procesamiento - 16 in EnriquezSelena
# Imágen de procesamiento - 17 in EnriquezSelena
# Imágen de procesamiento - 18 in EnriquezSelena
# Imágen de procesamiento - 19 in EnriquezSelena
# Imágen de procesamiento - 20 in EnriquezSelena
# Imágen de procesamiento - 21 in EnriquezSelena
# Imágen de procesamiento - 22 in EnriquezSelena
# Imágen de procesamiento - 23 in EnriquezSelena
# Imágen de procesamiento - 24 in EnriquezSelena
# Imágen de procesamiento - 25 in EnriquezSelena
# Imágen de procesamiento - 26 in EnriquezSelena
# Imágen de procesamiento - 27 in EnriquezSelena
# Imágen de procesamiento - 28 in EnriquezSelena
# Imágen de procesamiento - 29 in EnriquezSelena
# Imágen de procesamiento - 30 in EnriquezSelena
# Imágen de procesamiento - 31 in EnriquezSelena
# Imágen de procesamiento - 32 in EnriquezSelena
# Imágen de procesamiento - 33 in EnriquezSelena
# Imágen de procesamiento - 34 in EnriquezSelena
# Imágen de procesamiento - 35 in EnriquezSelena
# Imágen de procesamiento - 36 in EnriquezSelena
# Imágen de procesamiento - 37 in EnriquezSelena
# Imágen de procesamiento - 38 in EnriquezSelena
# Imágen de procesamiento - 39 in EnriquezSelena
# Imágen de procesamiento - 40 in EnriquezSelena
# Imágen de procesamiento - 41 in EnriquezSelena
# Imágen de procesamiento - 42 in EnriquezSelena
# Imágen de procesamiento - 43 in EnriquezSelena
# Imágen de procesamiento - 44 in EnriquezSelena
# Imágen de procesamiento - 45 in EnriquezSelena
# Imágen de procesamiento - 46 in EnriquezSelena
# Imágen de procesamiento - 47 in EnriquezSelena
# Imágen de procesamiento - 48 in EnriquezSelena
# Imágen de procesamiento - 49 in EnriquezSelena
# Imágen de procesamiento - 50 in EnriquezSelena
# Imágen de procesamiento - 1 in GenesisHeredia
# Imágen de procesamiento - 2 in GenesisHeredia
# Imágen de procesamiento - 3 in GenesisHeredia
# Imágen de procesamiento - 4 in GenesisHeredia
# Imágen de procesamiento - 5 in GenesisHeredia
# Imágen de procesamiento - 6 in GenesisHeredia
# Imágen de procesamiento - 7 in GenesisHeredia
# Imágen de procesamiento - 8 in GenesisHeredia
# Imágen de procesamiento - 9 in GenesisHeredia
# Imágen de procesamiento - 10 in GenesisHeredia
# Imágen de procesamiento - 11 in GenesisHeredia
# Imágen de procesamiento - 12 in GenesisHeredia
# Imágen de procesamiento - 13 in GenesisHeredia
# Imágen de procesamiento - 14 in GenesisHeredia
# Imágen de procesamiento - 15 in GenesisHeredia
# Imágen de procesamiento - 16 in GenesisHeredia
# Imágen de procesamiento - 17 in GenesisHeredia
# Imágen de procesamiento - 18 in GenesisHeredia
# Imágen de procesamiento - 19 in GenesisHeredia
# Imágen de procesamiento - 20 in GenesisHeredia
# Imágen de procesamiento - 21 in GenesisHeredia
# Imágen de procesamiento - 22 in GenesisHeredia
# Imágen de procesamiento - 23 in GenesisHeredia
# Imágen de procesamiento - 24 in GenesisHeredia
# Imágen de procesamiento - 25 in GenesisHeredia
# Imágen de procesamiento - 26 in GenesisHeredia
# Imágen de procesamiento - 27 in GenesisHeredia
# Imágen de procesamiento - 28 in GenesisHeredia
# Imágen de procesamiento - 29 in GenesisHeredia
# Imágen de procesamiento - 30 in GenesisHeredia
# Imágen de procesamiento - 31 in GenesisHeredia
# Imágen de procesamiento - 32 in GenesisHeredia
# Imágen de procesamiento - 33 in GenesisHeredia
# Imágen de procesamiento - 34 in GenesisHeredia
# Imágen de procesamiento - 35 in GenesisHeredia
# Imágen de procesamiento - 36 in GenesisHeredia
# Imágen de procesamiento - 37 in GenesisHeredia
# Imágen de procesamiento - 38 in GenesisHeredia
# Imágen de procesamiento - 39 in GenesisHeredia
# Imágen de procesamiento - 40 in GenesisHeredia
# Imágen de procesamiento - 41 in GenesisHeredia
# Imágen de procesamiento - 42 in GenesisHeredia
# Imágen de procesamiento - 43 in GenesisHeredia
# Imágen de procesamiento - 44 in GenesisHeredia
# Imágen de procesamiento - 45 in GenesisHeredia
# Imágen de procesamiento - 46 in GenesisHeredia
# Imágen de procesamiento - 47 in GenesisHeredia
# Imágen de procesamiento - 48 in GenesisHeredia
# Imágen de procesamiento - 49 in GenesisHeredia
# Imágen de procesamiento - 50 in GenesisHeredia
# Imágen de procesamiento - 51 in GenesisHeredia
# Imágen de procesamiento - 52 in GenesisHeredia
# Imágen de procesamiento - 53 in GenesisHeredia
# Imágen de procesamiento - 54 in GenesisHeredia
# Imágen de procesamiento - 55 in GenesisHeredia
# Imágen de procesamiento - 56 in GenesisHeredia
# Imágen de procesamiento - 57 in GenesisHeredia
# Imágen de procesamiento - 58 in GenesisHeredia
# Imágen de procesamiento - 59 in GenesisHeredia
# Imágen de procesamiento - 60 in GenesisHeredia
# Imágen de procesamiento - 61 in GenesisHeredia
# Imágen de procesamiento - 62 in GenesisHeredia
# Imágen de procesamiento - 63 in GenesisHeredia
# Imágen de procesamiento - 64 in GenesisHeredia
# Imágen de procesamiento - 65 in GenesisHeredia
# Imágen de procesamiento - 66 in GenesisHeredia
# Imágen de procesamiento - 67 in GenesisHeredia
# Imágen de procesamiento - 68 in GenesisHeredia
# Imágen de procesamiento - 69 in GenesisHeredia
# Imágen de procesamiento - 70 in GenesisHeredia
# Imágen de procesamiento - 71 in GenesisHeredia
# Imágen de procesamiento - 72 in GenesisHeredia
# Imágen de procesamiento - 73 in GenesisHeredia
# Imágen de procesamiento - 74 in GenesisHeredia
# Imágen de procesamiento - 75 in GenesisHeredia
# Imágen de procesamiento - 76 in GenesisHeredia
# Imágen de procesamiento - 77 in GenesisHeredia
# Imágen de procesamiento - 78 in GenesisHeredia
# Imágen de procesamiento - 79 in GenesisHeredia
# Imágen de procesamiento - 80 in GenesisHeredia
# Imágen de procesamiento - 81 in GenesisHeredia
# Imágen de procesamiento - 82 in GenesisHeredia
# Imágen de procesamiento - 83 in GenesisHeredia
# Imágen de procesamiento - 84 in GenesisHeredia
# Imágen de procesamiento - 85 in GenesisHeredia
# Imágen de procesamiento - 86 in GenesisHeredia
# Imágen de procesamiento - 87 in GenesisHeredia
# Imágen de procesamiento - 88 in GenesisHeredia
# Imágen de procesamiento - 89 in GenesisHeredia
# Imágen de procesamiento - 90 in GenesisHeredia
# Imágen de procesamiento - 91 in GenesisHeredia
# Imágen de procesamiento - 92 in GenesisHeredia
# Imágen de procesamiento - 93 in GenesisHeredia
# Imágen de procesamiento - 94 in GenesisHeredia
# Imágen de procesamiento - 95 in GenesisHeredia
# Imágen de procesamiento - 96 in GenesisHeredia
# Imágen de procesamiento - 97 in GenesisHeredia
# Imágen de procesamiento - 98 in GenesisHeredia
# Imágen de procesamiento - 99 in GenesisHeredia
# Imágen de procesamiento - 100 in GenesisHeredia
# Imágen de procesamiento - 1 in GoyesAnthony
# Imágen de procesamiento - 2 in GoyesAnthony
# Imágen de procesamiento - 3 in GoyesAnthony
# Imágen de procesamiento - 4 in GoyesAnthony
# Imágen de procesamiento - 5 in GoyesAnthony
# Imágen de procesamiento - 6 in GoyesAnthony
# Imágen de procesamiento - 7 in GoyesAnthony
# Imágen de procesamiento - 8 in GoyesAnthony
# Imágen de procesamiento - 9 in GoyesAnthony
# Imágen de procesamiento - 10 in GoyesAnthony
# Imágen de procesamiento - 11 in GoyesAnthony
# Imágen de procesamiento - 12 in GoyesAnthony
# Imágen de procesamiento - 13 in GoyesAnthony
# Imágen de procesamiento - 14 in GoyesAnthony
# Imágen de procesamiento - 15 in GoyesAnthony
# Imágen de procesamiento - 16 in GoyesAnthony
# Imágen de procesamiento - 17 in GoyesAnthony
# Imágen de procesamiento - 18 in GoyesAnthony
# Imágen de procesamiento - 19 in GoyesAnthony
# Imágen de procesamiento - 20 in GoyesAnthony
# Imágen de procesamiento - 21 in GoyesAnthony
# Imágen de procesamiento - 22 in GoyesAnthony
# Imágen de procesamiento - 23 in GoyesAnthony
# Imágen de procesamiento - 24 in GoyesAnthony
# Imágen de procesamiento - 25 in GoyesAnthony
# Imágen de procesamiento - 26 in GoyesAnthony
# Imágen de procesamiento - 27 in GoyesAnthony
# Imágen de procesamiento - 28 in GoyesAnthony
# Imágen de procesamiento - 29 in GoyesAnthony
# Imágen de procesamiento - 30 in GoyesAnthony
# Imágen de procesamiento - 31 in GoyesAnthony
# Imágen de procesamiento - 32 in GoyesAnthony
# Imágen de procesamiento - 33 in GoyesAnthony
# Imágen de procesamiento - 34 in GoyesAnthony
# Imágen de procesamiento - 35 in GoyesAnthony
# Imágen de procesamiento - 36 in GoyesAnthony
# Imágen de procesamiento - 37 in GoyesAnthony
# Imágen de procesamiento - 38 in GoyesAnthony
# Imágen de procesamiento - 39 in GoyesAnthony
# Imágen de procesamiento - 40 in GoyesAnthony
# Imágen de procesamiento - 41 in GoyesAnthony
# Imágen de procesamiento - 42 in GoyesAnthony
# Imágen de procesamiento - 43 in GoyesAnthony
# Imágen de procesamiento - 44 in GoyesAnthony
# Imágen de procesamiento - 45 in GoyesAnthony
# Imágen de procesamiento - 46 in GoyesAnthony
# Imágen de procesamiento - 47 in GoyesAnthony
# Imágen de procesamiento - 48 in GoyesAnthony
# Imágen de procesamiento - 49 in GoyesAnthony
# Imágen de procesamiento - 50 in GoyesAnthony
# Imágen de procesamiento - 51 in GoyesAnthony
# Imágen de procesamiento - 52 in GoyesAnthony
# Imágen de procesamiento - 53 in GoyesAnthony
# Imágen de procesamiento - 54 in GoyesAnthony
# Imágen de procesamiento - 55 in GoyesAnthony
# Imágen de procesamiento - 56 in GoyesAnthony
# Imágen de procesamiento - 57 in GoyesAnthony
# Imágen de procesamiento - 58 in GoyesAnthony
# Imágen de procesamiento - 59 in GoyesAnthony
# Imágen de procesamiento - 60 in GoyesAnthony
# Imágen de procesamiento - 61 in GoyesAnthony
# Imágen de procesamiento - 62 in GoyesAnthony
# Imágen de procesamiento - 63 in GoyesAnthony
# Imágen de procesamiento - 64 in GoyesAnthony
# Imágen de procesamiento - 65 in GoyesAnthony
# Imágen de procesamiento - 66 in GoyesAnthony
# Imágen de procesamiento - 67 in GoyesAnthony
# Imágen de procesamiento - 68 in GoyesAnthony
# Imágen de procesamiento - 69 in GoyesAnthony
# Imágen de procesamiento - 70 in GoyesAnthony
# Imágen de procesamiento - 71 in GoyesAnthony
# Imágen de procesamiento - 72 in GoyesAnthony
# Imágen de procesamiento - 73 in GoyesAnthony
# Imágen de procesamiento - 74 in GoyesAnthony
# Imágen de procesamiento - 75 in GoyesAnthony
# Imágen de procesamiento - 76 in GoyesAnthony
# Imágen de procesamiento - 77 in GoyesAnthony
# Imágen de procesamiento - 78 in GoyesAnthony
# Imágen de procesamiento - 79 in GoyesAnthony
# Imágen de procesamiento - 80 in GoyesAnthony
# Imágen de procesamiento - 81 in GoyesAnthony
# Imágen de procesamiento - 82 in GoyesAnthony
# Imágen de procesamiento - 83 in GoyesAnthony
# Imágen de procesamiento - 84 in GoyesAnthony
# Imágen de procesamiento - 85 in GoyesAnthony
# Imágen de procesamiento - 86 in GoyesAnthony
# Imágen de procesamiento - 87 in GoyesAnthony
# Imágen de procesamiento - 88 in GoyesAnthony
# Imágen de procesamiento - 89 in GoyesAnthony
# Imágen de procesamiento - 90 in GoyesAnthony
# Imágen de procesamiento - 91 in GoyesAnthony
# Imágen de procesamiento - 92 in GoyesAnthony
# Imágen de procesamiento - 93 in GoyesAnthony
# Imágen de procesamiento - 94 in GoyesAnthony
# Imágen de procesamiento - 95 in GoyesAnthony
# Imágen de procesamiento - 96 in GoyesAnthony
# Imágen de procesamiento - 97 in GoyesAnthony
# Imágen de procesamiento - 98 in GoyesAnthony
# Imágen de procesamiento - 99 in GoyesAnthony
# Imágen de procesamiento - 1 in HectorCedeno
# Imágen de procesamiento - 2 in HectorCedeno
# Imágen de procesamiento - 3 in HectorCedeno
# Imágen de procesamiento - 4 in HectorCedeno
# Imágen de procesamiento - 5 in HectorCedeno
# Imágen de procesamiento - 6 in HectorCedeno
# Imágen de procesamiento - 7 in HectorCedeno
# Imágen de procesamiento - 8 in HectorCedeno
# Imágen de procesamiento - 9 in HectorCedeno
# Imágen de procesamiento - 10 in HectorCedeno
# Imágen de procesamiento - 11 in HectorCedeno
# Imágen de procesamiento - 12 in HectorCedeno
# Imágen de procesamiento - 13 in HectorCedeno
# Imágen de procesamiento - 14 in HectorCedeno
# Imágen de procesamiento - 15 in HectorCedeno
# Imágen de procesamiento - 16 in HectorCedeno
# Imágen de procesamiento - 17 in HectorCedeno
# Imágen de procesamiento - 18 in HectorCedeno
# Imágen de procesamiento - 19 in HectorCedeno
# Imágen de procesamiento - 20 in HectorCedeno
# Imágen de procesamiento - 21 in HectorCedeno
# Imágen de procesamiento - 22 in HectorCedeno
# Imágen de procesamiento - 23 in HectorCedeno
# Imágen de procesamiento - 24 in HectorCedeno
# Imágen de procesamiento - 25 in HectorCedeno
# Imágen de procesamiento - 26 in HectorCedeno
# Imágen de procesamiento - 27 in HectorCedeno
# Imágen de procesamiento - 28 in HectorCedeno
# Imágen de procesamiento - 29 in HectorCedeno
# Imágen de procesamiento - 30 in HectorCedeno
# Imágen de procesamiento - 31 in HectorCedeno
# Imágen de procesamiento - 32 in HectorCedeno
# Imágen de procesamiento - 33 in HectorCedeno
# Imágen de procesamiento - 34 in HectorCedeno
# Imágen de procesamiento - 35 in HectorCedeno
# Imágen de procesamiento - 36 in HectorCedeno
# Imágen de procesamiento - 37 in HectorCedeno
# Imágen de procesamiento - 38 in HectorCedeno
# Imágen de procesamiento - 39 in HectorCedeno
# Imágen de procesamiento - 40 in HectorCedeno
# Imágen de procesamiento - 41 in HectorCedeno
# Imágen de procesamiento - 42 in HectorCedeno
# Imágen de procesamiento - 43 in HectorCedeno
# Imágen de procesamiento - 44 in HectorCedeno
# Imágen de procesamiento - 45 in HectorCedeno
# Imágen de procesamiento - 46 in HectorCedeno
# Imágen de procesamiento - 47 in HectorCedeno
# Imágen de procesamiento - 48 in HectorCedeno
# Imágen de procesamiento - 49 in HectorCedeno
# Imágen de procesamiento - 50 in HectorCedeno
# Imágen de procesamiento - 51 in HectorCedeno
# Imágen de procesamiento - 52 in HectorCedeno
# Imágen de procesamiento - 53 in HectorCedeno
# Imágen de procesamiento - 54 in HectorCedeno
# Imágen de procesamiento - 55 in HectorCedeno
# Imágen de procesamiento - 56 in HectorCedeno
# Imágen de procesamiento - 57 in HectorCedeno
# Imágen de procesamiento - 58 in HectorCedeno
# Imágen de procesamiento - 59 in HectorCedeno
# Imágen de procesamiento - 60 in HectorCedeno
# Imágen de procesamiento - 61 in HectorCedeno
# Imágen de procesamiento - 62 in HectorCedeno
# Imágen de procesamiento - 63 in HectorCedeno
# Imágen de procesamiento - 64 in HectorCedeno
# Imágen de procesamiento - 65 in HectorCedeno
# Imágen de procesamiento - 66 in HectorCedeno
# Imágen de procesamiento - 67 in HectorCedeno
# Imágen de procesamiento - 68 in HectorCedeno
# Imágen de procesamiento - 69 in HectorCedeno
# Imágen de procesamiento - 70 in HectorCedeno
# Imágen de procesamiento - 71 in HectorCedeno
# Imágen de procesamiento - 72 in HectorCedeno
# Imágen de procesamiento - 73 in HectorCedeno
# Imágen de procesamiento - 74 in HectorCedeno
# Imágen de procesamiento - 75 in HectorCedeno
# Imágen de procesamiento - 76 in HectorCedeno
# Imágen de procesamiento - 77 in HectorCedeno
# Imágen de procesamiento - 78 in HectorCedeno
# Imágen de procesamiento - 79 in HectorCedeno
# Imágen de procesamiento - 80 in HectorCedeno
# Imágen de procesamiento - 81 in HectorCedeno
# Imágen de procesamiento - 82 in HectorCedeno
# Imágen de procesamiento - 83 in HectorCedeno
# Imágen de procesamiento - 84 in HectorCedeno
# Imágen de procesamiento - 85 in HectorCedeno
# Imágen de procesamiento - 86 in HectorCedeno
# Imágen de procesamiento - 87 in HectorCedeno
# Imágen de procesamiento - 88 in HectorCedeno
# Imágen de procesamiento - 89 in HectorCedeno
# Imágen de procesamiento - 90 in HectorCedeno
# Imágen de procesamiento - 91 in HectorCedeno
# Imágen de procesamiento - 92 in HectorCedeno
# Imágen de procesamiento - 93 in HectorCedeno
# Imágen de procesamiento - 94 in HectorCedeno
# Imágen de procesamiento - 95 in HectorCedeno
# Imágen de procesamiento - 96 in HectorCedeno
# Imágen de procesamiento - 97 in HectorCedeno
# Imágen de procesamiento - 98 in HectorCedeno
# Imágen de procesamiento - 99 in HectorCedeno
# Imágen de procesamiento - 100 in HectorCedeno
# Imágen de procesamiento - 1 in Jhon Zambrano
# Imágen de procesamiento - 2 in Jhon Zambrano
# Imágen de procesamiento - 3 in Jhon Zambrano
# Imágen de procesamiento - 4 in Jhon Zambrano
# Imágen de procesamiento - 5 in Jhon Zambrano
# Imágen de procesamiento - 6 in Jhon Zambrano
# Imágen de procesamiento - 7 in Jhon Zambrano
# Imágen de procesamiento - 8 in Jhon Zambrano
# Imágen de procesamiento - 9 in Jhon Zambrano
# Imágen de procesamiento - 10 in Jhon Zambrano
# Imágen de procesamiento - 11 in Jhon Zambrano
# Imágen de procesamiento - 12 in Jhon Zambrano
# Imágen de procesamiento - 13 in Jhon Zambrano
# Imágen de procesamiento - 14 in Jhon Zambrano
# Imágen de procesamiento - 15 in Jhon Zambrano
# Imágen de procesamiento - 16 in Jhon Zambrano
# Imágen de procesamiento - 17 in Jhon Zambrano
# Imágen de procesamiento - 18 in Jhon Zambrano
# Imágen de procesamiento - 19 in Jhon Zambrano
# Imágen de procesamiento - 20 in Jhon Zambrano
# Imágen de procesamiento - 21 in Jhon Zambrano
# Imágen de procesamiento - 22 in Jhon Zambrano
# Imágen de procesamiento - 23 in Jhon Zambrano
# Imágen de procesamiento - 24 in Jhon Zambrano
# Imágen de procesamiento - 25 in Jhon Zambrano
# Imágen de procesamiento - 26 in Jhon Zambrano
# Imágen de procesamiento - 27 in Jhon Zambrano
# Imágen de procesamiento - 28 in Jhon Zambrano
# Imágen de procesamiento - 29 in Jhon Zambrano
# Imágen de procesamiento - 30 in Jhon Zambrano
# Imágen de procesamiento - 31 in Jhon Zambrano
# Imágen de procesamiento - 32 in Jhon Zambrano
# Imágen de procesamiento - 33 in Jhon Zambrano
# Imágen de procesamiento - 34 in Jhon Zambrano
# Imágen de procesamiento - 35 in Jhon Zambrano
# Imágen de procesamiento - 36 in Jhon Zambrano
# Imágen de procesamiento - 37 in Jhon Zambrano
# Imágen de procesamiento - 38 in Jhon Zambrano
# Imágen de procesamiento - 39 in Jhon Zambrano
# Imágen de procesamiento - 40 in Jhon Zambrano
# Imágen de procesamiento - 41 in Jhon Zambrano
# Imágen de procesamiento - 42 in Jhon Zambrano
# Imágen de procesamiento - 43 in Jhon Zambrano
# Imágen de procesamiento - 44 in Jhon Zambrano
# Imágen de procesamiento - 45 in Jhon Zambrano
# Imágen de procesamiento - 46 in Jhon Zambrano
# Imágen de procesamiento - 47 in Jhon Zambrano
# Imágen de procesamiento - 48 in Jhon Zambrano
# Imágen de procesamiento - 49 in Jhon Zambrano
# Imágen de procesamiento - 50 in Jhon Zambrano
# Imágen de procesamiento - 51 in Jhon Zambrano
# Imágen de procesamiento - 52 in Jhon Zambrano
# Imágen de procesamiento - 53 in Jhon Zambrano
# Imágen de procesamiento - 54 in Jhon Zambrano
# Imágen de procesamiento - 55 in Jhon Zambrano
# Imágen de procesamiento - 56 in Jhon Zambrano
# Imágen de procesamiento - 57 in Jhon Zambrano
# Imágen de procesamiento - 58 in Jhon Zambrano
# Imágen de procesamiento - 59 in Jhon Zambrano
# Imágen de procesamiento - 60 in Jhon Zambrano
# Imágen de procesamiento - 61 in Jhon Zambrano
# Imágen de procesamiento - 62 in Jhon Zambrano
# Imágen de procesamiento - 63 in Jhon Zambrano
# Imágen de procesamiento - 64 in Jhon Zambrano
# Imágen de procesamiento - 65 in Jhon Zambrano
# Imágen de procesamiento - 66 in Jhon Zambrano
# Imágen de procesamiento - 67 in Jhon Zambrano
# Imágen de procesamiento - 68 in Jhon Zambrano
# Imágen de procesamiento - 69 in Jhon Zambrano
# Imágen de procesamiento - 70 in Jhon Zambrano
# Imágen de procesamiento - 71 in Jhon Zambrano
# Imágen de procesamiento - 72 in Jhon Zambrano
# Imágen de procesamiento - 73 in Jhon Zambrano
# Imágen de procesamiento - 74 in Jhon Zambrano
# Imágen de procesamiento - 75 in Jhon Zambrano
# Imágen de procesamiento - 76 in Jhon Zambrano
# Imágen de procesamiento - 77 in Jhon Zambrano
# Imágen de procesamiento - 78 in Jhon Zambrano
# Imágen de procesamiento - 79 in Jhon Zambrano
# Imágen de procesamiento - 80 in Jhon Zambrano
# Imágen de procesamiento - 81 in Jhon Zambrano
# Imágen de procesamiento - 82 in Jhon Zambrano
# Imágen de procesamiento - 83 in Jhon Zambrano
# Imágen de procesamiento - 84 in Jhon Zambrano
# Imágen de procesamiento - 85 in Jhon Zambrano
# Imágen de procesamiento - 86 in Jhon Zambrano
# Imágen de procesamiento - 87 in Jhon Zambrano
# Imágen de procesamiento - 88 in Jhon Zambrano
# Imágen de procesamiento - 89 in Jhon Zambrano
# Imágen de procesamiento - 90 in Jhon Zambrano
# Imágen de procesamiento - 91 in Jhon Zambrano
# Imágen de procesamiento - 92 in Jhon Zambrano
# Imágen de procesamiento - 93 in Jhon Zambrano
# Imágen de procesamiento - 94 in Jhon Zambrano
# Imágen de procesamiento - 95 in Jhon Zambrano
# Imágen de procesamiento - 96 in Jhon Zambrano
# Imágen de procesamiento - 97 in Jhon Zambrano
# Imágen de procesamiento - 98 in Jhon Zambrano
# Imágen de procesamiento - 99 in Jhon Zambrano
# Imágen de procesamiento - 100 in Jhon Zambrano
# Imágen de procesamiento - 101 in Jhon Zambrano
# Imágen de procesamiento - 102 in Jhon Zambrano
# Imágen de procesamiento - 103 in Jhon Zambrano
# Imágen de procesamiento - 104 in Jhon Zambrano
# Imágen de procesamiento - 105 in Jhon Zambrano
# Imágen de procesamiento - 106 in Jhon Zambrano
# Imágen de procesamiento - 107 in Jhon Zambrano
# Imágen de procesamiento - 108 in Jhon Zambrano
# Imágen de procesamiento - 109 in Jhon Zambrano
# Imágen de procesamiento - 110 in Jhon Zambrano
# Imágen de procesamiento - 111 in Jhon Zambrano
# Imágen de procesamiento - 112 in Jhon Zambrano
# Imágen de procesamiento - 113 in Jhon Zambrano
# Imágen de procesamiento - 114 in Jhon Zambrano
# Imágen de procesamiento - 115 in Jhon Zambrano
# Imágen de procesamiento - 116 in Jhon Zambrano
# Imágen de procesamiento - 117 in Jhon Zambrano
# Imágen de procesamiento - 118 in Jhon Zambrano
# Imágen de procesamiento - 119 in Jhon Zambrano
# Imágen de procesamiento - 120 in Jhon Zambrano
# Imágen de procesamiento - 121 in Jhon Zambrano
# Imágen de procesamiento - 122 in Jhon Zambrano
# Imágen de procesamiento - 123 in Jhon Zambrano
# Imágen de procesamiento - 124 in Jhon Zambrano
# Imágen de procesamiento - 125 in Jhon Zambrano
# Imágen de procesamiento - 126 in Jhon Zambrano
# Imágen de procesamiento - 127 in Jhon Zambrano
# Imágen de procesamiento - 128 in Jhon Zambrano
# Imágen de procesamiento - 129 in Jhon Zambrano
# Imágen de procesamiento - 130 in Jhon Zambrano
# Imágen de procesamiento - 1 in Jordan Espinosa
# Imágen de procesamiento - 2 in Jordan Espinosa
# Imágen de procesamiento - 3 in Jordan Espinosa
# Imágen de procesamiento - 4 in Jordan Espinosa
# Imágen de procesamiento - 5 in Jordan Espinosa
# Imágen de procesamiento - 6 in Jordan Espinosa
# Imágen de procesamiento - 7 in Jordan Espinosa
# Imágen de procesamiento - 8 in Jordan Espinosa
# Imágen de procesamiento - 9 in Jordan Espinosa
# Imágen de procesamiento - 10 in Jordan Espinosa
# Imágen de procesamiento - 11 in Jordan Espinosa
# Imágen de procesamiento - 12 in Jordan Espinosa
# Imágen de procesamiento - 13 in Jordan Espinosa
# Imágen de procesamiento - 14 in Jordan Espinosa
# Imágen de procesamiento - 15 in Jordan Espinosa
# Imágen de procesamiento - 16 in Jordan Espinosa
# Imágen de procesamiento - 17 in Jordan Espinosa
# Imágen de procesamiento - 18 in Jordan Espinosa
# Imágen de procesamiento - 19 in Jordan Espinosa
# Imágen de procesamiento - 20 in Jordan Espinosa
# Imágen de procesamiento - 21 in Jordan Espinosa
# Imágen de procesamiento - 22 in Jordan Espinosa
# Imágen de procesamiento - 23 in Jordan Espinosa
# Imágen de procesamiento - 24 in Jordan Espinosa
# Imágen de procesamiento - 25 in Jordan Espinosa
# Imágen de procesamiento - 26 in Jordan Espinosa
# Imágen de procesamiento - 27 in Jordan Espinosa
# Imágen de procesamiento - 28 in Jordan Espinosa
# Imágen de procesamiento - 29 in Jordan Espinosa
# Imágen de procesamiento - 30 in Jordan Espinosa
# Imágen de procesamiento - 31 in Jordan Espinosa
# Imágen de procesamiento - 32 in Jordan Espinosa
# Imágen de procesamiento - 33 in Jordan Espinosa
# Imágen de procesamiento - 34 in Jordan Espinosa
# Imágen de procesamiento - 35 in Jordan Espinosa
# Imágen de procesamiento - 36 in Jordan Espinosa
# Imágen de procesamiento - 37 in Jordan Espinosa
# Imágen de procesamiento - 38 in Jordan Espinosa
# Imágen de procesamiento - 39 in Jordan Espinosa
# Imágen de procesamiento - 40 in Jordan Espinosa
# Imágen de procesamiento - 41 in Jordan Espinosa
# Imágen de procesamiento - 42 in Jordan Espinosa
# Imágen de procesamiento - 43 in Jordan Espinosa
# Imágen de procesamiento - 44 in Jordan Espinosa
# Imágen de procesamiento - 45 in Jordan Espinosa
# Imágen de procesamiento - 46 in Jordan Espinosa
# Imágen de procesamiento - 47 in Jordan Espinosa
# Imágen de procesamiento - 48 in Jordan Espinosa
# Imágen de procesamiento - 49 in Jordan Espinosa
# Imágen de procesamiento - 50 in Jordan Espinosa
# Imágen de procesamiento - 51 in Jordan Espinosa
# Imágen de procesamiento - 52 in Jordan Espinosa
# Imágen de procesamiento - 53 in Jordan Espinosa
# Imágen de procesamiento - 54 in Jordan Espinosa
# Imágen de procesamiento - 55 in Jordan Espinosa
# Imágen de procesamiento - 56 in Jordan Espinosa
# Imágen de procesamiento - 57 in Jordan Espinosa
# Imágen de procesamiento - 58 in Jordan Espinosa
# Imágen de procesamiento - 59 in Jordan Espinosa
# Imágen de procesamiento - 60 in Jordan Espinosa
# Imágen de procesamiento - 61 in Jordan Espinosa
# Imágen de procesamiento - 62 in Jordan Espinosa
# Imágen de procesamiento - 63 in Jordan Espinosa
# Imágen de procesamiento - 64 in Jordan Espinosa
# Imágen de procesamiento - 65 in Jordan Espinosa
# Imágen de procesamiento - 66 in Jordan Espinosa
# Imágen de procesamiento - 67 in Jordan Espinosa
# Imágen de procesamiento - 68 in Jordan Espinosa
# Imágen de procesamiento - 69 in Jordan Espinosa
# Imágen de procesamiento - 70 in Jordan Espinosa
# Imágen de procesamiento - 71 in Jordan Espinosa
# Imágen de procesamiento - 72 in Jordan Espinosa
# Imágen de procesamiento - 73 in Jordan Espinosa
# Imágen de procesamiento - 74 in Jordan Espinosa
# Imágen de procesamiento - 75 in Jordan Espinosa
# Imágen de procesamiento - 76 in Jordan Espinosa
# Imágen de procesamiento - 77 in Jordan Espinosa
# Imágen de procesamiento - 78 in Jordan Espinosa
# Imágen de procesamiento - 79 in Jordan Espinosa
# Imágen de procesamiento - 80 in Jordan Espinosa
# Imágen de procesamiento - 1 in Jorge Borrero
# Imágen de procesamiento - 2 in Jorge Borrero
# Imágen de procesamiento - 3 in Jorge Borrero
# Imágen de procesamiento - 4 in Jorge Borrero
# Imágen de procesamiento - 5 in Jorge Borrero
# Imágen de procesamiento - 6 in Jorge Borrero
# Imágen de procesamiento - 7 in Jorge Borrero
# Imágen de procesamiento - 8 in Jorge Borrero
# Imágen de procesamiento - 9 in Jorge Borrero
# Imágen de procesamiento - 10 in Jorge Borrero
# Imágen de procesamiento - 11 in Jorge Borrero
# Imágen de procesamiento - 12 in Jorge Borrero
# Imágen de procesamiento - 13 in Jorge Borrero
# Imágen de procesamiento - 14 in Jorge Borrero
# Imágen de procesamiento - 15 in Jorge Borrero
# Imágen de procesamiento - 16 in Jorge Borrero
# Imágen de procesamiento - 17 in Jorge Borrero
# Imágen de procesamiento - 18 in Jorge Borrero
# Imágen de procesamiento - 19 in Jorge Borrero
# Imágen de procesamiento - 20 in Jorge Borrero
# Imágen de procesamiento - 21 in Jorge Borrero
# Imágen de procesamiento - 22 in Jorge Borrero
# Imágen de procesamiento - 23 in Jorge Borrero
# Imágen de procesamiento - 24 in Jorge Borrero
# Imágen de procesamiento - 25 in Jorge Borrero
# Imágen de procesamiento - 26 in Jorge Borrero
# Imágen de procesamiento - 27 in Jorge Borrero
# Imágen de procesamiento - 28 in Jorge Borrero
# Imágen de procesamiento - 29 in Jorge Borrero
# Imágen de procesamiento - 30 in Jorge Borrero
# Imágen de procesamiento - 1 in JoseRuiz
# Imágen de procesamiento - 2 in JoseRuiz
# Imágen de procesamiento - 3 in JoseRuiz
# Imágen de procesamiento - 4 in JoseRuiz
# Imágen de procesamiento - 5 in JoseRuiz
# Imágen de procesamiento - 6 in JoseRuiz
# Imágen de procesamiento - 7 in JoseRuiz
# Imágen de procesamiento - 8 in JoseRuiz
# Imágen de procesamiento - 9 in JoseRuiz
# Imágen de procesamiento - 10 in JoseRuiz
# Imágen de procesamiento - 11 in JoseRuiz
# Imágen de procesamiento - 12 in JoseRuiz
# Imágen de procesamiento - 13 in JoseRuiz
# Imágen de procesamiento - 14 in JoseRuiz
# Imágen de procesamiento - 15 in JoseRuiz
# Imágen de procesamiento - 16 in JoseRuiz
# Imágen de procesamiento - 17 in JoseRuiz
# Imágen de procesamiento - 18 in JoseRuiz
# Imágen de procesamiento - 19 in JoseRuiz
# Imágen de procesamiento - 20 in JoseRuiz
# Imágen de procesamiento - 21 in JoseRuiz
# Imágen de procesamiento - 22 in JoseRuiz
# Imágen de procesamiento - 23 in JoseRuiz
# Imágen de procesamiento - 24 in JoseRuiz
# Imágen de procesamiento - 25 in JoseRuiz
# Imágen de procesamiento - 26 in JoseRuiz
# Imágen de procesamiento - 27 in JoseRuiz
# Imágen de procesamiento - 28 in JoseRuiz
# Imágen de procesamiento - 29 in JoseRuiz
# Imágen de procesamiento - 30 in JoseRuiz
# Imágen de procesamiento - 31 in JoseRuiz
# Imágen de procesamiento - 32 in JoseRuiz
# Imágen de procesamiento - 33 in JoseRuiz
# Imágen de procesamiento - 34 in JoseRuiz
# Imágen de procesamiento - 35 in JoseRuiz
# Imágen de procesamiento - 36 in JoseRuiz
# Imágen de procesamiento - 37 in JoseRuiz
# Imágen de procesamiento - 38 in JoseRuiz
# Imágen de procesamiento - 39 in JoseRuiz
# Imágen de procesamiento - 40 in JoseRuiz
# Imágen de procesamiento - 41 in JoseRuiz
# Imágen de procesamiento - 42 in JoseRuiz
# Imágen de procesamiento - 43 in JoseRuiz
# Imágen de procesamiento - 44 in JoseRuiz
# Imágen de procesamiento - 45 in JoseRuiz
# Imágen de procesamiento - 46 in JoseRuiz
# Imágen de procesamiento - 47 in JoseRuiz
# Imágen de procesamiento - 48 in JoseRuiz
# Imágen de procesamiento - 49 in JoseRuiz
# Imágen de procesamiento - 50 in JoseRuiz
# Imágen de procesamiento - 51 in JoseRuiz
# Imágen de procesamiento - 52 in JoseRuiz
# Imágen de procesamiento - 53 in JoseRuiz
# Imágen de procesamiento - 54 in JoseRuiz
# Imágen de procesamiento - 55 in JoseRuiz
# Imágen de procesamiento - 56 in JoseRuiz
# Imágen de procesamiento - 57 in JoseRuiz
# Imágen de procesamiento - 58 in JoseRuiz
# Imágen de procesamiento - 59 in JoseRuiz
# Imágen de procesamiento - 60 in JoseRuiz
# Imágen de procesamiento - 61 in JoseRuiz
# Imágen de procesamiento - 62 in JoseRuiz
# Imágen de procesamiento - 63 in JoseRuiz
# Imágen de procesamiento - 64 in JoseRuiz
# Imágen de procesamiento - 65 in JoseRuiz
# Imágen de procesamiento - 66 in JoseRuiz
# Imágen de procesamiento - 67 in JoseRuiz
# Imágen de procesamiento - 68 in JoseRuiz
# Imágen de procesamiento - 69 in JoseRuiz
# Imágen de procesamiento - 70 in JoseRuiz
# Imágen de procesamiento - 71 in JoseRuiz
# Imágen de procesamiento - 72 in JoseRuiz
# Imágen de procesamiento - 73 in JoseRuiz
# Imágen de procesamiento - 74 in JoseRuiz
# Imágen de procesamiento - 75 in JoseRuiz
# Imágen de procesamiento - 76 in JoseRuiz
# ...
# Imágen de procesamiento - 78 in RivasSelena
# Imágen de procesamiento - 79 in RivasSelena
# Imágen de procesamiento - 80 in RivasSelena
# Imágen de procesamiento - 81 in RivasSelena
# Imágen de procesamiento - 82 in RivasSelena
# Imágen de procesamiento - 83 in RivasSelena
# Imágen de procesamiento - 84 in RivasSelena
# Imágen de procesamiento - 85 in RivasSelena
# Imágen de procesamiento - 86 in RivasSelena
# Imágen de procesamiento - 87 in RivasSelena
# Imágen de procesamiento - 88 in RivasSelena
# Imágen de procesamiento - 89 in RivasSelena
# Imágen de procesamiento - 90 in RivasSelena
# Imágen de procesamiento - 91 in RivasSelena
# Imágen de procesamiento - 92 in RivasSelena
# Imágen de procesamiento - 93 in RivasSelena
# Imágen de procesamiento - 94 in RivasSelena
# Imágen de procesamiento - 95 in RivasSelena
# Imágen de procesamiento - 96 in RivasSelena
# Imágen de procesamiento - 97 in RivasSelena
# Imágen de procesamiento - 98 in RivasSelena
# Imágen de procesamiento - 99 in RivasSelena
# Imágen de procesamiento - 100 in RivasSelena
# Imágen de procesamiento - 101 in RivasSelena
# Imágen de procesamiento - 102 in RivasSelena
# Imágen de procesamiento - 103 in RivasSelena
# Imágen de procesamiento - 104 in RivasSelena
# Imágen de procesamiento - 105 in RivasSelena
# Imágen de procesamiento - 106 in RivasSelena
# Imágen de procesamiento - 107 in RivasSelena
# Imágen de procesamiento - 108 in RivasSelena
# Imágen de procesamiento - 109 in RivasSelena
# Imágen de procesamiento - 1 in SalazarJohana
# Imágen de procesamiento - 2 in SalazarJohana
# Imágen de procesamiento - 3 in SalazarJohana
# Imágen de procesamiento - 4 in SalazarJohana
# Imágen de procesamiento - 5 in SalazarJohana
# Imágen de procesamiento - 6 in SalazarJohana
# Imágen de procesamiento - 7 in SalazarJohana
# Imágen de procesamiento - 8 in SalazarJohana
# Imágen de procesamiento - 9 in SalazarJohana
# Imágen de procesamiento - 10 in SalazarJohana
# Imágen de procesamiento - 11 in SalazarJohana
# Imágen de procesamiento - 12 in SalazarJohana
# Imágen de procesamiento - 13 in SalazarJohana
# Imágen de procesamiento - 14 in SalazarJohana
# Imágen de procesamiento - 15 in SalazarJohana
# Imágen de procesamiento - 16 in SalazarJohana
# Imágen de procesamiento - 17 in SalazarJohana
# Imágen de procesamiento - 18 in SalazarJohana
# Imágen de procesamiento - 19 in SalazarJohana
# Imágen de procesamiento - 20 in SalazarJohana
# Imágen de procesamiento - 21 in SalazarJohana
# Imágen de procesamiento - 22 in SalazarJohana
# Imágen de procesamiento - 23 in SalazarJohana
# Imágen de procesamiento - 24 in SalazarJohana
# Imágen de procesamiento - 25 in SalazarJohana
# Imágen de procesamiento - 26 in SalazarJohana
# Imágen de procesamiento - 27 in SalazarJohana
# Imágen de procesamiento - 28 in SalazarJohana
# Imágen de procesamiento - 29 in SalazarJohana
# Imágen de procesamiento - 30 in SalazarJohana
# Imágen de procesamiento - 31 in SalazarJohana
# Imágen de procesamiento - 32 in SalazarJohana
# Imágen de procesamiento - 33 in SalazarJohana
# Imágen de procesamiento - 34 in SalazarJohana
# Imágen de procesamiento - 35 in SalazarJohana
# Imágen de procesamiento - 36 in SalazarJohana
# Imágen de procesamiento - 37 in SalazarJohana
# Imágen de procesamiento - 38 in SalazarJohana
# Imágen de procesamiento - 39 in SalazarJohana
# Imágen de procesamiento - 40 in SalazarJohana
# Imágen de procesamiento - 41 in SalazarJohana
# Imágen de procesamiento - 42 in SalazarJohana
# Imágen de procesamiento - 43 in SalazarJohana
# Imágen de procesamiento - 44 in SalazarJohana
# Imágen de procesamiento - 45 in SalazarJohana
# Imágen de procesamiento - 46 in SalazarJohana
# Imágen de procesamiento - 47 in SalazarJohana
# Imágen de procesamiento - 48 in SalazarJohana
# Imágen de procesamiento - 49 in SalazarJohana
# Imágen de procesamiento - 50 in SalazarJohana
# Imágen de procesamiento - 1 in Solano Wilmer
# Imágen de procesamiento - 2 in Solano Wilmer
# Imágen de procesamiento - 3 in Solano Wilmer
# Imágen de procesamiento - 4 in Solano Wilmer
# Imágen de procesamiento - 5 in Solano Wilmer
# Imágen de procesamiento - 6 in Solano Wilmer
# Imágen de procesamiento - 7 in Solano Wilmer
# Imágen de procesamiento - 8 in Solano Wilmer
# Imágen de procesamiento - 9 in Solano Wilmer
# Imágen de procesamiento - 10 in Solano Wilmer
# Imágen de procesamiento - 11 in Solano Wilmer
# Imágen de procesamiento - 12 in Solano Wilmer
# Imágen de procesamiento - 13 in Solano Wilmer
# Imágen de procesamiento - 14 in Solano Wilmer
# Imágen de procesamiento - 15 in Solano Wilmer
# Imágen de procesamiento - 16 in Solano Wilmer
# Imágen de procesamiento - 17 in Solano Wilmer
# Imágen de procesamiento - 18 in Solano Wilmer
# Imágen de procesamiento - 19 in Solano Wilmer
# Imágen de procesamiento - 20 in Solano Wilmer
# Imágen de procesamiento - 21 in Solano Wilmer
# Imágen de procesamiento - 22 in Solano Wilmer
# Imágen de procesamiento - 23 in Solano Wilmer
# Imágen de procesamiento - 24 in Solano Wilmer
# Imágen de procesamiento - 25 in Solano Wilmer
# Imágen de procesamiento - 26 in Solano Wilmer
# Imágen de procesamiento - 27 in Solano Wilmer
# Imágen de procesamiento - 28 in Solano Wilmer
# Imágen de procesamiento - 29 in Solano Wilmer
# Imágen de procesamiento - 30 in Solano Wilmer
# Imágen de procesamiento - 31 in Solano Wilmer
# Imágen de procesamiento - 32 in Solano Wilmer
# Imágen de procesamiento - 33 in Solano Wilmer
# Imágen de procesamiento - 34 in Solano Wilmer
# Imágen de procesamiento - 35 in Solano Wilmer
# Imágen de procesamiento - 36 in Solano Wilmer
# Imágen de procesamiento - 37 in Solano Wilmer
# Imágen de procesamiento - 38 in Solano Wilmer
# Imágen de procesamiento - 39 in Solano Wilmer
# Imágen de procesamiento - 40 in Solano Wilmer
# Imágen de procesamiento - 41 in Solano Wilmer
# Imágen de procesamiento - 42 in Solano Wilmer
# Imágen de procesamiento - 43 in Solano Wilmer
# Imágen de procesamiento - 44 in Solano Wilmer
# Imágen de procesamiento - 45 in Solano Wilmer
# Imágen de procesamiento - 46 in Solano Wilmer
# Imágen de procesamiento - 47 in Solano Wilmer
# Imágen de procesamiento - 48 in Solano Wilmer
# Imágen de procesamiento - 49 in Solano Wilmer
# Imágen de procesamiento - 50 in Solano Wilmer
# Imágen de procesamiento - 51 in Solano Wilmer
# Imágen de procesamiento - 52 in Solano Wilmer
# Imágen de procesamiento - 53 in Solano Wilmer
# Imágen de procesamiento - 54 in Solano Wilmer
# Imágen de procesamiento - 55 in Solano Wilmer
# Imágen de procesamiento - 56 in Solano Wilmer
# Imágen de procesamiento - 57 in Solano Wilmer
# Imágen de procesamiento - 58 in Solano Wilmer
# Imágen de procesamiento - 59 in Solano Wilmer
# Imágen de procesamiento - 60 in Solano Wilmer
# Imágen de procesamiento - 61 in Solano Wilmer
# Imágen de procesamiento - 62 in Solano Wilmer
# Imágen de procesamiento - 63 in Solano Wilmer
# Imágen de procesamiento - 64 in Solano Wilmer
# Imágen de procesamiento - 65 in Solano Wilmer
# Imágen de procesamiento - 66 in Solano Wilmer
# Imágen de procesamiento - 67 in Solano Wilmer
# Imágen de procesamiento - 68 in Solano Wilmer
# Imágen de procesamiento - 69 in Solano Wilmer
# Imágen de procesamiento - 70 in Solano Wilmer
# Imágen de procesamiento - 71 in Solano Wilmer
# Imágen de procesamiento - 72 in Solano Wilmer
# Imágen de procesamiento - 73 in Solano Wilmer
# Imágen de procesamiento - 74 in Solano Wilmer
# Imágen de procesamiento - 75 in Solano Wilmer
# Imágen de procesamiento - 76 in Solano Wilmer
# Imágen de procesamiento - 77 in Solano Wilmer
# Imágen de procesamiento - 78 in Solano Wilmer
# Imágen de procesamiento - 79 in Solano Wilmer
# Imágen de procesamiento - 80 in Solano Wilmer
# Imágen de procesamiento - 1 in SolorzanoBryan
# Imágen de procesamiento - 2 in SolorzanoBryan
# Imágen de procesamiento - 3 in SolorzanoBryan
# Imágen de procesamiento - 4 in SolorzanoBryan
# Imágen de procesamiento - 5 in SolorzanoBryan
# Imágen de procesamiento - 6 in SolorzanoBryan
# Imágen de procesamiento - 7 in SolorzanoBryan
# Imágen de procesamiento - 8 in SolorzanoBryan
# Imágen de procesamiento - 9 in SolorzanoBryan
# Imágen de procesamiento - 10 in SolorzanoBryan
# Imágen de procesamiento - 11 in SolorzanoBryan
# Imágen de procesamiento - 12 in SolorzanoBryan
# Imágen de procesamiento - 13 in SolorzanoBryan
# Imágen de procesamiento - 14 in SolorzanoBryan
# Imágen de procesamiento - 15 in SolorzanoBryan
# Imágen de procesamiento - 16 in SolorzanoBryan
# Imágen de procesamiento - 17 in SolorzanoBryan
# Imágen de procesamiento - 18 in SolorzanoBryan
# Imágen de procesamiento - 19 in SolorzanoBryan
# Imágen de procesamiento - 20 in SolorzanoBryan
# Imágen de procesamiento - 21 in SolorzanoBryan
# Imágen de procesamiento - 22 in SolorzanoBryan
# Imágen de procesamiento - 23 in SolorzanoBryan
# Imágen de procesamiento - 24 in SolorzanoBryan
# Imágen de procesamiento - 25 in SolorzanoBryan
# Imágen de procesamiento - 26 in SolorzanoBryan
# Imágen de procesamiento - 27 in SolorzanoBryan
# Imágen de procesamiento - 28 in SolorzanoBryan
# Imágen de procesamiento - 29 in SolorzanoBryan
# Imágen de procesamiento - 30 in SolorzanoBryan
# Imágen de procesamiento - 31 in SolorzanoBryan
# Imágen de procesamiento - 32 in SolorzanoBryan
# Imágen de procesamiento - 33 in SolorzanoBryan
# Imágen de procesamiento - 34 in SolorzanoBryan
# Imágen de procesamiento - 35 in SolorzanoBryan
# Imágen de procesamiento - 36 in SolorzanoBryan
# Imágen de procesamiento - 37 in SolorzanoBryan
# Imágen de procesamiento - 38 in SolorzanoBryan
# Imágen de procesamiento - 39 in SolorzanoBryan
# Imágen de procesamiento - 40 in SolorzanoBryan
# Imágen de procesamiento - 41 in SolorzanoBryan
# Imágen de procesamiento - 42 in SolorzanoBryan
# Imágen de procesamiento - 43 in SolorzanoBryan
# Imágen de procesamiento - 44 in SolorzanoBryan
# Imágen de procesamiento - 45 in SolorzanoBryan
# Imágen de procesamiento - 46 in SolorzanoBryan
# Imágen de procesamiento - 47 in SolorzanoBryan
# Imágen de procesamiento - 48 in SolorzanoBryan
# Imágen de procesamiento - 49 in SolorzanoBryan
# Imágen de procesamiento - 50 in SolorzanoBryan
# Imágen de procesamiento - 51 in SolorzanoBryan
# Imágen de procesamiento - 52 in SolorzanoBryan
# Imágen de procesamiento - 53 in SolorzanoBryan
# Imágen de procesamiento - 54 in SolorzanoBryan
# Imágen de procesamiento - 55 in SolorzanoBryan
# Imágen de procesamiento - 56 in SolorzanoBryan
# Imágen de procesamiento - 57 in SolorzanoBryan
# Imágen de procesamiento - 58 in SolorzanoBryan
# Imágen de procesamiento - 59 in SolorzanoBryan
# Imágen de procesamiento - 60 in SolorzanoBryan
# Imágen de procesamiento - 61 in SolorzanoBryan
# Imágen de procesamiento - 62 in SolorzanoBryan
# Imágen de procesamiento - 63 in SolorzanoBryan
# Imágen de procesamiento - 64 in SolorzanoBryan
# Imágen de procesamiento - 65 in SolorzanoBryan
# Imágen de procesamiento - 66 in SolorzanoBryan
# Imágen de procesamiento - 67 in SolorzanoBryan
# Imágen de procesamiento - 68 in SolorzanoBryan
# Imágen de procesamiento - 69 in SolorzanoBryan
# Imágen de procesamiento - 70 in SolorzanoBryan
# Imágen de procesamiento - 71 in SolorzanoBryan
# Imágen de procesamiento - 72 in SolorzanoBryan
# Imágen de procesamiento - 73 in SolorzanoBryan
# Imágen de procesamiento - 74 in SolorzanoBryan
# Imágen de procesamiento - 75 in SolorzanoBryan
# Imágen de procesamiento - 76 in SolorzanoBryan
# Imágen de procesamiento - 77 in SolorzanoBryan
# Imágen de procesamiento - 78 in SolorzanoBryan
# Imágen de procesamiento - 79 in SolorzanoBryan
# Imágen de procesamiento - 80 in SolorzanoBryan
# Imágen de procesamiento - 81 in SolorzanoBryan
# Imágen de procesamiento - 82 in SolorzanoBryan
# Imágen de procesamiento - 83 in SolorzanoBryan
# Imágen de procesamiento - 84 in SolorzanoBryan
# Imágen de procesamiento - 85 in SolorzanoBryan
# Imágen de procesamiento - 86 in SolorzanoBryan
# Imágen de procesamiento - 87 in SolorzanoBryan
# Imágen de procesamiento - 88 in SolorzanoBryan
# Imágen de procesamiento - 89 in SolorzanoBryan
# Imágen de procesamiento - 1 in VinicioBorja
# Imágen de procesamiento - 2 in VinicioBorja
# Imágen de procesamiento - 3 in VinicioBorja
# Imágen de procesamiento - 4 in VinicioBorja
# Imágen de procesamiento - 5 in VinicioBorja
# Imágen de procesamiento - 6 in VinicioBorja
# Imágen de procesamiento - 7 in VinicioBorja
# Imágen de procesamiento - 8 in VinicioBorja
# Imágen de procesamiento - 9 in VinicioBorja
# Imágen de procesamiento - 10 in VinicioBorja
# Imágen de procesamiento - 11 in VinicioBorja
# Imágen de procesamiento - 12 in VinicioBorja
# Imágen de procesamiento - 13 in VinicioBorja
# Imágen de procesamiento - 14 in VinicioBorja
# Imágen de procesamiento - 15 in VinicioBorja
# Imágen de procesamiento - 16 in VinicioBorja
# Imágen de procesamiento - 17 in VinicioBorja
# Imágen de procesamiento - 18 in VinicioBorja
# Imágen de procesamiento - 19 in VinicioBorja
# Imágen de procesamiento - 20 in VinicioBorja
# Imágen de procesamiento - 21 in VinicioBorja
# Imágen de procesamiento - 22 in VinicioBorja
# Imágen de procesamiento - 23 in VinicioBorja
# Imágen de procesamiento - 24 in VinicioBorja
# Imágen de procesamiento - 25 in VinicioBorja
# Imágen de procesamiento - 26 in VinicioBorja
# Imágen de procesamiento - 27 in VinicioBorja
# Imágen de procesamiento - 28 in VinicioBorja
# Imágen de procesamiento - 29 in VinicioBorja
# Imágen de procesamiento - 30 in VinicioBorja
# Imágen de procesamiento - 31 in VinicioBorja
# Imágen de procesamiento - 32 in VinicioBorja
# Imágen de procesamiento - 33 in VinicioBorja
# Imágen de procesamiento - 34 in VinicioBorja
# Imágen de procesamiento - 35 in VinicioBorja
# Imágen de procesamiento - 36 in VinicioBorja
# Imágen de procesamiento - 37 in VinicioBorja
# Imágen de procesamiento - 38 in VinicioBorja
# Imágen de procesamiento - 39 in VinicioBorja
# Imágen de procesamiento - 40 in VinicioBorja
# Imágen de procesamiento - 41 in VinicioBorja
# Imágen de procesamiento - 42 in VinicioBorja
# Imágen de procesamiento - 43 in VinicioBorja
# Imágen de procesamiento - 44 in VinicioBorja
# Imágen de procesamiento - 45 in VinicioBorja
# Imágen de procesamiento - 46 in VinicioBorja
# Imágen de procesamiento - 47 in VinicioBorja
# Imágen de procesamiento - 48 in VinicioBorja
# Imágen de procesamiento - 49 in VinicioBorja
# Imágen de procesamiento - 50 in VinicioBorja
# Imágen de procesamiento - 51 in VinicioBorja
# Imágen de procesamiento - 52 in VinicioBorja
# Imágen de procesamiento - 53 in VinicioBorja
# Imágen de procesamiento - 54 in VinicioBorja
# Imágen de procesamiento - 55 in VinicioBorja
# Imágen de procesamiento - 56 in VinicioBorja
# Imágen de procesamiento - 57 in VinicioBorja
# Imágen de procesamiento - 58 in VinicioBorja
# Imágen de procesamiento - 59 in VinicioBorja
# Imágen de procesamiento - 60 in VinicioBorja
# Imágen de procesamiento - 61 in VinicioBorja
# Imágen de procesamiento - 62 in VinicioBorja
# Imágen de procesamiento - 63 in VinicioBorja
# Imágen de procesamiento - 64 in VinicioBorja
# Imágen de procesamiento - 65 in VinicioBorja
# Imágen de procesamiento - 66 in VinicioBorja
# Imágen de procesamiento - 67 in VinicioBorja
# Imágen de procesamiento - 68 in VinicioBorja
# Imágen de procesamiento - 69 in VinicioBorja
# Imágen de procesamiento - 70 in VinicioBorja
# Imágen de procesamiento - 71 in VinicioBorja
# Imágen de procesamiento - 72 in VinicioBorja
# Imágen de procesamiento - 73 in VinicioBorja
# Imágen de procesamiento - 74 in VinicioBorja
# Imágen de procesamiento - 75 in VinicioBorja
# Imágen de procesamiento - 76 in VinicioBorja
# Imágen de procesamiento - 77 in VinicioBorja
# Imágen de procesamiento - 78 in VinicioBorja
# Imágen de procesamiento - 79 in VinicioBorja
# Imágen de procesamiento - 80 in VinicioBorja
# Imágen de procesamiento - 81 in VinicioBorja
# Imágen de procesamiento - 82 in VinicioBorja
# Imágen de procesamiento - 83 in VinicioBorja
# Imágen de procesamiento - 84 in VinicioBorja
# Imágen de procesamiento - 85 in VinicioBorja
# Imágen de procesamiento - 86 in VinicioBorja
# Imágen de procesamiento - 87 in VinicioBorja
# Imágen de procesamiento - 88 in VinicioBorja
# Imágen de procesamiento - 89 in VinicioBorja
# Imágen de procesamiento - 90 in VinicioBorja
# Imágen de procesamiento - 91 in VinicioBorja
# Imágen de procesamiento - 92 in VinicioBorja
# Imágen de procesamiento - 93 in VinicioBorja
# Imágen de procesamiento - 94 in VinicioBorja
# Imágen de procesamiento - 95 in VinicioBorja
# Imágen de procesamiento - 96 in VinicioBorja
# Imágen de procesamiento - 97 in VinicioBorja
# Imágen de procesamiento - 98 in VinicioBorja
# Imágen de procesamiento - 99 in VinicioBorja

# %% [markdown]
# # Carga y exploración de datos

# %%
"""Dirección de donde se encuentran las imágenes con las que se va a trabajar"""
fpath = './PROYECTOIA-U3_eliminarBG'
random_seed = 9
"""Imprimiendo el nombre de las categorías y el número"""
categories = os.listdir(fpath)
print("Listar las categorías = ",categories,"\n\nNúmero de categorías = ", len(categories))
# Out:
# Listar las categorías =  ['Ariel Chabla', 'ArroboMercy', 'BarraganSteven', 'CevallosJoan', 'EnriquezSelena', 'GenesisHeredia', 'GoyesAnthony', 'HectorCedeno', 'Jhon Zambrano', 'Jordan Espinosa', 'Jorge Borrero', 'JoseRuiz', 'LucioCarlos', 'MosqueraLucy', 'Nataly Acosta', 'OlallaLuis', 'ParragaMariaJose', 'PauteKevin', 'Raymond Davila', 'RivasSelena', 'SalazarJohana', 'Solano Wilmer', 'SolorzanoBryan', 'VinicioBorja']
#
# Número de categorías =  24

# %%
"""Función para cargas las imágenes y etiquetas que recibe las categorías"""
def load_images_and_labels(categories):
    img_lst=[]
    labels=[]
    for index, category in enumerate(categories):
        for image_name in os.listdir(fpath+"/"+category):
            """Características de las imágenes"""
            IMAGE_SIZE=(192,192)
            img = cv2.imread(fpath+"/"+category+"/"+image_name)
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img=cv2.resize(img,IMAGE_SIZE)
            
            """Creando array de imágenes"""
            img_array = Image.fromarray(img, 'RGB')
            
            img_lst.append(np.array(img_array))
            
            labels.append(index)
    return img_lst, labels

images, labels = load_images_and_labels(categories)
"""Presentando el número de etiquetas e imágenes que han sido cargadas"""
print("No. de imagenes cargadas = ",len(images),"\nNo. de etiquetas cargadas = ",len(labels))
print(type(images),type(labels))
# Out:
# No. de imagenes cargadas =  2074
# No. de etiquetas cargadas =  2074
# <class 'list'> <class 'list'>

# %%
"""Imagenes y etiquetas"""
images = np.array(images)
labels = np.array(labels)

print("Figura imagenes = ",images.shape,"\nFigura etiquetas = ",labels.shape)
print(type(images),type(labels))
# Out:
# Figura imagenes =  (2074, 192, 192, 3)
# Figura etiquetas =  (2074,)
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>

# %%
"""Función para mostrar imágenes aleatorias que recieben las etiquetas e imágenes"""
def display_rand_images(images, labels):
    plt.figure(1 , figsize = (19 , 10))
    n = 0 
    for i in range(9):
        n += 1 
        r = np.random.randint(0 , images.shape[0] , 1)
        
        plt.subplot(3 , 3 , n)
        plt.subplots_adjust(hspace = 0.3 , wspace = 0.3)
        plt.imshow(images[r[0]])
        
        plt.title('Personas : {}'.format(labels[r[0]]))
        plt.xticks([])
        plt.yticks([])
        
    plt.show()
    
display_rand_images(images, labels)

# %% [markdown]
# # Preparar datos para entrenar el modelo CNN

# %%
#1-paso en el barajado de datos

#obtener números igualmente espaciados en un rango dado
n = np.arange(images.shape[0])
print("'n' valores antes de barajar = ",n)

#mezclar todos los valores igualmente espaciados en la lista 'n'
np.random.seed(random_seed)
np.random.shuffle(n)
print("\n'n' valores despues de barajar= ",n)
# Out:
# 'n' valores antes de barajar =  [   0    1    2 ... 2071 2072 2073]
#
# 'n' valores despues de barajar=  [ 131  216 1786 ...  501  348  382]

# %%
#2-paso en el barajado de datos

#barajar las imágenes y los datos de las etiquetas correspondientes en ambas listas
images = images[n]
labels = labels[n]

print("Forma de las imagenes despues de barajar = ",images.shape,"\nEtiquetas despues de barajar = ",labels.shape)
# Out:
# Forma de las imagenes despues de barajar =  (2074, 192, 192, 3)
# Etiquetas despues de barajar =  (2074,)

# %%
"""Forma de imágenes"""
images = images.astype(np.float32)
labels = labels.astype(np.int32)
images = images/255
print("Forma de las imágenes después de la normalización = ",images.shape)
# Out:
# Forma de las imágenes después de la normalización =  (2074, 192, 192, 3)

# %%
display_rand_images(images, labels)

# %%
"""Variables de entrenamiento y prueba"""
train_ds, test_ds, train_labels, test_labels = train_test_split(images, labels, test_size = 0.2, random_state = random_seed)

print("enternamiento_ds forma = ",train_ds.shape)
print("entrenamiento_etiqueta forma = ",train_labels.shape)
print("\nprueba_ds forma = ",test_ds.shape)
print("prueba_etiqueta forma = ",test_labels.shape)
# Out:
# enternamiento_ds forma =  (1659, 192, 192, 3)
# entrenamiento_etiqueta forma =  (1659,)
#
# prueba_ds forma =  (415, 192, 192, 3)
# prueba_etiqueta forma =  (415,)

# %%
display_rand_images(train_ds, train_labels)

# %%
## Cambiar el tamaño de las imágenes
train_ds = tf.image.resize(train_ds, (227, 227))
test_ds = tf.image.resize(test_ds, (227, 227)) #AQUI ESTABAN 150

# %% [markdown]
# AQUI DEBE DE COMENZAR EL MODELO

# %% [markdown]
# # PCA

# %%
from keras.models import Model, Sequential
from sklearn import preprocessing
from keras.utils import to_categorical
from sklearn.decomposition import PCA
from keras.applications.vgg16 import VGG16
from keras.layers import  Input

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
le.fit(test_labels)
test_labels_encoded = le.transform(test_labels)
le.fit(train_labels)
train_labels_encoded = le.transform(train_labels)

# %%
#Split data into test and train datasets (already split but assigning to meaningful convention)
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size = 0.2, random_state = random_seed)
x_train, x_test = x_train / 255.0, x_test / 255.0
y_train_one_hot = to_categorical(y_train)
y_test_one_hot = to_categorical(y_test)

# %%
#SIZE = 192  
#VGG_model = VGG16(weights='imagenet', include_top=False, input_shape=(SIZE, SIZE, 3))
#for layer in VGG_model.layers:
#    layer.trainable = False
#VGG_model.summary() 
model=keras.models.Sequential([
    keras.layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(192,192,3)),#Implementación de la primera capa de convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion para mitigar los efectos del gradiente estandarizando y normalizando los valores de entrada
    keras.layers.MaxPool2D(pool_size=(2,2)), #Capa de MaxPooling con una ventana de 2x2
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),#Capa de Convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.MaxPool2D(pool_size=(3,3)), #Capa de MaxPooling
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"), #Capa de Convolusion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),#Capa de Convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"), #Capa de Convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.MaxPool2D(pool_size=(2,2)), #Capa de Max Pooling
    keras.layers.Flatten(), #Convierto a matriz unidimensional
    keras.layers.Dense(1024,activation='relu'), #Capa densa con diferenteres neuronas
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='relu'), #Capa densa
    keras.layers.Dropout(0.5),
    keras.layers.Dense(10,activation='softmax')  #Capa densa  
])

# %%
#addic
model.compile(
    loss='sparse_categorical_crossentropy',
    #optimizer=tf.optimizers.SGD(lr=0.001),
    optimizer='adam',
    metrics=['accuracy']    
)
#Entrego un resumen de mi modelo que indica la composicion de cada capa
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 46, 46, 128)       46592
#
#  batch_normalization_5 (Batc  (None, 46, 46, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 23, 23, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 23, 23, 256)       819456
#
#  batch_normalization_6 (Batc  (None, 23, 23, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 7, 7, 256)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 256)         590080
#
#  batch_normalization_7 (Batc  (None, 7, 7, 256)        1024
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 7, 7, 256)         65792
#
#  batch_normalization_8 (Batc  (None, 7, 7, 256)        1024
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 7, 7, 256)         65792
#
#  batch_normalization_9 (Batc  (None, 7, 7, 256)        1024
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 3, 3, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 2304)              0
#
#  dense_3 (Dense)             (None, 1024)              2360320
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 1024)              1049600
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 10)                10250
#
# =================================================================
# Total params: 5,012,490
# Trainable params: 5,010,186
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
train_feature_extractor=model.predict(x_train)
train_features = train_feature_extractor.reshape(train_feature_extractor.shape[0], -1)
#test features
test_feature_extractor=model.predict(x_test)
test_features = test_feature_extractor.reshape(test_feature_extractor.shape[0], -1)
# Out:
# 52/52 [==============================] - 61s 998ms/step
# 13/13 [==============================] - 25s 1s/step

# %%
pca_test = PCA(n_components=1659) #
pca_test.fit(train_features)
plt.plot(np.cumsum(pca_test.explained_variance_ratio_))
plt.xlabel("Number of components")
plt.ylabel("Cum variance")
# Out:
# Text(0, 0.5, 'Cum variance')

# %%
n_PCA_components = 250
pca = PCA(n_components=n_PCA_components)
train_PCA = pca.fit_transform(train_features)
test_PCA = pca.transform(test_features)

# %%
model = Sequential()
inputs = Input(shape=(n_PCA_components,)) #Shape = n_components
hidden = Dense(192, activation='relu')(inputs)
#hidden1 = Dense(512, activation='relu')(inputs)
#hidden2 = Dense(192, activation='relu')(hidden1)
output = Dense(24, activation='softmax')(hidden)
model = Model(inputs=inputs, outputs=output)

# %%
print(model.summary())
#
model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['categorical_accuracy'])
# Out:
# Model: "model_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 250)]             0
#
#  dense_12 (Dense)            (None, 192)               48192
#
#  dense_13 (Dense)            (None, 24)                4632
#
# =================================================================
# Total params: 52,824
# Trainable params: 52,824
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
import datetime
start = datetime.datetime.now()
#Fit the model. Do not forget to use on-hot-encoded Y values. 
model.fit(train_PCA, y_train_one_hot, epochs=50, verbose=1,callbacks=[es])

end = datetime.datetime.now()
print("Total execution time with PCA is: ", end-start)
# Out:
# Epoch 1/50
# 43/52 [=======================>......] - ETA: 0s - loss: 3.1695 - categorical_accuracy: 0.0632    WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 10s 3ms/step - loss: 3.1680 - categorical_accuracy: 0.0639
# Epoch 2/50
# 36/52 [===================>..........] - ETA: 0s - loss: 3.1452 - categorical_accuracy: 0.0816WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.1431 - categorical_accuracy: 0.0729
# Epoch 3/50
# 39/52 [=====================>........] - ETA: 0s - loss: 3.1257 - categorical_accuracy: 0.0721WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.1248 - categorical_accuracy: 0.0735
# Epoch 4/50
# 37/52 [====================>.........] - ETA: 0s - loss: 3.1139 - categorical_accuracy: 0.0684WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.1120 - categorical_accuracy: 0.0699
# Epoch 5/50
# 37/52 [====================>.........] - ETA: 0s - loss: 3.1003 - categorical_accuracy: 0.0709WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.1001 - categorical_accuracy: 0.0705
# Epoch 6/50
# 36/52 [===================>..........] - ETA: 0s - loss: 3.0804 - categorical_accuracy: 0.0799WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.0875 - categorical_accuracy: 0.0759
# Epoch 7/50
# 35/52 [===================>..........] - ETA: 0s - loss: 3.0721 - categorical_accuracy: 0.0964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.0728 - categorical_accuracy: 0.1019
# Epoch 8/50
# 48/52 [==========================>...] - ETA: 0s - loss: 3.0545 - categorical_accuracy: 0.1029WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.0560 - categorical_accuracy: 0.1049
# Epoch 9/50
# 37/52 [====================>.........] - ETA: 0s - loss: 3.0386 - categorical_accuracy: 0.1056WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.0371 - categorical_accuracy: 0.1109
# Epoch 10/50
# 43/52 [=======================>......] - ETA: 0s - loss: 3.0182 - categorical_accuracy: 0.1446WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 3.0166 - categorical_accuracy: 0.1453
# Epoch 11/50
# 52/52 [==============================] - ETA: 0s - loss: 2.9935 - categorical_accuracy: 0.1634WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.9935 - categorical_accuracy: 0.1634
# Epoch 12/50
# 42/52 [=======================>......] - ETA: 0s - loss: 2.9728 - categorical_accuracy: 0.1674WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.9695 - categorical_accuracy: 0.1706
# Epoch 13/50
# 38/52 [====================>.........] - ETA: 0s - loss: 2.9528 - categorical_accuracy: 0.1686WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.9434 - categorical_accuracy: 0.1778
# Epoch 14/50
# 45/52 [========================>.....] - ETA: 0s - loss: 2.9169 - categorical_accuracy: 0.1868WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 4ms/step - loss: 2.9150 - categorical_accuracy: 0.1881
# Epoch 15/50
# 38/52 [====================>.........] - ETA: 0s - loss: 2.8822 - categorical_accuracy: 0.1908WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.8870 - categorical_accuracy: 0.1917
# Epoch 16/50
# 35/52 [===================>..........] - ETA: 0s - loss: 2.8672 - categorical_accuracy: 0.1964WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.8581 - categorical_accuracy: 0.2043
# Epoch 17/50
# 36/52 [===================>..........] - ETA: 0s - loss: 2.8280 - categorical_accuracy: 0.2092WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.8280 - categorical_accuracy: 0.2049
# Epoch 18/50
# 51/52 [============================>.] - ETA: 0s - loss: 2.7971 - categorical_accuracy: 0.2267WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.7966 - categorical_accuracy: 0.2266
# Epoch 19/50
# 34/52 [==================>...........] - ETA: 0s - loss: 2.7981 - categorical_accuracy: 0.2188WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.7673 - categorical_accuracy: 0.2375
# Epoch 20/50
# 43/52 [=======================>......] - ETA: 0s - loss: 2.7422 - categorical_accuracy: 0.2384WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 4ms/step - loss: 2.7369 - categorical_accuracy: 0.2411
# Epoch 21/50
# 50/52 [===========================>..] - ETA: 0s - loss: 2.7062 - categorical_accuracy: 0.2631WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.7066 - categorical_accuracy: 0.2616
# Epoch 22/50
# 36/52 [===================>..........] - ETA: 0s - loss: 2.6826 - categorical_accuracy: 0.2613WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.6756 - categorical_accuracy: 0.2610
# Epoch 23/50
# 48/52 [==========================>...] - ETA: 0s - loss: 2.6433 - categorical_accuracy: 0.2812WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 4ms/step - loss: 2.6454 - categorical_accuracy: 0.2803
# Epoch 24/50
# 36/52 [===================>..........] - ETA: 0s - loss: 2.6305 - categorical_accuracy: 0.2943WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.6158 - categorical_accuracy: 0.2911
# Epoch 25/50
# 34/52 [==================>...........] - ETA: 0s - loss: 2.5931 - categorical_accuracy: 0.2987WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.5866 - categorical_accuracy: 0.3044
# Epoch 26/50
# 35/52 [===================>..........] - ETA: 0s - loss: 2.5562 - categorical_accuracy: 0.2920WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.5567 - categorical_accuracy: 0.3086
# Epoch 27/50
# 39/52 [=====================>........] - ETA: 0s - loss: 2.5367 - categorical_accuracy: 0.3117WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.5289 - categorical_accuracy: 0.3128
# Epoch 28/50
# 42/52 [=======================>......] - ETA: 0s - loss: 2.5030 - categorical_accuracy: 0.3341WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.5008 - categorical_accuracy: 0.3327
# Epoch 29/50
# 44/52 [========================>.....] - ETA: 0s - loss: 2.4829 - categorical_accuracy: 0.3310WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.4726 - categorical_accuracy: 0.3285
# Epoch 30/50
# 45/52 [========================>.....] - ETA: 0s - loss: 2.4474 - categorical_accuracy: 0.3458WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.4451 - categorical_accuracy: 0.3484
# Epoch 31/50
# 41/52 [======================>.......] - ETA: 0s - loss: 2.4167 - categorical_accuracy: 0.3613WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.4182 - categorical_accuracy: 0.3550
# Epoch 32/50
# 50/52 [===========================>..] - ETA: 0s - loss: 2.3954 - categorical_accuracy: 0.3575WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.3927 - categorical_accuracy: 0.3574
# Epoch 33/50
# 37/52 [====================>.........] - ETA: 0s - loss: 2.3536 - categorical_accuracy: 0.3860WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.3663 - categorical_accuracy: 0.3713
# Epoch 34/50
# 37/52 [====================>.........] - ETA: 0s - loss: 2.3590 - categorical_accuracy: 0.3674WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.3395 - categorical_accuracy: 0.3737
# Epoch 35/50
# 33/52 [==================>...........] - ETA: 0s - loss: 2.3069 - categorical_accuracy: 0.3778WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.3144 - categorical_accuracy: 0.3785
# Epoch 36/50
# 39/52 [=====================>........] - ETA: 0s - loss: 2.2947 - categorical_accuracy: 0.3862WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.2896 - categorical_accuracy: 0.3918
# Epoch 37/50
# 50/52 [===========================>..] - ETA: 0s - loss: 2.2676 - categorical_accuracy: 0.4019WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.2656 - categorical_accuracy: 0.4027
# Epoch 38/50
# 34/52 [==================>...........] - ETA: 0s - loss: 2.2482 - categorical_accuracy: 0.4072WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.2414 - categorical_accuracy: 0.4075
# Epoch 39/50
# 38/52 [====================>.........] - ETA: 0s - loss: 2.2190 - categorical_accuracy: 0.4161WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.2169 - categorical_accuracy: 0.4171
# Epoch 40/50
# 38/52 [====================>.........] - ETA: 0s - loss: 2.1854 - categorical_accuracy: 0.4326WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.1920 - categorical_accuracy: 0.4244
# Epoch 41/50
# 51/52 [============================>.] - ETA: 0s - loss: 2.1738 - categorical_accuracy: 0.4350WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.1690 - categorical_accuracy: 0.4382
# Epoch 42/50
# 35/52 [===================>..........] - ETA: 0s - loss: 2.1553 - categorical_accuracy: 0.4304WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.1465 - categorical_accuracy: 0.4382
# Epoch 43/50
# 48/52 [==========================>...] - ETA: 0s - loss: 2.1208 - categorical_accuracy: 0.4570WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 4ms/step - loss: 2.1232 - categorical_accuracy: 0.4539
# Epoch 44/50
# 35/52 [===================>..........] - ETA: 0s - loss: 2.0977 - categorical_accuracy: 0.4607WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.1017 - categorical_accuracy: 0.4557
# Epoch 45/50
# 35/52 [===================>..........] - ETA: 0s - loss: 2.0921 - categorical_accuracy: 0.4616WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.0794 - categorical_accuracy: 0.4629
# Epoch 46/50
# 49/52 [===========================>..] - ETA: 0s - loss: 2.0662 - categorical_accuracy: 0.4707WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.0575 - categorical_accuracy: 0.4768
# Epoch 47/50
# 51/52 [============================>.] - ETA: 0s - loss: 2.0376 - categorical_accuracy: 0.4761WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.0358 - categorical_accuracy: 0.4792
# Epoch 48/50
# 35/52 [===================>..........] - ETA: 0s - loss: 2.0155 - categorical_accuracy: 0.4938WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 2.0150 - categorical_accuracy: 0.4882
# Epoch 49/50
# 44/52 [========================>.....] - ETA: 0s - loss: 1.9963 - categorical_accuracy: 0.4865WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 4ms/step - loss: 1.9940 - categorical_accuracy: 0.4907
# Epoch 50/50
# 52/52 [==============================] - ETA: 0s - loss: 1.9724 - categorical_accuracy: 0.4985WARNING:tensorflow:Early stopping conditioned on metric `val_loss` which is not available. Available metrics are: loss,categorical_accuracy
# 52/52 [==============================] - 0s 3ms/step - loss: 1.9724 - categorical_accuracy: 0.4985
# Total execution time with PCA is:  0:00:18.401974

# %%
predict_test = model.predict(test_PCA)
predict_test = np.argmax(predict_test, axis=1)
predict_test = le.inverse_transform(predict_test)
# Out:
# 13/13 [==============================] - 6s 1ms/step

# %%
from sklearn import metrics
print ("Accuracy = ", metrics.accuracy_score(test_labels, predict_test))
# Out:
# Accuracy =  0.39036144578313253

# %% [markdown]
# # DROPOUT - GRIDSEARCH

# %%
from keras.callbacks import LearningRateScheduler
from sklearn.model_selection import GridSearchCV
from keras.constraints import maxnorm

# %%
np.random.seed(42)
x_train, x_test, y_train, y_test = train_test_split(images, labels, test_size = 0.2, random_state = random_seed)

# %%
# normalize the data
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
# reshape images to 1D so we can just work with dense layers
#For this demo purposes
x_train = x_train.reshape(1659,192, 192, 3)
x_test = x_test.reshape(415, 192, 192, 3)

num_classes = 24

# %%
# One hot encoding for categorical labels
y_train = keras.utils.to_categorical(y_train, num_classes)
y_test = keras.utils.to_categorical(y_test, num_classes)

# %%
#Take a subset of train for grid search. Let us take 10% for now
from sklearn.model_selection import train_test_split
x_grid, x_not_use, y_grid, y_not_use = train_test_split(x_train, y_train, test_size=0.9, random_state=42)

# %%
# build the model
input_dim = x_grid.shape[1]

# %%
#NOTE: Add default optimizer, otherwise throws error 'optimizer not legal parameter'
def define_model(dropout_rate=0.0, weight_constraint=0, neurons=10):   

    model=Sequential()

    #1 conv layer
    model.add(Conv2D(filters=96,kernel_size=(11,11),strides=(4,4),padding="valid",activation="relu",input_shape=(227,227,3)))

    #1 max pool layer
    model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))

    model.add(BatchNormalization())

    #2 conv layer
    model.add(Conv2D(filters=256,kernel_size=(5,5),strides=(1,1),padding="valid",activation="relu"))

    #2 max pool layer
    model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))

    model.add(BatchNormalization())

    #3 conv layer
    model.add(Conv2D(filters=384,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

    #4 conv layer
    model.add(Conv2D(filters=384,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

    #5 conv layer
    model.add(Conv2D(filters=256,kernel_size=(3,3),strides=(1,1),padding="valid",activation="relu"))

    #3 max pool layer
    model.add(MaxPooling2D(pool_size=(3,3),strides=(2,2)))

    model.add(BatchNormalization())


    model.add(Flatten())

    #1 dense layer
    model.add(Dense(4096,input_shape=(227,227,3),activation="relu"))

    model.add(Dropout(0.4))

    model.add(BatchNormalization())

    #2 dense layer
    model.add(Dense(4096,activation="relu"))

    model.add(Dropout(0.4))

    model.add(BatchNormalization())

    #3 dense layer
    model.add(Dense(1000,activation="relu"))

    model.add(Dropout(0.4))

    model.add(BatchNormalization())

    #output layer
    model.add(Dense(24,activation="softmax"))

    model.summary()
    
    # compile the model
    model.compile(loss='sparse_categorical_crossentropy',
                  optimizer='sdam',      
                  metrics=['accuracy'])
    return model

# %%
# implement the Scikit-Learn classifier interface
# requires model defined as a function, which we already have
from keras.wrappers.scikit_learn import KerasClassifier

model = KerasClassifier(build_fn=define_model, 
                        verbose=1)
# Out:
# C:\Users\wilme\AppData\Local\Temp\ipykernel_1988\466899070.py:5: DeprecationWarning: KerasClassifier is deprecated, use Sci-Keras (https://github.com/adriangb/scikeras) instead. See https://www.adriangb.com/scikeras/stable/migration.html for help migrating.
#   model = KerasClassifier(build_fn=define_model,

# %%
dropout_rate = [0.0, 0.2, 0.4]
weight_constraint = [1, 2, 3]
neurons = [10, 32, 64]
batch_size = [100, 200, 400]
epochs = [1, 5, 10]

# %%
param_grid = dict(dropout_rate=dropout_rate, 
                  weight_constraint=weight_constraint,
                  neurons=neurons, batch_size=batch_size, 
                  epochs=epochs)

# %%
#n_jobs=16 uses 16 CPUs. Try not to do -1 on your system as it may hang!!!
# -1 refers to using all available CPUs
#Cross validation, cv=3
grid = GridSearchCV(estimator=model, param_grid=param_grid, n_jobs=1, cv=3)

grid_result = grid.fit(x_grid, y_grid)

# %%
# summarize results
print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [22], in <cell line: 2>()
#       1 # summarize results
# ----> 2 print("Best: %f using %s" % (grid_result.best_score_, grid_result.best_params_))
#
# NameError: name 'grid_result' is not defined

# %% [markdown]
# # Definir el modelo CNN de AlexNet

# %% [markdown]
# Definir todas las capas en el modelo AlexNet CNN

# %%
model=keras.models.Sequential([
    keras.layers.Conv2D(filters=128, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227,227,3)),#Implementación de la primera capa de convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion para mitigar los efectos del gradiente estandarizando y normalizando los valores de entrada
    keras.layers.MaxPool2D(pool_size=(2,2)), #Capa de MaxPooling con una ventana de 2x2
    keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),#Capa de Convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.MaxPool2D(pool_size=(3,3)), #Capa de MaxPooling
    keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"), #Capa de Convolusion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"),#Capa de Convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.Conv2D(filters=256, kernel_size=(1,1), strides=(1,1), activation='relu', padding="same"), #Capa de Convolucion
    keras.layers.BatchNormalization(), #Capa de Normalizacion
    keras.layers.MaxPool2D(pool_size=(2,2)), #Capa de Max Pooling
    keras.layers.Flatten(), #Convierto a matriz unidimensional
    keras.layers.Dense(1024,activation='relu'), #Capa densa con diferenteres neuronas
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1024,activation='relu'), #Capa densa
    keras.layers.Dropout(0.5),
    keras.layers.Dense(24,activation='softmax')  #Capa densa  
])

# %% [markdown]
# Compilar el modelo CNN

# %%
#Implemento la compilacion del modelo con la funcion de perdida, el algoritmo de optimizacion e incluyo la metrica que usare
model.compile(
    loss='sparse_categorical_crossentropy',
    #optimizer=tf.optimizers.SGD(lr=0.001),
    optimizer='adam',
    metrics=['accuracy']    
)
#Entrego un resumen de mi modelo que indica la composicion de cada capa
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_5 (Conv2D)           (None, 55, 55, 128)       46592
#
#  batch_normalization_5 (Batc  (None, 55, 55, 128)      512
#  hNormalization)
#
#  max_pooling2d_3 (MaxPooling  (None, 27, 27, 128)      0
#  2D)
#
#  conv2d_6 (Conv2D)           (None, 27, 27, 256)       819456
#
#  batch_normalization_6 (Batc  (None, 27, 27, 256)      1024
#  hNormalization)
#
#  max_pooling2d_4 (MaxPooling  (None, 9, 9, 256)        0
#  2D)
#
#  conv2d_7 (Conv2D)           (None, 9, 9, 256)         590080
#
#  batch_normalization_7 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  conv2d_8 (Conv2D)           (None, 9, 9, 256)         65792
#
#  batch_normalization_8 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  conv2d_9 (Conv2D)           (None, 9, 9, 256)         65792
#
#  batch_normalization_9 (Batc  (None, 9, 9, 256)        1024
#  hNormalization)
#
#  max_pooling2d_5 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  flatten_1 (Flatten)         (None, 4096)              0
#
#  dense_3 (Dense)             (None, 1024)              4195328
#
#  dropout_2 (Dropout)         (None, 1024)              0
#
#  dense_4 (Dense)             (None, 1024)              1049600
#
#  dropout_3 (Dropout)         (None, 1024)              0
#
#  dense_5 (Dense)             (None, 24)                24600
#
# =================================================================
# Total params: 6,861,848
# Trainable params: 6,859,544
# Non-trainable params: 2,304
# _________________________________________________________________

# %%
"""Usando EarlyStopping para mayor acurrancy"""
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=200)

# %% [markdown]
# Ajuste el modelo usando datos de entrenamiento

# %%
#Proceso de entrenamiento de la red
history = model.fit(train_ds, train_labels, epochs=10, validation_split=0.2)
# Out:
# Epoch 1/10
# 42/42 [==============================] - 291s 7s/step - loss: 4.2728 - accuracy: 0.0950 - val_loss: 3.8709 - val_accuracy: 0.0542
# Epoch 2/10
# 42/42 [==============================] - 271s 6s/step - loss: 3.0111 - accuracy: 0.1349 - val_loss: 3.0691 - val_accuracy: 0.0753
# Epoch 3/10
# 42/42 [==============================] - 259s 6s/step - loss: 2.8983 - accuracy: 0.1944 - val_loss: 2.8402 - val_accuracy: 0.1566
# Epoch 4/10
# 42/42 [==============================] - 256s 6s/step - loss: 2.6679 - accuracy: 0.2080 - val_loss: 2.8427 - val_accuracy: 0.1506
# Epoch 5/10
# 42/42 [==============================] - 269s 6s/step - loss: 2.5253 - accuracy: 0.2374 - val_loss: 2.8060 - val_accuracy: 0.1627
# Epoch 6/10
# 42/42 [==============================] - 268s 6s/step - loss: 2.3823 - accuracy: 0.2886 - val_loss: 2.6981 - val_accuracy: 0.2108
# Epoch 7/10
# 42/42 [==============================] - 296s 7s/step - loss: 2.2573 - accuracy: 0.3414 - val_loss: 2.5583 - val_accuracy: 0.2169
# Epoch 8/10
# 42/42 [==============================] - 334s 8s/step - loss: 2.1427 - accuracy: 0.3738 - val_loss: 2.9370 - val_accuracy: 0.2319
# Epoch 9/10
# 42/42 [==============================] - 349s 8s/step - loss: 1.9706 - accuracy: 0.4092 - val_loss: 2.5806 - val_accuracy: 0.2771
# Epoch 10/10
# 42/42 [==============================] - 413s 10s/step - loss: 1.7433 - accuracy: 0.4710 - val_loss: 1.9111 - val_accuracy: 0.4247

# %% [markdown]
# Métricas para evaluar la precisión y la pérdida en el conjunto de datos de prueba

# %%
loss, accuracy = model.evaluate(test_ds, test_labels)

print(loss,accuracy)
# Out:
# 13/13 [==============================] - 44s 3s/step - loss: 1.8930 - accuracy: 0.4410
# 1.8929513692855835 0.44096386432647705

# %% [markdown]
# # Predecir valores usando el modelo entrenado

# %%
"""Declarando variable para predecir"""
pred = model.predict(test_ds)

pred.shape
# Out:
# 1/1 [==============================] - 8s 8s/step
# (30, 20)

# %% [markdown]
# Muestre pocas imágenes aleatorias con valores de etiquetas reales versus predichos

# %%
plt.figure(1 , figsize = (19 , 10))
n = 0 

for i in range(9):
    n += 1 
    r = np.random.randint( 0, test_ds.shape[0], 1)
    
    plt.subplot(3, 3, n)
    plt.subplots_adjust(hspace = 0.3, wspace = 0.3)
    
    plt.imshow(test_ds[r[0]])
    plt.title('Actual = {}, Predicted = {}'.format(test_labels[r[0]] , test_labels[r[0]]*pred[r[0]][test_labels[r[0]]]) )
    plt.xticks([]) , plt.yticks([])

plt.show()

# %%
loss, accuracy = model.evaluate(test_ds, test_labels)

print(loss,accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [4], in <cell line: 1>()
# ----> 1 loss, accuracy = model.evaluate(test_ds, test_labels)
#       3 print(loss,accuracy)
#
# NameError: name 'model' is not defined
